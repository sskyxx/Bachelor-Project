# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
from matplotlib.patches import Circle
import os
import pickle
from scipy.stats import mannwhitneyu, ttest_ind, kruskal, f_oneway
from statannotations.Annotator import Annotator
from itertools import combinations

# %%
df_food_scaled = pd.read_csv('df_food_scaled.csv')
# Out:
# C:\Users\Sophie\AppData\Local\Temp\ipykernel_12360\4074791732.py:1: DtypeWarning: Columns (1,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food_scaled = pd.read_csv('df_food_scaled.csv')

# %%
df_hard_semi_hard_cheese = df_food_scaled[df_food_scaled['food_group'] == 'hard_semi_hard_cheese']
df_hard_semi_hard_cheese.drop_duplicates('combined_name')[['combined_name', 'QI', 'DI', 'NB']].sort_values('QI', ascending=False)
# Out:
#                                            combined_name        QI        DI  \
# 272896                     Fol Epi Classic soft & fruity  6.573909  3.595762
# 282578                     Migros Fol Epi Léger 7 slices  2.100957  1.912679
# 296924                        Toast processed fat cheese  1.743339  2.745038
# 299511         Coop Qualité & Prix - Cheddar Schmelzkäse  1.694202  2.331588
# 103394                                  Processed cheese  1.667539  2.461564
# ...                                                  ...       ...       ...
# 100925                                          Mutschli  0.113846  1.280629
# 313727                         Der scharfe Maxx Scheiben  0.113636  1.398678
# 308101  M Le Gruyère Swiss Classic Ramequins Gruyère AOP  0.092134  1.135489
# 311096             Milfina - Trappisten-Käse in Scheiben  0.038043  0.344707
# 94193                                        Gala cheese  0.028141  1.502181
#
#                NB
# 272896  78.091519
# ...
