# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
from matplotlib.patches import Circle
import os
import pickle
from scipy.stats import mannwhitneyu, ttest_ind, kruskal, f_oneway
from statannotations.Annotator import Annotator
from itertools import combinations

# %%
df_food = pd.read_csv("df_food_filtered_with_food_group.csv",index_col=0)
with open("df_food_openfoodfacts_merged.pkl", "rb") as f:
    df_food_openfoodfacts = pickle.load(f, encoding="latin1")
# Out:
# C:\Users\Sophie\AppData\Local\Temp\ipykernel_14232\1585345951.py:1: DtypeWarning: Columns (2,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food = pd.read_csv("df_food_filtered_with_food_group.csv",index_col=0)

# %%
df_food = df_food[df_food["eaten_quantity_in_gram"] > 0]
df_food = df_food[df_food["energy_kcal_eaten"] > 0]

# %%
nutrient_info = {
    'folate_eaten':                                         {'unit': 'mcg', 'target': 400,  'type': 'qualifying'},
    'niacin_eaten':                                         {'unit': 'mg',  'target': 14,   'type': 'qualifying'},
    'pantothenic_acid_eaten':                               {'unit': 'mg',  'target': 5,    'type': 'qualifying'},
    'vitamin_b2_eaten':                                     {'unit': 'mg',  'target': 1.1,  'type': 'qualifying'},
    'vitamin_b1_eaten':                                     {'unit': 'mg',  'target': 1.2,  'type': 'qualifying'},
    'all_trans_retinol_equivalents_activity_eaten':         {'unit': 'IU',  'target': 700,  'type': 'qualifying'},
    'beta_carotene_eaten':                                  {'unit' : 'mcg','target' : 700, 'type' :'qualifying'},
    'vitamin_b12_eaten':                                    {'unit': 'mcg', 'target': 2.4,  'type': 'qualifying'},
    'vitamin_b6_eaten':                                     {'unit': 'mg',  'target': 1.3,  'type': 'qualifying'},
    'vitamin_c_eaten':                                      {'unit': 'mg',  'target': 75,   'type': 'qualifying'},
    'vitamin_d_eaten':                                      {'unit': 'mcg', 'target': 7.5,  'type': 'qualifying'},
    'vitamin_e_activity_eaten':                             {'unit': 'TAE', 'target': 15,    'type': 'qualifying'},
    'calcium_eaten':                                        {'unit': 'mg',  'target': 1000, 'type': 'qualifying'},
    'iron_eaten':                                           {'unit': 'mg',  'target': 18,   'type': 'qualifying'},
    'magnesium_eaten':                                      {'unit': 'mg',  'target': 320,  'type': 'qualifying'},
    'phosphorus_eaten':                                     {'unit': 'mg',  'target': 700,  'type': 'qualifying'},
    'potassium_eaten':                                      {'unit': 'mg',  'target': 4700, 'type': 'qualifying'},
    'zinc_eaten':                                           {'unit': 'mg',  'target': 8,    'type': 'qualifying'},
    'fiber_eaten':                                          {'unit': 'g',   'target': 25,   'type': 'qualifying'},
    'protein_eaten':                                        {'unit': 'g',   'target': 46,   'type': 'qualifying'},
    'fat_eaten':                                            {'unit': 'g',   'target': 78,   'type': 'disqualifying'},
    'fatty_acids_saturated_eaten':                          {'unit': 'g',   'target': 22,   'type': 'disqualifying'},
    'cholesterol_eaten':                                    {'unit': 'mg',  'target': 300,  'type': 'disqualifying'},
    'sugar_eaten':                                          {'unit': 'g',   'target': 125,  'type': 'disqualifying'},
    'sodium_eaten':                                         {'unit': 'mg',  'target': 2400, 'type': 'disqualifying'},
    'salt_eaten' :                                          {'unit' : 'g',  'target': 6,   'type': 'disqualifying'}
}


conversion_factors = {
    "mg": 1000,
    "g": 1,
    "mcg": 1000000,
    "IU": 1,
    "TAE": 1,
}

# %%
qualifying_nutrients = {nutr: info for nutr, info in nutrient_info.items() if info['type'] == 'qualifying'}
disqualifying_nutrients = {nutr: info for nutr, info in nutrient_info.items() if info['type'] == 'disqualifying'}

# %%
df_food_scaled = pd.read_csv('df_food_scaled.csv')
# Out:
# C:\Users\Sophie\AppData\Local\Temp\ipykernel_14232\4074791732.py:1: DtypeWarning: Columns (1,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food_scaled = pd.read_csv('df_food_scaled.csv')

# %%
df_food_scaled[['QI', 'DI','NB', 'combined_name', 'food_group']].groupby('food_group').median(numeric_only=True).sort_values('QI')
# Out:
#                                      QI        DI         NB
# food_group
# alcoholic_beverages            0.038127  0.007668   3.812709
# sweetened_beverages            0.041806  0.664300   4.180602
# others                         0.105016  0.666667   5.474351
# soups_sauces_condiments        0.117561  1.068889   6.402525
# salty_snacks                   0.121828  0.535766  10.000000
# cooked_grains_pasta            0.135563  0.517566   9.358974
# sweets_desserts                0.157373  0.852030  12.639102
# vegetable_oils                 0.245871  0.694173   6.645221
# butter_margarine_spreads       0.284294  1.837749  15.794434
# soy_granules_textured_protein  0.310860  0.904191  10.000000
# cereal_grains_starches         0.387116  0.772625  37.638387
# bread_pastries                 0.394379  0.794362  36.802253
# cream_based_foods              0.404529  1.780764  30.226246
# vegetable_fruit_juices         0.417644  0.626646  27.020117
# pulses                         0.704875  0.328410  40.796185
# processed_foods                0.712773  0.773424  59.909995
# breakfast_cereals              0.900254  0.217934  55.079974
# processed_meats                0.970745  1.723488  54.014220
# nuts_seeds                     1.053747  0.562181  60.146978
# soft_cheese                    1.106874  1.817459  49.344432
# milk                           1.317956  1.376910  63.051948
# hard_semi_hard_cheese          1.335195  1.663530  53.737957
# fruits                         1.340383  0.581514  67.680753
# potatoes                       1.365492  0.034843  69.079880
# yogurt_fresh_dairy             1.465341  0.999830  60.670446
# tofu_tempeh_seitan             1.839542  0.283953  64.834583
# eggs                           2.098087  4.464696  64.299480
# beverages                      2.115202  0.090278  35.000000
# meat_fish_seafood              2.202903  1.039562  62.202229
# vegetables                     6.021484  0.475585  81.058201

# %%
df_meat_fish_seafood = df_food_scaled[df_food_scaled['food_group'] == 'meat_fish_seafood']

# %%
df_meat_fish_seafood.drop_duplicates('combined_name')
# Out:
#         food_id        barcode  dish_id  eaten_quantity eaten_unit  \
# 0            13              0   335994           110.0          g
# 56           27              0   118524            60.0          g
# 800          71              0   372924           100.0          g
# 802          82              0   102980           120.0          g
# 815          83              0   113397           250.0          g
# ...         ...            ...      ...             ...        ...
# 317129    33144  7613312222911   386534           155.0          g
# 317360    33417  7613269437260   393863           300.0          g
# 317488    33609  3660088100350   400544            90.0          g
# 317589    46072  7613312352717   406386           125.0          g
# 317749    46436  7610200094025   423397           120.0          g
#
#        subject_key             eaten_at  eaten_at_utc_offset  media_count  \
# 0           bjsqab  2022-02-15 18:06:27                   60            1
# 56          nwfrgc  2020-05-11 17:53:04                  120            1
# 800         7wuem4  2022-07-06 18:42:58                  120            1
# 802         cbqxxj  2020-03-23 11:04:30                   60            1
# 815         8vtq3c  2020-04-27 17:30:00                  120            0
# ...            ...                  ...                  ...          ...
# 317129      x4xuqb  2022-09-22 15:21:21                  120            0
# 317360      vxyht3  2022-10-21 20:15:55                  120            0
# 317488      7mm74m  2022-11-16 11:25:53                   60            0
# 317589      48wbxy  2022-12-08 11:10:36                   60            0
# 317749      u3z8m4  2023-02-24 19:14:10                   60            1
#
#                           food_group_cname  ... potassium_eaten_ratio_scaled  \
# 0       dairy_products_meat_fish_eggs_tofu  ...                     0.856776
# 56      dairy_products_meat_fish_eggs_tofu  ...                     0.584522
# 800     dairy_products_meat_fish_eggs_tofu  ...                     0.368107
# 802     dairy_products_meat_fish_eggs_tofu  ...                     0.697593
# 815     dairy_products_meat_fish_eggs_tofu  ...                     0.788022
# ...                                    ...  ...                          ...
# 317129                        unclassified  ...                     0.000000
# 317360                        unclassified  ...                     0.000000
# 317488                        unclassified  ...                     0.000000
# 317589                        unclassified  ...                     0.000000
# 317749                        unclassified  ...                     0.000000
#
#        zinc_eaten_ratio_scaled fiber_eaten_ratio_scaled  \
# 0                     7.214765                 0.000000
# 56                    2.335165                 0.000000
# 800                   5.017301                 0.000000
# 802                   6.420765                 0.000000
# 815                  12.500000                 0.000000
# ...                        ...                      ...
# 317129                0.000000                 0.000000
# 317360                0.000000                 0.317460
# 317488                0.000000                 0.000000
# 317589                0.000000                 0.000000
# 317749                0.000000                 0.218579
#
#        protein_eaten_ratio_scaled  fat_eaten_ratio_scaled  \
# 0                        7.936971                0.774393
# 56                       6.306737                1.183432
# 800                      4.889424                1.570402
# 802                      7.555239                0.868712
# 815                      8.051530                0.743906
# ...                           ...                     ...
# 317129                   6.769071                1.074774
# 317360                   5.521049                0.712251
# 317488                   3.801242                1.846154
# 317589                   3.881988                1.831502
# 317749                   4.751722                1.541264
#
#         fatty_acids_saturated_eaten_ratio_scaled  \
# 0                                       1.037218
# 56                                      1.448551
# 800                                     2.359232
# 802                                     1.490313
# 815                                     0.953984
# ...                                          ...
# 317129                                  1.088732
# 317360                                  0.721501
# 317488                                  1.641558
# 317589                                  1.217532
# 317749                                  1.738698
#
#        cholesterol_eaten_ratio_scaled  sugar_eaten_ratio_scaled  \
# 0                            3.937360                  0.000000
# 56                           2.783883                  0.008791
# 800                          2.029988                  0.000000
# 802                          2.295082                  0.000000
# 815                          3.497942                  0.000000
# ...                               ...                       ...
# 317129                       0.000000                  0.047904
# 317360                       0.000000                  0.825397
# 317488                       0.000000                  0.036571
# 317589                       0.000000                  0.000000
# 317749                       0.000000                  0.087432
#
#         sodium_eaten_ratio_scaled  salt_eaten_ratio_scaled
# 0                        0.430649                 0.000000
# 56                      22.756410                 0.000000
# 800                      0.129758                 0.000000
# 802                      0.223133                 0.000000
# 815                      0.303498                 0.000000
# ...                           ...                      ...
# 317129                   0.000000                 1.896208
# 317360                   0.000661                 0.000000
# 317488                   0.000000                 0.761905
# 317589                   0.000000                 0.148810
# 317749                   0.002140                 2.185792
#
# [321 rows x 150 columns]

# %%
high_qi_meat_fish_seafood = df_meat_fish_seafood[df_meat_fish_seafood['QI'] > 10].drop_duplicates('combined_name').sort_values('QI', ascending=False)

# %%
high_qi_meat_fish_seafood[['combined_name', 'eaten_quantity', 'QI', 'DI', 'NB']]
# Out:
#                           combined_name  eaten_quantity         QI        DI  \
# 260724             Perch fillets (lake)           120.0  61.567363  1.045119
# 154859                            Liver            30.0  31.765218  3.232951
# 294168     Sushi Nigiri "saumon & thon"            90.0  17.293963  0.484705
# 276920  GRAN MAR Polypfisch in Marinade            57.5  12.878941  1.905372
# 285020                          Octopus           110.0  12.093442  1.193991
#
#                NB
# 260724  80.933707
# 154859  77.415456
# 294168  62.241389
# 276920  82.178683
# 285020  81.319930

# %%
def compute_index(row, nutrient_cols, scaling_factor=2000) :

    index = 0
    ratio_sum = 0

    for nutr in nutrient_cols :
        ratio_sum += row[nutr + '_ratio']

    index = (scaling_factor / row['energy_kcal_eaten']) * (ratio_sum / len(nutrient_cols))
    return index

# %%
def compute_qi_excluding(row, nutrient_list, exclude=None, scaling_factor=2000):
    if exclude is not None:
        new_list = [nutr for nutr in nutrient_list if nutr != exclude]
    else:
        new_list = nutrient_list
    

    return compute_index(row, new_list, scaling_factor=scaling_factor)

# %%
high_qi_meat_fish_seafood[high_qi_meat_fish_seafood['combined_name'] == 'Perch fillets (lake)'][[i for i in df_meat_fish_seafood.columns if '_ratio_scaled' in i]].T
# Out:
#                                                          260724
# folate_eaten_ratio_scaled                              0.672269
# niacin_eaten_ratio_scaled                              3.577431
# pantothenic_acid_eaten_ratio_scaled                    2.722689
# vitamin_b2_eaten_ratio_scaled                       1176.470588
# vitamin_b1_eaten_ratio_scaled                          1.260504
# all_trans_retinol_equivalents_activity_eaten_ra...     0.000000
# beta_carotene_eaten_ratio_scaled                       0.000000
# vitamin_b12_eaten_ratio_scaled                         5.812325
# vitamin_b6_eaten_ratio_scaled                          1.680672
# vitamin_c_eaten_ratio_scaled                           0.851541
# vitamin_d_eaten_ratio_scaled                          20.168067
# vitamin_e_activity_eaten_ratio_scaled                  1.478992
# calcium_eaten_ratio_scaled                             1.226891
# iron_eaten_ratio_scaled                                0.662932
# magnesium_eaten_ratio_scaled                           1.365546
# phosphorus_eaten_ratio_scaled                          2.521008
# potassium_eaten_ratio_scaled                           1.183622
# zinc_eaten_ratio_scaled                                1.617647
# fiber_eaten_ratio_scaled                               0.000000
# protein_eaten_ratio_scaled                             8.074534
# fat_eaten_ratio_scaled                                 0.736910
# fatty_acids_saturated_eaten_ratio_scaled               0.649351
# cholesterol_eaten_ratio_scaled                         4.616246
# sugar_eaten_ratio_scaled                               0.000000
# sodium_eaten_ratio_scaled                              0.268207
# salt_eaten_ratio_scaled                                0.000000

# %%
food_item = high_qi_meat_fish_seafood[high_qi_meat_fish_seafood['combined_name'] == 'Perch fillets (lake)'].iloc[0]
qi_including = food_item['QI']
results = []

for nutr in qualifying_nutrients:
    qi_excluding = compute_qi_excluding(food_item, qualifying_nutrients, exclude=nutr, scaling_factor=2000)
    abs_diff = qi_including - qi_excluding
    pct_diff = (abs_diff / qi_including) * 100
    results.append({
        'Nutrient Excluded': nutr,
        'QI (incl.)': qi_including,
        'QI (excl.)': qi_excluding,
        'Absolute Change': abs_diff,
        'Percent Change': pct_diff
    })


df_results = pd.DataFrame(results)
df_results.sort_values('Absolute Change', ascending=False)
# Out:
#                                Nutrient Excluded  QI (incl.)  QI (excl.)  \
# 3                               vitamin_b2_eaten   61.567363    2.888246
# 10                               vitamin_d_eaten   61.567363   63.746273
# 19                                 protein_eaten   61.567363   64.382775
# 7                              vitamin_b12_eaten   61.567363   64.501839
# 1                                   niacin_eaten   61.567363   64.619465
# 2                         pantothenic_acid_eaten   61.567363   64.664451
# 15                              phosphorus_eaten   61.567363   64.675066
# 8                               vitamin_b6_eaten   61.567363   64.719294
# 17                                    zinc_eaten   61.567363   64.722611
# 11                      vitamin_e_activity_eaten   61.567363   64.729909
# 14                               magnesium_eaten   61.567363   64.735880
# 4                               vitamin_b1_eaten   61.567363   64.741408
# 12                                 calcium_eaten   61.567363   64.743177
# 16                               potassium_eaten   61.567363   64.745455
# 9                                vitamin_c_eaten   61.567363   64.762933
# 0                                   folate_eaten   61.567363   64.772368
# 13                                    iron_eaten   61.567363   64.772859
# 6                            beta_carotene_eaten   61.567363   64.807750
# 5   all_trans_retinol_equivalents_activity_eaten   61.567363   64.807750
# 18                                   fiber_eaten   61.567363   64.807750
#
#     Absolute Change  Percent Change
# 3         58.679117       95.308804
# 10        -2.178910       -3.539067
# 19        -2.815412       -4.572897
# 7         -2.934476       -4.766285
# 1         -3.052102       -4.957337
# 2         -3.097088       -5.030406
# 15        -3.107703       -5.047647
# 8         -3.151931       -5.119484
# 17        -3.155248       -5.124871
# 11        -3.162546       -5.136725
# 14        -3.168517       -5.146423
# 4         -3.174045       -5.155402
# 12        -3.175814       -5.158276
# 16        -3.178092       -5.161975
# 9         -3.195570       -5.190363
# 0         -3.205005       -5.205688
# 13        -3.205496       -5.206486
# 6         -3.240388       -5.263158
# 5         -3.240388       -5.263158
# 18        -3.240388       -5.263158

# %% [markdown]
# We observe that for the 'Perch fillets (lake)', the vitamin b2 is the only micronutrient that boost the QI value

# %%
high_qi_meat_fish_seafood[high_qi_meat_fish_seafood['combined_name'] == 'Liver'][[i for i in df_meat_fish_seafood.columns if '_ratio_scaled' in i]].T
# Out:
#                                                         154859
# folate_eaten_ratio_scaled                             7.621951
# niacin_eaten_ratio_scaled                            13.066202
# pantothenic_acid_eaten_ratio_scaled                  20.000000
# vitamin_b2_eaten_ratio_scaled                        32.150776
# vitamin_b1_eaten_ratio_scaled                         2.540650
# all_trans_retinol_equivalents_activity_eaten_ra...  242.160279
# beta_carotene_eaten_ratio_scaled                      0.000000
# vitamin_b12_eaten_ratio_scaled                      279.471545
# vitamin_b6_eaten_ratio_scaled                         8.255159
# vitamin_c_eaten_ratio_scaled                          3.414634
# vitamin_d_eaten_ratio_scaled                          0.650407
# vitamin_e_activity_eaten_ratio_scaled                 0.235772
# calcium_eaten_ratio_scaled                            0.134146
# iron_eaten_ratio_scaled                               5.826558
# magnesium_eaten_ratio_scaled                          0.762195
# phosphorus_eaten_ratio_scaled                         5.574913
# potassium_eaten_ratio_scaled                          0.700571
# zinc_eaten_ratio_scaled                               6.402439
# fiber_eaten_ratio_scaled                              0.000000
# protein_eaten_ratio_scaled                            6.336161
# fat_eaten_ratio_scaled                                0.797373
# fatty_acids_saturated_eaten_ratio_scaled              0.886918
# cholesterol_eaten_ratio_scaled                       17.357724
# sugar_eaten_ratio_scaled                              0.000000
# sodium_eaten_ratio_scaled                             0.355691
# salt_eaten_ratio_scaled                               0.000000

# %%
food_item = high_qi_meat_fish_seafood[high_qi_meat_fish_seafood['combined_name'] == 'Liver'].iloc[0]
qi_including = food_item['QI']
results = []

for nutr in qualifying_nutrients:
    qi_excluding = compute_qi_excluding(food_item, qualifying_nutrients, exclude=nutr, scaling_factor=2000)
    abs_diff = qi_including - qi_excluding
    pct_diff = (abs_diff / qi_including) * 100
    results.append({
        'Nutrient Excluded': nutr,
        'QI (incl.)': qi_including,
        'QI (excl.)': qi_excluding,
        'Absolute Change': abs_diff,
        'Percent Change': pct_diff
    })


df_results = pd.DataFrame(results)
df_results.sort_values('Absolute Change', ascending=False)
# Out:
#                                Nutrient Excluded  QI (incl.)  QI (excl.)  \
# 7                              vitamin_b12_eaten   31.765218   18.728043
# 5   all_trans_retinol_equivalents_activity_eaten   31.765218   20.691794
# 3                               vitamin_b2_eaten   31.765218   31.744925
# 2                         pantothenic_acid_eaten   31.765218   32.384440
# 1                                   niacin_eaten   31.765218   32.749377
# 8                               vitamin_b6_eaten   31.765218   33.002589
# 0                                   folate_eaten   31.765218   33.035916
# 17                                    zinc_eaten   31.765218   33.100101
# 19                                 protein_eaten   31.765218   33.103589
# 13                                    iron_eaten   31.765218   33.130411
# 15                              phosphorus_eaten   31.765218   33.143655
# 9                                vitamin_c_eaten   31.765218   33.257354
# 4                               vitamin_b1_eaten   31.765218   33.303353
# 14                               magnesium_eaten   31.765218   33.396956
# 16                               potassium_eaten   31.765218   33.400199
# 10                               vitamin_d_eaten   31.765218   33.402840
# 11                      vitamin_e_activity_eaten   31.765218   33.424662
# 12                                 calcium_eaten   31.765218   33.430011
# 6                            beta_carotene_eaten   31.765218   33.437072
# 18                                   fiber_eaten   31.765218   33.437072
#
#     Absolute Change  Percent Change
# 7         13.037175       41.042297
# 5         11.073424       34.860218
# 3          0.020293        0.063883
# 2         -0.619222       -1.949371
# 1         -0.984159       -3.098228
# 8         -1.237371       -3.895366
# 0         -1.270698       -4.000282
# 17        -1.334883       -4.202342
# 19        -1.338371       -4.213324
# 13        -1.365193       -4.297759
# 15        -1.378437       -4.339454
# 9         -1.492136       -4.697389
# 4         -1.538135       -4.842199
# 14        -1.631738       -5.136870
# 16        -1.634981       -5.147081
# 10        -1.637622       -5.155392
# 11        -1.659445       -5.224093
# 12        -1.664793       -5.240931
# 6         -1.671854       -5.263158
# 18        -1.671854       -5.263158

# %% [markdown]
# Same thing, the vitamin b12 and the RAE are the two micronutrients that influence the most the QI value of 'Liver'

# %%
high_qi_meat_fish_seafood[high_qi_meat_fish_seafood['combined_name'] == 'Sushi Nigiri "saumon & thon"'][[i for i in df_meat_fish_seafood.columns if '_ratio_scaled' in i]].T
# Out:
#                                                         294168
# folate_eaten_ratio_scaled                             0.387435
# niacin_eaten_ratio_scaled                             1.323859
# pantothenic_acid_eaten_ratio_scaled                   0.879581
# vitamin_b2_eaten_ratio_scaled                       266.539743
# vitamin_b1_eaten_ratio_scaled                         0.523560
# all_trans_retinol_equivalents_activity_eaten_ra...    0.000000
# beta_carotene_eaten_ratio_scaled                      0.629768
# vitamin_b12_eaten_ratio_scaled                        5.453752
# vitamin_b6_eaten_ratio_scaled                         1.772050
# vitamin_c_eaten_ratio_scaled                          0.273647
# vitamin_d_eaten_ratio_scaled                          1.116928
# vitamin_e_activity_eaten_ratio_scaled                62.129145
# calcium_eaten_ratio_scaled                            0.092147
# iron_eaten_ratio_scaled                               0.098895
# magnesium_eaten_ratio_scaled                          0.425393
# phosphorus_eaten_ratio_scaled                         1.331339
# potassium_eaten_ratio_scaled                          0.334187
# zinc_eaten_ratio_scaled                               0.510471
# fiber_eaten_ratio_scaled                              0.293194
# protein_eaten_ratio_scaled                            1.764170
# fat_eaten_ratio_scaled                                1.020271
# fatty_acids_saturated_eaten_ratio_scaled              0.000000
# cholesterol_eaten_ratio_scaled                        0.663176
# sugar_eaten_ratio_scaled                              0.343455
# sodium_eaten_ratio_scaled                             0.881326
# salt_eaten_ratio_scaled                               0.000000

# %%
food_item = high_qi_meat_fish_seafood[high_qi_meat_fish_seafood['combined_name'] == 'Sushi Nigiri "saumon & thon"'].iloc[0]
qi_including = food_item['QI']
results = []

for nutr in qualifying_nutrients:
    qi_excluding = compute_qi_excluding(food_item, qualifying_nutrients, exclude=nutr, scaling_factor=2000)
    abs_diff = qi_including - qi_excluding
    pct_diff = (abs_diff / qi_including) * 100
    results.append({
        'Nutrient Excluded': nutr,
        'QI (incl.)': qi_including,
        'QI (excl.)': qi_excluding,
        'Absolute Change': abs_diff,
        'Percent Change': pct_diff
    })


df_results = pd.DataFrame(results)
df_results.sort_values('Absolute Change', ascending=False)
# Out:
#                                Nutrient Excluded  QI (incl.)  QI (excl.)  \
# 3                               vitamin_b2_eaten   17.293963    4.175764
# 11                      vitamin_e_activity_eaten   17.293963   14.934217
# 7                              vitamin_b12_eaten   17.293963   17.917132
# 8                               vitamin_b6_eaten   17.293963   18.110906
# 19                                 protein_eaten   17.293963   18.111321
# 15                              phosphorus_eaten   17.293963   18.134101
# 1                                   niacin_eaten   17.293963   18.134495
# 10                               vitamin_d_eaten   17.293963   18.145386
# 2                         pantothenic_acid_eaten   17.293963   18.157878
# 6                            beta_carotene_eaten   17.293963   18.171026
# 4                               vitamin_b1_eaten   17.293963   18.176616
# 17                                    zinc_eaten   17.293963   18.177305
# 14                               magnesium_eaten   17.293963   18.181783
# 0                                   folate_eaten   17.293963   18.183781
# 16                               potassium_eaten   17.293963   18.186583
# 18                                   fiber_eaten   17.293963   18.188741
# 9                                vitamin_c_eaten   17.293963   18.189769
# 13                                    iron_eaten   17.293963   18.198967
# 12                                 calcium_eaten   17.293963   18.199322
# 5   all_trans_retinol_equivalents_activity_eaten   17.293963   18.204172
#
#     Absolute Change  Percent Change
# 3         13.118199       75.854209
# 11         2.359746       13.644914
# 7         -0.623169       -3.603390
# 8         -0.816943       -4.723861
# 19        -0.817358       -4.726259
# 15        -0.840138       -4.857985
# 1         -0.840532       -4.860261
# 10        -0.851423       -4.923238
# 2         -0.863915       -4.995471
# 6         -0.877063       -5.071497
# 4         -0.882653       -5.103820
# 17        -0.883342       -5.107804
# 14        -0.887820       -5.133696
# 0         -0.889817       -5.145248
# 16        -0.892620       -5.161453
# 18        -0.894777       -5.173929
# 9         -0.895806       -5.179877
# 13        -0.905004       -5.233061
# 12        -0.905359       -5.235114
# 5         -0.910209       -5.263158

# %% [markdown]
# Vitamin b2 is the one with the most influence
