# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
from matplotlib.patches import Circle
import os
import pickle
from scipy.stats import mannwhitneyu, ttest_ind, kruskal, f_oneway
from statannotations.Annotator import Annotator
from itertools import combinations
from ipywidgets import interact
import ipywidgets as widgets
from IPython.display import clear_output, display
import sys
sys.path.append('../scripts') 
from functions import *
from config import nutrient_info, conversion_factors

# %%
df_food_scaled = pd.read_csv('../data/df_food_scaled.csv')
# Out:
# C:\Users\Sophie\AppData\Local\Temp\ipykernel_10632\2711278687.py:1: DtypeWarning: Columns (1,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food_scaled = pd.read_csv('../data/df_food_scaled.csv')

# %%
qualifying_nutrients = {nutr: info for nutr, info in nutrient_info.items() if info['type'] == 'qualifying'}
disqualifying_nutrients = {nutr: info for nutr, info in nutrient_info.items() if info['type'] == 'disqualifying'}

# %%
df_sweetened_beverages = df_food_scaled[df_food_scaled['food_group'] == 'sweetened_beverages']
df_sweetened_beverages.drop_duplicates('combined_name')[['combined_name', 'QI', 'DI', 'NB']].sort_values('QI', ascending=False)
# Out:
#                                             combined_name          QI  \
# 301657                                   Coca-Cola Energy  209.000523
# 317152                             Red Bull Zero Calories  185.734636
# 277171                                            OK zero  167.161172
# 310452                                    Denner - E-Zero  167.161172
# 301207                      Monster Energy - Ultra citron  155.209707
# ...                                                   ...         ...
# 316775     Enertea by Rivella - Guayusa, Herbes des Alpes    0.000000
# 316740                            M Budget - Energy Drink    0.000000
# 317676               Vita Malz - Das Original Alkoholfrei    0.000000
# 317694  Nastea Energy - Tea, Guarana (Green apple & pe...    0.000000
# 317773              M-Budget Table water with lemon aroma    0.000000
#
#                DI    NB
# 301657  15.079365  20.0
# 317152   1.851852  20.0
# 277171   7.777778  20.0
# 310452   5.688889  20.0
# 301207   5.555556  20.0
# ...           ...   ...
# 316775   0.571429   0.0
# 316740   0.666667   0.0
# 317676   0.501587   0.0
# 317694   0.634722   0.0
# 317773   0.701389   0.0
#
# [636 rows x 4 columns]

# %%
high_qi_sweetened_beverages = df_sweetened_beverages[df_sweetened_beverages['QI'] > 2].drop_duplicates('combined_name').sort_values('QI', ascending=False)

# %%
high_qi_sweetened_beverages[['combined_name', 'QI', 'DI', 'NB']]
# Out:
#                                           combined_name          QI  \
# 301657                                 Coca-Cola Energy  209.000523
# 317152                           Red Bull Zero Calories  185.734636
# 277171                                          OK zero  167.161172
# 310452                                  Denner - E-Zero  167.161172
# 301207                    Monster Energy - Ultra citron  155.209707
# ...                                                 ...         ...
# 289527                                 Caotina original    2.356001
# 279433                                   Nestle Nesquik    2.194968
# 293541                          Capri-sun multi-vitamin    2.185182
# 308734  original CAOTINA SWISS CHOCOLATE PURE SENSATION    2.091287
# 312293                         Mono - Rei, Vitamin shot    2.041932
#
#                DI         NB
# 301657  15.079365  20.000000
# 317152   1.851852  20.000000
# 277171   7.777778  20.000000
# 310452   5.688889  20.000000
# 301207   5.555556  20.000000
# ...           ...        ...
# 289527   0.707224  72.039811
# 279433   0.478740  59.450531
# 293541   0.762916  71.414942
# 308734   0.705439  52.794233
# 312293   0.650536  11.859903
#
# [75 rows x 4 columns]

# %%
ratio_cols = [i for i in high_qi_sweetened_beverages.columns if '_ratio_scaled' in i]

df_corr = high_qi_sweetened_beverages[ratio_cols + ['QI']]
corr = df_corr.corr()['QI']
corr.sort_values(ascending=True)
# Out:
# sugar_eaten_ratio_scaled                                    -0.298810
# vitamin_e_activity_eaten_ratio_scaled                       -0.177651
# fatty_acids_saturated_eaten_ratio_scaled                    -0.164504
# vitamin_b2_eaten_ratio_scaled                               -0.154554
# vitamin_b1_eaten_ratio_scaled                               -0.144916
# phosphorus_eaten_ratio_scaled                               -0.135109
# calcium_eaten_ratio_scaled                                  -0.133451
# vitamin_c_eaten_ratio_scaled                                -0.130853
# magnesium_eaten_ratio_scaled                                -0.125957
# zinc_eaten_ratio_scaled                                     -0.100206
# folate_eaten_ratio_scaled                                   -0.096320
# beta_carotene_eaten_ratio_scaled                            -0.092900
# potassium_eaten_ratio_scaled                                -0.088669
# iron_eaten_ratio_scaled                                     -0.085730
# fiber_eaten_ratio_scaled                                    -0.077949
# protein_eaten_ratio_scaled                                  -0.064830
# fat_eaten_ratio_scaled                                      -0.056314
# all_trans_retinol_equivalents_activity_eaten_ratio_scaled   -0.049204
# cholesterol_eaten_ratio_scaled                              -0.049204
# vitamin_d_eaten_ratio_scaled                                -0.026505
# salt_eaten_ratio_scaled                                      0.684283
# sodium_eaten_ratio_scaled                                    0.712987
# vitamin_b6_eaten_ratio_scaled                                0.873505
# pantothenic_acid_eaten_ratio_scaled                          0.913290
# vitamin_b12_eaten_ratio_scaled                               0.925897
# niacin_eaten_ratio_scaled                                    0.938268
# QI                                                           1.000000
# Name: QI, dtype: float64

# %%
high_di_sweetened_beverages = df_sweetened_beverages[df_sweetened_beverages['DI'] > 2].drop_duplicates('combined_name').sort_values('DI', ascending=False)

# %%
high_di_sweetened_beverages[['combined_name', 'QI', 'DI', 'NB']]
# Out:
#                                             combined_name          QI  \
# 308540           Bundaberg - Passionfruit sparkling drink    0.000000
# 301657                                   Coca-Cola Energy  209.000523
# 314664                         Capri-sun Mango & Maracuja    0.543478
# 294175                                Sinalco - Cola Zero    3.623188
# 299977                         Munster - Ultra zero sucre  112.161172
# 312075    PowerBar - 5 Electrolytes (mango, passionfruit)    1.797321
# 277171                                            OK zero  167.161172
# 309121              Dame Gingembre - Ginger shot (citron)    0.217391
# 312252                                7Up Free Zero Sugar    0.543478
# 312179                               7Up free, zero sugar    0.543478
# 299921                          MBudget - Drink Sugarfree  111.440781
# 315232         Sponser - Electrolytes, Energy & Endurance    0.000000
# 301598                         Monster - Energy ultra red   56.495726
# 310452                                    Denner - E-Zero  167.161172
# 279640                                      CocaCola Zero    0.000000
# 276267                                   Coca-cola : zero    0.000000
# 278981                                     Coca-Cola zero    0.000000
# 295692                Coca Cola zero sugar, zero caffeine    0.000000
# 274765                                     Coca-Cola Zero    0.000000
# 290849                               Coca Cola zero sugar    0.000000
# 277349                              Coca-Cola zero sugars    0.000000
# 295923                                     Coca Cola Zero    0.000000
# 299168         Migros Sélection - Sirup Erdbeere Hibiskus    0.564984
# 310542                             Coca-Cola - Zéro sucre    0.000000
# 316329                              Coca Cola, Zero sugar    0.000000
# 301207                      Monster Energy - Ultra citron  155.209707
# 281695                                    Coca-Cola Light    0.000000
# 312114                                  Coca-cola : light    0.000000
# 307348                              Coca Cola zero Zucker    0.000000
# 306689                                 You - Ginger water    1.543478
# 308764                   Morand - Sirop (Fleur de Sureau)    0.547598
# 310314  Waterdrop - Microdrink, ZEN (star fruit, lemon...   12.375000
# 299327                                   Pepsi max cherry    0.434783
# 295811                                          Pepsi Max    0.724638
# 306654                                  C.C. lemon (Soda)    0.169179
# 293039        Fusetea (black ice tea, lemon & lemongrass)    2.595657
# 286120                              Coca-Cola, zero sugar    0.000000
# 279913                                    Coca Cola light    0.000000
# 300179  Schützengarten - Grapefruit, Orange & Zitrone,...    1.149344
# 294383  Venga Functional infusions Calorie balance Lem...    1.231154
# 288504                        Fusetea black ice tea peach    2.595657
# 290465                             7Up - Free, grapefruit    1.543478
# 311180                        Ost-Schwuzer - Apfelschorle    0.038820
# 313673                Holderhof - Bio Schrole (Rhabarber)    0.038820
# 316827           Holderhof - Bio Limonade (Holunderblüte)    0.038820
#
#                DI         NB
# 308540  50.093075   0.000000
# 301657  15.079365  20.000000
# 314664  13.077778   5.000000
# 294175  11.613248   5.000000
# 299977   9.722222  20.000000
# 312075   8.477551  10.000000
# 277171   7.777778  20.000000
# 309121   7.764724   5.000000
# 312252   6.944444   5.000000
# 312179   6.944444   5.000000
# 299921   6.481481  20.000000
# 315232   6.299605   0.000000
# 301598   6.296296  15.000000
# 310452   5.688889  20.000000
# 279640   5.625000   0.000000
# 276267   5.625000   0.000000
# 278981   5.625000   0.000000
# 295692   5.625000   0.000000
# 274765   5.625000   0.000000
# 290849   5.625000   0.000000
# 277349   5.625000   0.000000
# 295923   5.625000   0.000000
# 299168   5.562922  41.245894
# 310542   5.555556   0.000000
# 316329   5.555556   0.000000
# 301207   5.555556  20.000000
# 281695   5.555556   0.000000
# 312114   5.555556   0.000000
# 307348   5.555556   0.000000
# 306689   5.522922  10.000000
# 308764   5.420309  40.179560
# 310314   5.000000  10.000000
# 299327   4.977778   5.000000
# 295811   4.629630   5.000000
# 306654   4.538952  13.324161
# 293039   3.888889  26.000000
# 286120   3.750000   0.000000
# 279913   3.750000   0.000000
# 300179   3.503028  10.000000
# 294383   2.854908  29.761905
# 288504   2.222222  26.000000
# 290465   2.055556  10.000000
# 311180   2.005606   3.881988
# 313673   2.005606   3.881988
# 316827   2.005606   3.881988

# %%
ratio_cols = [i for i in high_di_sweetened_beverages.columns if '_ratio_scaled' in i]

df_corr = high_di_sweetened_beverages[ratio_cols + ['DI']]
corr = df_corr.corr()['DI']
corr.sort_values(ascending=True)
# Out:
# salt_eaten_ratio_scaled                                     -0.165700
# phosphorus_eaten_ratio_scaled                               -0.138077
# potassium_eaten_ratio_scaled                                -0.135205
# fiber_eaten_ratio_scaled                                    -0.109745
# folate_eaten_ratio_scaled                                   -0.083073
# vitamin_b2_eaten_ratio_scaled                               -0.061941
# iron_eaten_ratio_scaled                                     -0.046141
# zinc_eaten_ratio_scaled                                     -0.038907
# vitamin_e_activity_eaten_ratio_scaled                       -0.038907
# vitamin_b1_eaten_ratio_scaled                               -0.038907
# vitamin_c_eaten_ratio_scaled                                -0.038828
# magnesium_eaten_ratio_scaled                                -0.017046
# vitamin_b6_eaten_ratio_scaled                                0.024397
# calcium_eaten_ratio_scaled                                   0.033144
# niacin_eaten_ratio_scaled                                    0.061415
# protein_eaten_ratio_scaled                                   0.065058
# pantothenic_acid_eaten_ratio_scaled                          0.131288
# vitamin_b12_eaten_ratio_scaled                               0.150621
# sodium_eaten_ratio_scaled                                    0.150862
# fat_eaten_ratio_scaled                                       0.564438
# fatty_acids_saturated_eaten_ratio_scaled                     0.861782
# sugar_eaten_ratio_scaled                                     0.889292
# DI                                                           1.000000
# all_trans_retinol_equivalents_activity_eaten_ratio_scaled         NaN
# beta_carotene_eaten_ratio_scaled                                  NaN
# vitamin_d_eaten_ratio_scaled                                      NaN
# cholesterol_eaten_ratio_scaled                                    NaN
# Name: DI, dtype: float64

# %%
def interactive_exclude_nutrient(nutrient):
    clear_output(wait=True)
    df_plot = compare_qi_excluding_nutrient(
        df=high_qi_sweetened_beverages, 
        nutrient_to_exclude=nutrient,
        qualifying_nutrients=qualifying_nutrients, 
        scaling_factor=2000
    )

    display(df_plot[['combined_name', 'QI', f"QI_excl_{nutrient}", 'QI_diff', 'QI_pct_change']])

    print(f"\nExcluding {nutrient} for NB:")
    df_nb = compare_nb_excluding_nutrient(
        df=high_qi_sweetened_beverages, 
        nutrient_to_exclude=nutrient,
        qualifying_nutrients=qualifying_nutrients, 
        scaling_factor=2000
    )
    display(df_nb[['combined_name', 'NB', f"NB_excl_{nutrient}", 'NB_diff', 'NB_pct_change']])
    df_di = compare_di_excluding_nutrient(
    df= high_di_sweetened_beverages, 
    nutrient_to_exclude=nutrient,
    disqualifying_nutrients=disqualifying_nutrients,  # make sure this list is defined
    scaling_factor=2000
    )
    display(df_di[['combined_name', 'DI', f"DI_excl_{nutrient}", 'DI_diff', 'DI_pct_change']])

nutrient_choice = ['folate_eaten', 
                   'niacin_eaten', 
                   'pantothenic_acid_eaten', 
                   'vitamin_b2_eaten', 
                   'vitamin_b1_eaten', 
                   'all_trans_retinol_equivalents_activity_eaten', 
                   'beta_carotene_eaten', 
                   'vitamin_b12_eaten', 
                   'vitamin_b6_eaten', 
                   'vitamin_c_eaten', 
                   'vitamin_d_eaten', 
                   'vitamin_e_activity_eaten', 
                   'calcium_eaten', 
                   'iron_eaten', 
                   'magnesium_eaten', 
                   'phosphorus_eaten', 
                   'potassium_eaten', 
                   'zinc_eaten', 
                   'fiber_eaten', 
                   'protein_eaten',
                   'fat_eaten',
                   'fatty_acids_saturated_eaten',
                   'cholesterol_eaten',
                   'sugar_eaten',
                   'sodium_eaten',
                   'salt_eaten'
                   ]

# %%
interact(interactive_exclude_nutrient, nutrient=widgets.Dropdown(options=nutrient_choice, description='Exclude:'))
# Out:
# interactive(children=(Dropdown(description='Exclude:', options=('folate_eaten', 'niacin_eaten', 'pantothenic_a…
# <function __main__.interactive_exclude_nutrient(nutrient)>
