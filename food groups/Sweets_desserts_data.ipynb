# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
from matplotlib.patches import Circle
import os
import pickle
from scipy.stats import mannwhitneyu, ttest_ind, kruskal, f_oneway
from statannotations.Annotator import Annotator
from itertools import combinations
from ipywidgets import interact
import ipywidgets as widgets
from IPython.display import clear_output, display
import sys
sys.path.append('../scripts') 
from functions import *
from config import nutrient_info, conversion_factors

# %%
df_food_scaled = pd.read_csv('../data/df_food_scaled.csv')
# Out:
# C:\Users\Sophie\AppData\Local\Temp\ipykernel_2316\2711278687.py:1: DtypeWarning: Columns (1,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food_scaled = pd.read_csv('../data/df_food_scaled.csv')

# %%
qualifying_nutrients = {nutr: info for nutr, info in nutrient_info.items() if info['type'] == 'qualifying'}
disqualifying_nutrients = {nutr: info for nutr, info in nutrient_info.items() if info['type'] == 'disqualifying'}

# %%
df_sweets_desserts = df_food_scaled[df_food_scaled['food_group'] == 'sweets_desserts']
df_sweets_desserts.drop_duplicates('combined_name')[['combined_name', 'QI', 'DI', 'NB']].sort_values('QI', ascending=False)
# Out:
#                                             combined_name          QI  \
# 310392                          Flying powder (Sugarfree)  111.440781
# 294423  Gerblé - Preparation without added sugars (str...  101.135828
# 298382                                        Yogos honey   35.602400
# 303176                                   Yogos with Honey   35.589892
# 297359             Excellence - Linzentorte, extra cremig   35.353995
# ...                                                   ...         ...
# 316815                 Biscotto - Butter Karamell Waffeln    0.000000
# 312364                       MClassic - Biscuits Japonais    0.000000
# 312764                      Frey - Duett Noir & Lait café    0.000000
# 311979                 Ricolas - Bonbons (Citron Mélisse)    0.000000
# 317493  Pulsaar Nutrition - Nut Baar, blueberry, choco...    0.000000
#
#               DI         NB
# 310392  0.000000  20.000000
# 294423  0.134211  48.624207
# 298382  1.172000  54.136598
# 303176  1.172000  53.603543
# 297359  1.096179  54.098106
# ...          ...        ...
# 316815  0.000000   0.000000
# 312364  0.899636   0.000000
# 312764  0.000000   0.000000
# 311979  0.000000   0.000000
# 317493  0.495641   0.000000
#
# [2191 rows x 4 columns]

# %%
high_qi_sweets_desserts = df_sweets_desserts[df_sweets_desserts['QI'] > 1.5].drop_duplicates('combined_name').sort_values('QI', ascending=False)

# %%
high_qi_sweets_desserts[['combined_name', 'eaten_quantity', 'QI', 'DI', 'NB']]
# Out:
#                                             combined_name  eaten_quantity  \
# 310392                          Flying powder (Sugarfree)             2.5
# 294423  Gerblé - Preparation without added sugars (str...            20.0
# 298382                                        Yogos honey           180.0
# 303176                                   Yogos with Honey            20.0
# 297359             Excellence - Linzentorte, extra cremig           150.0
# 290122                                          Yogos fig           180.0
# 272310                        Biscuit tile, crisp (sweet)            10.0
# 269882                                     Apple turnover            50.0
# 259975                                         Cheesecake           120.0
# 293430                      Excellence - Kirsche mit Rahm           150.0
# 267361                          Ofenchüecheli, Windbeutel            96.0
# 269320                                           Calisson             8.0
# 262211                                      Apple crumble           100.0
# 259786                                   Chocolate mousse            40.0
# 268666      Mousse cake (strawberry, rasberry, chocolate)           100.0
# 302488                                kolid - Rol baklava            20.0
# 260401                                            Baklava            30.0
# 266863      Palme, Schweinsohren (Gebäck aus Blätterteig)            90.0
# 304119                                 Bjorg - Le Palmier            40.0
# 315768  nimm2 - Filled orange and lemon candies with v...             6.0
# 297298                                      Denner - Mint             2.0
# 295697        Isostar - Fruit Gel Energy, Acti FOOD Apple            35.0
# 306408                                         Blue Break             2.0
# 292485                                          Ovo Sport            15.0
# 317760                                           ovosport            15.0
# 297660                          Actilife - Wellness Crisp            45.0
# %%
ratio_cols = [i for i in high_qi_sweets_desserts.columns if '_ratio_scaled' in i]

df_corr = high_qi_sweets_desserts[ratio_cols + ['QI']]
corr = df_corr.corr()['QI']
corr.sort_values(ascending=True)
# Out:
# sodium_eaten_ratio_scaled                                   -0.260063
# magnesium_eaten_ratio_scaled                                -0.234277
# salt_eaten_ratio_scaled                                     -0.195274
# potassium_eaten_ratio_scaled                                -0.190826
# phosphorus_eaten_ratio_scaled                               -0.189720
# sugar_eaten_ratio_scaled                                    -0.189600
# vitamin_d_eaten_ratio_scaled                                -0.185815
# all_trans_retinol_equivalents_activity_eaten_ratio_scaled   -0.181797
# protein_eaten_ratio_scaled                                  -0.170561
# vitamin_e_activity_eaten_ratio_scaled                       -0.151219
# vitamin_c_eaten_ratio_scaled                                -0.140635
# beta_carotene_eaten_ratio_scaled                            -0.133036
# iron_eaten_ratio_scaled                                     -0.123387
# folate_eaten_ratio_scaled                                   -0.108434
# calcium_eaten_ratio_scaled                                  -0.090904
# fat_eaten_ratio_scaled                                      -0.078510
# fatty_acids_saturated_eaten_ratio_scaled                    -0.030688
# cholesterol_eaten_ratio_scaled                               0.025708
# fiber_eaten_ratio_scaled                                     0.114089
# vitamin_b2_eaten_ratio_scaled                                0.508717
# vitamin_b1_eaten_ratio_scaled                                0.557095
# zinc_eaten_ratio_scaled                                      0.562455
# niacin_eaten_ratio_scaled                                    0.620845
# vitamin_b12_eaten_ratio_scaled                               0.647360
# pantothenic_acid_eaten_ratio_scaled                          0.855755
# vitamin_b6_eaten_ratio_scaled                                0.875316
# QI                                                           1.000000
# Name: QI, dtype: float64

# %%
def interactive_exclude_nutrient(nutrient):
    clear_output(wait=True)
    df_plot = compare_qi_excluding_nutrient(
        df=high_qi_sweets_desserts, 
        nutrient_to_exclude=nutrient,
        qualifying_nutrients=qualifying_nutrients, 
        scaling_factor=2000
    )

    display(df_plot[['combined_name', 'QI', f"QI_excl_{nutrient}", 'QI_diff', 'QI_pct_change']])

    print(f"\nExcluding {nutrient} for NB:")
    df_nb = compare_nb_excluding_nutrient(
        df=high_qi_sweets_desserts, 
        nutrient_to_exclude=nutrient,
        qualifying_nutrients=qualifying_nutrients, 
        scaling_factor=2000
    )
    display(df_nb[['combined_name', 'NB', f"NB_excl_{nutrient}", 'NB_diff', 'NB_pct_change']])

nutrient_choice = ['folate_eaten', 
                   'niacin_eaten', 
                   'pantothenic_acid_eaten', 
                   'vitamin_b2_eaten', 
                   'vitamin_b1_eaten', 
                   'all_trans_retinol_equivalents_activity_eaten', 
                   'beta_carotene_eaten', 
                   'vitamin_b12_eaten', 
                   'vitamin_b6_eaten', 
                   'vitamin_c_eaten', 
                   'vitamin_d_eaten', 
                   'vitamin_e_activity_eaten', 
                   'calcium_eaten', 
                   'iron_eaten', 
                   'magnesium_eaten', 
                   'phosphorus_eaten', 
                   'potassium_eaten', 
                   'zinc_eaten', 
                   'fiber_eaten', 
                   'protein_eaten']

# %%
interact(interactive_exclude_nutrient, nutrient=widgets.Dropdown(options=nutrient_choice, description='Exclude:'))
# Out:
# interactive(children=(Dropdown(description='Exclude:', options=('folate_eaten', 'niacin_eaten', 'pantothenic_a…
# <function __main__.interactive_exclude_nutrient(nutrient)>

# %% [markdown]
# - niacin
# - pantothenic acid
# - vitamin b2
# - vitamin b1
# - vitamin b12
# - vitamin b6
# - phosphorus
