# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
from matplotlib.patches import Circle
import os
import pickle
from scipy.stats import mannwhitneyu, ttest_ind, kruskal, f_oneway
from statannotations.Annotator import Annotator
from itertools import combinations
from ipywidgets import interact
import ipywidgets as widgets
from IPython.display import clear_output, display

# %%
df_food_scaled = pd.read_csv('df_food_scaled.csv')
# Out:
# C:\Users\Sophie\AppData\Local\Temp\ipykernel_11976\4074791732.py:1: DtypeWarning: Columns (1,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food_scaled = pd.read_csv('df_food_scaled.csv')

# %%
df_cooked_grains_pasta = df_food_scaled[df_food_scaled['food_group'] == 'cooked_grains_pasta']
df_cooked_grains_pasta.drop_duplicates('combined_name')[['combined_name', 'QI', 'DI', 'NB']].sort_values('QI', ascending=False)
# Out:
#                                             combined_name        QI        DI  \
# 300661                  Glutenfrei Lasagne ohne Vorkochen  4.236493  0.067197
# 292652  Frischeierteigwaren gefüllt mit Ricotta und Sp...  1.577592  1.256721
# 299384          Giovanni Rana - Tortellini Roher Schinken  1.340350  1.758965
# 293899   Coop Karma - Red lentil Fusilli aus Roten Linsen  0.557352  0.223783
# 300822                       Uncle Ben's EXPRESS VOLLREIS  0.547306  0.693927
# 115650                               Pearl barley, cooked  0.489439  0.809906
# 305944                      M Classic Macaroni of the Alp  0.459412  0.319941
# 299544   coop naturaplan Betty Bossi Tagliatelle blanched  0.309639  0.488322
# 283008                   Barilla - Casarecce Kichererbsen  0.292104  0.147849
# 281904  M Budget Feather beaks Pasta with durum wheat ...  0.283693  0.236150
# 282231      M-Classic Egg Pasta with Durum Wheat Semolina  0.264233  0.318398
# ...

# %%
df_cooked_grains_pasta[df_cooked_grains_pasta['combined_name'] == 'Glutenfrei Lasagne ohne Vorkochen'].drop_duplicates('combined_name')[[i for i in df_cooked_grains_pasta.columns if '_ratio_scaled' in i]].T
# Out:
#                                                        300661
# folate_eaten_ratio_scaled                            0.176880
# niacin_eaten_ratio_scaled                            0.059690
# pantothenic_acid_eaten_ratio_scaled                  0.189415
# vitamin_b2_eaten_ratio_scaled                        0.000000
# vitamin_b1_eaten_ratio_scaled                        0.185701
# all_trans_retinol_equivalents_activity_eaten_ra...   0.000000
# beta_carotene_eaten_ratio_scaled                     0.000000
# vitamin_b12_eaten_ratio_scaled                       0.208914
# vitamin_b6_eaten_ratio_scaled                       81.422756
# vitamin_c_eaten_ratio_scaled                         0.000000
# vitamin_d_eaten_ratio_scaled                         0.000000
# vitamin_e_activity_eaten_ratio_scaled                0.000000
# calcium_eaten_ratio_scaled                           0.053482
# iron_eaten_ratio_scaled                              0.148561
# ...

# %% [markdown]
# - vitamin b6
