# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
from matplotlib.patches import Circle
import os
import pickle
from scipy.stats import mannwhitneyu, ttest_ind, kruskal, f_oneway
from statannotations.Annotator import Annotator
from itertools import combinations
from ipywidgets import interact
import ipywidgets as widgets
from IPython.display import clear_output, display

# %%
df_food_scaled = pd.read_csv('../data/df_food_scaled.csv')
# Out:
# C:\Users\Sophie\AppData\Local\Temp\ipykernel_4152\3668861322.py:1: DtypeWarning: Columns (1,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food_scaled = pd.read_csv('../data/df_food_scaled.csv')

# %%
df_soy_granules_textured_protein = df_food_scaled[df_food_scaled['food_group'] == 'soy_granules_textured_protein']
df_soy_granules_textured_protein.drop_duplicates('combined_name')[['combined_name', 'QI', 'DI', 'NB']].sort_values('QI', ascending=False)
# Out:
#                                             combined_name        QI        DI  \
# 305771  New Roots - Free the cow, spread (garlic and f...  1.534240  1.500968
# 313945                               Coop Délicorn Ground  1.395668  0.984468
# 303539   Alnatura Bio Soja Schnetzel grob rein pflanzlich  1.085834  0.129981
# 312877                           planted.chicken (nature)  0.997519  0.436613
# 317369         Planted. - Chicken Curry, 100% plant-based  0.790720  0.942333
# ...                                                   ...       ...       ...
# 311492                 Veganz - Vegan cold cuts (peppers)  0.098814  1.209454
# 313448               Next level meat - Next level nuggets  0.078595  0.679735
# 307195  New roots - Fresh cheese alternative, artisan ...  0.072288  0.670082
# 317252     Simply V - Cremig Milder Streichgenuss (Vegan)  0.042533  1.545541
# 312432                 Planted. - Wie Poulet (Cheeky BBQ)  0.000000  0.200244
#
#                NB
# ...
