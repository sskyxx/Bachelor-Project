# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
from matplotlib.patches import Circle
import os
import pickle
from scipy.stats import mannwhitneyu, ttest_ind, kruskal, f_oneway
from statannotations.Annotator import Annotator
from itertools import combinations
from ipywidgets import interact
import ipywidgets as widgets
from IPython.display import clear_output, display
import sys
sys.path.append('../scripts') 
from functions import *
from config import nutrient_info, conversion_factors

# %%
df_food_scaled = pd.read_csv('../data/df_food_scaled.csv')
# Out:
# C:\Users\Sophie\AppData\Local\Temp\ipykernel_16056\2711278687.py:1: DtypeWarning: Columns (1,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food_scaled = pd.read_csv('../data/df_food_scaled.csv')

# %%
qualifying_nutrients = {nutr: info for nutr, info in nutrient_info.items() if info['type'] == 'qualifying'}
disqualifying_nutrients = {nutr: info for nutr, info in nutrient_info.items() if info['type'] == 'disqualifying'}

# %%
df_processed_foods = df_food_scaled[df_food_scaled['food_group'] == 'processed_foods']
df_processed_foods.drop_duplicates('combined_name')[['combined_name', 'QI', 'DI', 'NB']].sort_values('QI', ascending=False)
# Out:
#                                             combined_name          QI  \
# 290599                       MClassic - Saladbowl Chicken  254.631479
# 291464  Betty Bossi - Chicken Caesar Salad (& caesar d...  147.293505
# 261242  Chicken caesar salad (green salad, cheese, cro...  143.393908
# 256693                                        Bami goreng   86.332573
# 297433                                      Tandoori Wrap   64.399538
# ...                                                   ...         ...
# 299379  Migros Daily - Salatschale gemischt mit Balsam...    0.007489
# 316141              Migros V-Love - Plant-based Schnitzel    0.000000
# 316159                      Pierre Baguette - Wrap Caesar    0.000000
# 310824                            Nissin Demae Ramen Beef    0.000000
# 316551                        M Classic - Älpler-Magronen    0.000000
#
#               DI         NB
# 290599  1.645896  85.009150
# 291464  1.478695  78.709698
# 261242  1.126360  80.829971
# 256693  1.083334  72.360804
# 297433  1.224223  71.323872
# ...          ...        ...
# 299379  0.985452   0.748878
# 316141  0.000000   0.000000
# 316159  0.000000   0.000000
# 310824  0.330351   0.000000
# 316551  0.000000   0.000000
#
# [838 rows x 4 columns]

# %%
high_qi_processed_foods = df_processed_foods[df_processed_foods['QI'] > 2].drop_duplicates('combined_name').sort_values('QI', ascending=False)

# %%
high_qi_processed_foods[['combined_name', 'eaten_quantity', 'QI', 'DI', 'NB']]
# Out:
#                                             combined_name  eaten_quantity  \
# 290599                       MClassic - Saladbowl Chicken         250.000
# 291464  Betty Bossi - Chicken Caesar Salad (& caesar d...         260.000
# 261242  Chicken caesar salad (green salad, cheese, cro...         200.000
# 256693                                        Bami goreng         400.000
# 297433                                      Tandoori Wrap         190.000
# 294058                         COOP Spicy Chicken Avocado         235.000
# 301176      migrolino - Avocado & Kalbsspeck Chicken Wrap         200.000
# 281830                           Chicken Ketchup Sandwich         215.000
# 281347                            Chicken Crispy Sandwich         230.000
# 290384        Coop, Betty Bossi - Sandwich Poulet tartare         235.000
# 269244  Sandwich, chicken (raw vegetable, tomato, sala...         250.000
# 307982                    Baguettine maïs poulet exotique         130.000
# 258309                                             Paella         250.000
# 282671                 Coop Betty Bossi - Poulet Cocktail         220.000
# 288097                                coop Chicken Caesar         200.000
# 266234                                     Vegetable flan         125.000
# 284981          Coop Naturaplan Bio - Rüeblisalat (Vegan)         160.000
# 266428  Chicken curry (cream/coconut milk. curry spice...         140.000
# 297043                       Migros - Sushi Salmon Masago         165.000
# 292436                               Naturaplan Bio sushi         250.000
# 298861                   Sushis vegan no fish - 15 pieces         313.000
# 303443                           Sushi wrap smoked salmon         350.000
# 277188  Coop Betty Bossi - Chicken Tikka Masala mit Ba...         400.000
# 296390               Onigiri Zenbu - Spinach and shiitake         110.000
# 297044                            Migros - Sushi Maki Mix         200.000
# 257611                                              Sushi         180.000
# 310292                                       Sushi Nigiri         240.000
# 299691             Anna's best - Salade bowl farmer style         180.000
# 305742                                    Sandwich salmon         240.000
# 288554                         Zenbu - Onigiri Spicy tuna         110.000
# 316612                                 Carpaccio de boeuf           0.102
# 304174                  Fait Maison - Carpaccio de poulpe         112.000
# 299410                      Betty Bossi Vegi sticks & dip         150.000
# 306091                                 Power salad Linsen         300.000
# 17537                                         Ratatouille         120.000
# 304044                                   Russischer Salat         100.000
# 301556                         Coop Bordelaise Baked fish         120.000
# 306137           Coop Fait maison - Bowl salade de saumon         180.000
# 8351         Quiche, with spinach, baked, with cake dough          70.000
# 281945              Farmer's Best Spicy Ratatouille Mixes         150.000
# 8476        Quiche, with spinach, baked, with puff pastry         120.000
# 296578         Betty Bossi - Mâche salad & House dressing         190.000
# 5640                   Egg, scrambled, with ham, prepared         250.000
# 5597                Egg, scrambled, with cheese, prepared         136.000
# 8672                    Beef ragout, with sauce, prepared         250.000
# 289682                           Migros Bio - Linsensalat         200.000
# 298059                    Alnatura - Bratlinge mediterran          87.500
# 274571                         Vegetable au gratin, baked         200.000
# 8647                    Lamb ragout, with sauce, prepared         120.000
# 308739             coop naturaplan Plätzli mit Spinat bio         180.000
# 144154                                              Patty          60.000
# 119896              Pasta, tortelloni, vegetable stuffing         160.000
# 295577                               MIGROS Salmon tartar         180.000
# 278715                          M Classic Chili with meat         430.000
# 8738                    Pork ragout, with sauce, prepared         200.000
#
#                 QI         DI         NB
# 290599  254.631479   1.645896  85.009150
# 291464  147.293505   1.478695  78.709698
# 261242  143.393908   1.126360  80.829971
# 256693   86.332573   1.083334  72.360804
# 297433   64.399538   1.224223  71.323872
# 294058   63.639363   1.244381  70.529591
# 301176   57.342590   1.231895  67.389236
# 281830   51.153458   1.023575  62.918973
# 281347   47.803951   1.105742  61.095693
# 290384   44.197996   1.070280  59.971490
# 269244   42.917946   0.672460  59.239724
# 307982   42.917946   0.672460  59.239724
# 258309   42.599565   0.787205  77.265047
# 282671   40.548636   0.956261  57.625859
# 288097   32.093522   0.971304  51.121824
# 266234   30.849914   2.481927  68.959993
# 284981   28.327363   0.731399  80.790109
# 266428   23.133060   1.452577  71.087165
# 297043   22.774807   1.215756  67.952450
# 292436   22.161030   1.356121  67.888551
# 298861   20.980305   1.133819  66.553980
# 303443   20.099597   1.019840  65.537227
# 277188   18.825940   1.412344  65.393477
# 296390   18.128352   0.660648  65.517540
# 297044   17.293963   0.484705  62.241389
# 257611   17.293963   0.484705  62.241389
# 310292   17.293963   0.484705  62.241389
# 299691   17.187527   0.417521  85.000000
# 305742   16.333035   0.702573  61.426264
# 288554   15.295266   0.626517  61.457278
# 316612   15.217391  21.168091   5.000000
# 304174   12.093442   1.193991  81.319930
# 299410    4.684958   0.843915  55.415293
# 306091    4.496858   0.544199  85.052632
# 17537     4.355484   1.620089  84.583333
# 304044    4.278647   1.559904  98.362573
# 301556    3.919717   1.341602  79.081365
# 306137    3.319293   2.086387  64.640719
# 8351      3.294457   1.419167  95.260637
# 281945    3.210203   1.554814  82.230769
# 8476      3.129374   1.538136  93.879706
# 296578    3.123942   0.952614  56.413501
# 5640      3.007359   3.682127  76.258987
# 5597      2.893992   3.720559  66.894750
# 8672      2.783396   1.107407  68.517156
# 289682    2.759388   0.685142  77.398268
# 298059    2.686034   2.789252  76.008170
# 274571    2.634672   1.295495  92.630187
# 8647      2.558935   1.291487  62.700435
# 308739    2.417053   1.353547  82.688777
# 144154    2.364214   0.835238  56.108389
# 119896    2.322210   1.715616  84.707561
# 295577    2.319845   2.389467  61.500386
# 278715    2.303934   1.446780  91.207283
# 8738      2.183452   1.156192  65.620422

# %%
ratio_cols = [i for i in high_qi_processed_foods.columns if '_ratio_scaled' in i]

df_corr = high_qi_processed_foods[ratio_cols + ['QI']]
corr = df_corr.corr()['QI']
corr.sort_values(ascending=True)
# Out:
# vitamin_d_eaten_ratio_scaled                                -0.246694
# all_trans_retinol_equivalents_activity_eaten_ratio_scaled   -0.238711
# vitamin_c_eaten_ratio_scaled                                -0.186693
# iron_eaten_ratio_scaled                                     -0.174035
# zinc_eaten_ratio_scaled                                     -0.171968
# pantothenic_acid_eaten_ratio_scaled                         -0.124503
# magnesium_eaten_ratio_scaled                                -0.113676
# vitamin_b12_eaten_ratio_scaled                              -0.097083
# potassium_eaten_ratio_scaled                                -0.096146
# vitamin_e_activity_eaten_ratio_scaled                       -0.082748
# cholesterol_eaten_ratio_scaled                              -0.072221
# salt_eaten_ratio_scaled                                     -0.068826
# fiber_eaten_ratio_scaled                                    -0.064617
# phosphorus_eaten_ratio_scaled                               -0.057383
# protein_eaten_ratio_scaled                                  -0.045098
# sugar_eaten_ratio_scaled                                    -0.038661
# fat_eaten_ratio_scaled                                      -0.036742
# folate_eaten_ratio_scaled                                   -0.028073
# fatty_acids_saturated_eaten_ratio_scaled                    -0.023123
# beta_carotene_eaten_ratio_scaled                            -0.020840
# niacin_eaten_ratio_scaled                                    0.035596
# sodium_eaten_ratio_scaled                                    0.048450
# calcium_eaten_ratio_scaled                                   0.179435
# vitamin_b2_eaten_ratio_scaled                                0.852263
# vitamin_b6_eaten_ratio_scaled                                0.887987
# vitamin_b1_eaten_ratio_scaled                                0.948325
# QI                                                           1.000000
# Name: QI, dtype: float64

# %%
def interactive_exclude_nutrient(nutrient):
    clear_output(wait=True)
    df_plot = compare_qi_excluding_nutrient(
        df=high_qi_processed_foods, 
        nutrient_to_exclude=nutrient,
        qualifying_nutrients=qualifying_nutrients, 
        scaling_factor=2000
    )

    display(df_plot[['combined_name', 'QI', f"QI_excl_{nutrient}", 'QI_diff', 'QI_pct_change']])

    print(f"\nExcluding {nutrient} for NB:")
    df_nb = compare_nb_excluding_nutrient(
        df=high_qi_processed_foods, 
        nutrient_to_exclude=nutrient,
        qualifying_nutrients=qualifying_nutrients, 
        scaling_factor=2000
    )
    display(df_nb[['combined_name', 'NB', f"NB_excl_{nutrient}", 'NB_diff', 'NB_pct_change']])

nutrient_choice = ['folate_eaten', 
                   'niacin_eaten', 
                   'pantothenic_acid_eaten', 
                   'vitamin_b2_eaten', 
                   'vitamin_b1_eaten', 
                   'all_trans_retinol_equivalents_activity_eaten', 
                   'beta_carotene_eaten', 
                   'vitamin_b12_eaten', 
                   'vitamin_b6_eaten', 
                   'vitamin_c_eaten', 
                   'vitamin_d_eaten', 
                   'vitamin_e_activity_eaten', 
                   'calcium_eaten', 
                   'iron_eaten', 
                   'magnesium_eaten', 
                   'phosphorus_eaten', 
                   'potassium_eaten', 
                   'zinc_eaten', 
                   'fiber_eaten', 
                   'protein_eaten']

# %%
interact(interactive_exclude_nutrient, nutrient=widgets.Dropdown(options=nutrient_choice, description='Exclude:'))
# Out:
# interactive(children=(Dropdown(description='Exclude:', options=('folate_eaten', 'niacin_eaten', 'pantothenic_a…
# <function __main__.interactive_exclude_nutrient(nutrient)>

# %% [markdown]
# - vitamin b2
# - vitamin b1
# - vitamin b6

# %%
exclude_list = ['vitamin_b1_eaten', 'vitamin_b6_eaten', 'vitamin_b2_eaten']
qualifying_nutrients = list(nutrient_info.keys())

for idx, row in high_qi_processed_foods.iterrows():

    qi_incl = compute_qi_excluding_multiple(row, qualifying_nutrients, exclude_list=[])
    qi_excl = compute_qi_excluding_multiple(row, qualifying_nutrients, exclude_list=exclude_list)

    nb_incl = compute_nb_excluding_multiple(row, qualifying_nutrients, exclude_list=[]) 
    nb_excl = compute_nb_excluding_multiple(row, qualifying_nutrients, exclude_list=exclude_list)

    print(f"Food item : {row['combined_name']}")
    print(f"QI (incl. all): {qi_incl}")
    print(f"QI (excl. {', '.join(exclude_list)}): {qi_excl}")
    print(f"NB (incl. all): {nb_incl:.2f}")
    print(f"NB (excl. {', '.join(exclude_list)}): {nb_excl:.2f}")
    print("-----------")
# Out:
# Food item : MClassic - Saladbowl Chicken
# QI (incl. all): 203.25717289336825
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.9624300249514324
# NB (incl. all): 83.70
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 81.47
# -----------
# Food item : Betty Bossi - Chicken Caesar Salad (& caesar dressing)
# QI (incl. all): 117.70222736532166
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.330840233707126
# NB (incl. all): 79.62
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 76.84
# -----------
# Food item : Chicken caesar salad (green salad, cheese, croutons, sauce)
# QI (incl. all): 114.51090197950856
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.2121934740808353
# NB (incl. all): 77.39
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 74.31
# -----------
# Food item : Bami goreng
# QI (incl. all): 68.90442175019095
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.017362260899655
# NB (incl. all): 70.33
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 66.28
# -----------
# Food item : Tandoori Wrap
# QI (incl. all): 51.74374202369936
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.042312724082437
# NB (incl. all): 70.60
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 66.59
# -----------
# Food item : COOP Spicy Chicken Avocado
# QI (incl. all): 51.141197998437484
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.9854013666517566
# NB (incl. all): 72.38
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 68.61
# -----------
# Food item : migrolino - Avocado & Kalbsspeck Chicken Wrap
# QI (incl. all): 46.10763631245752
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.9445702640703779
# NB (incl. all): 71.19
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 67.35
# -----------
# Food item : Chicken Ketchup Sandwich
# QI (incl. all): 41.11302851935422
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.8160941271728567
# NB (incl. all): 63.37
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 58.95
# -----------
# Food item : Chicken Crispy Sandwich
# QI (incl. all): 38.45676064709915
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.7953715960809301
# NB (incl. all): 63.77
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 59.67
# -----------
# Food item : Coop, Betty Bossi - Sandwich Poulet tartare
# QI (incl. all): 35.56739339621004
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.7501501182307828
# NB (incl. all): 62.34
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 58.32
# -----------
# Food item : Sandwich, chicken (raw vegetable, tomato, salad, mayonnaise)
# QI (incl. all): 34.449279638869946
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.6419792665136927
# NB (incl. all): 56.99
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 52.34
# -----------
# Food item : Baguettine maïs poulet exotique
# QI (incl. all): 34.44927963886992
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.6419792665136885
# NB (incl. all): 56.99
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 52.34
# -----------
# Food item : Paella
# QI (incl. all): 34.17205616591325
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.1569852409137373
# NB (incl. all): 72.87
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 69.17
# -----------
# Food item : Coop Betty Bossi - Poulet Cocktail
# QI (incl. all): 32.62451635110541
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.7001454193347753
# NB (incl. all): 59.49
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 55.36
# -----------
# Food item : coop Chicken Caesar
# QI (incl. all): 25.873269888342055
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.6805530821812843
# NB (incl. all): 55.36
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 51.34
# -----------
# Food item : Vegetable flan
# QI (incl. all): 24.226509564240168
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.2360378610813778
# NB (incl. all): 67.62
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 63.87
# -----------
# Food item : Coop Naturaplan Bio - Rüeblisalat (Vegan)
# QI (incl. all): 1.7878019460239623
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.429045747599474
# NB (incl. all): 71.41
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 67.51
# -----------
# Food item : Chicken curry (cream/coconut milk. curry spices/paste))
# QI (incl. all): 18.475343077979787
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.348494042106132
# NB (incl. all): 69.64
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 70.04
# -----------
# Food item : Migros - Sushi Salmon Masago
# QI (incl. all): 18.478444559503
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 4.901821028415648
# NB (incl. all): 67.95
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 64.99
# -----------
# Food item : Naturaplan Bio sushi
# QI (incl. all): 18.02198013155174
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 4.804709870000895
# NB (incl. all): 66.51
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 63.43
# -----------
# Food item : Sushis vegan no fish - 15 pieces
# QI (incl. all): 17.025714285312688
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 4.4812901338448
# NB (incl. all): 70.99
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 68.68
# -----------
# Food item : Sushi wrap smoked salmon
# QI (incl. all): 16.295101246548196
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 4.285577234837909
# NB (incl. all): 67.92
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 65.32
# -----------
# Food item : Coop Betty Bossi - Chicken Tikka Masala mit Basmatireis
# QI (incl. all): 15.089940401719774
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.1204849676026736
# NB (incl. all): 68.99
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 69.30
# -----------
# Food item : Onigiri Zenbu - Spinach and shiitake
# QI (incl. all): 14.634800588457987
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.80639116631653
# NB (incl. all): 63.03
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 60.04
# -----------
# Food item : Migros - Sushi Maki Mix
# QI (incl. all): 13.926309032620415
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.6055623948619813
# NB (incl. all): 58.83
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 55.38
# -----------
# Food item : Sushi
# QI (incl. all): 13.926309032620411
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.605562394861976
# NB (incl. all): 58.83
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 55.38
# -----------
# Food item : Sushi Nigiri
# QI (incl. all): 13.926309032620392
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.605562394861983
# NB (incl. all): 58.83
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 55.38
# -----------
# Food item : Anna's best - Salade bowl farmer style
# QI (incl. all): 4.828004770345605
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 4.516883996816979
# NB (incl. all): 73.04
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 69.37
# -----------
# Food item : Sandwich salmon
# QI (incl. all): 13.211226532661268
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.458402687305829
# NB (incl. all): 61.02
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 58.00
# -----------
# Food item : Zenbu - Onigiri Spicy tuna
# QI (incl. all): 12.364301573872002
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.244881323938622
# NB (incl. all): 61.04
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 58.16
# -----------
# Food item : Carpaccio de boeuf
# QI (incl. all): 17.254254923820138
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 19.60710786797743
# NB (incl. all): 12.00
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 13.64
# -----------
# Food item : Fait Maison - Carpaccio de poulpe
# QI (incl. all): 9.961311257351962
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 10.960353171763064
# NB (incl. all): 75.47
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 74.42
# -----------
# Food item : Betty Bossi Vegi sticks & dip
# QI (incl. all): 2.107187629968896
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.180913148883062
# NB (incl. all): 54.06
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 52.45
# -----------
# Food item : Power salad Linsen
# QI (incl. all): 3.702830657900452
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.5466190278586263
# NB (incl. all): 76.44
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 73.22
# -----------
# Food item : Ratatouille
# QI (incl. all): 2.5755891426899473
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.531352181466732
# NB (incl. all): 81.94
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 79.48
# -----------
# Food item : Russischer Salat
# QI (incl. all): 2.247419965262118
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.0863846604875858
# NB (incl. all): 89.27
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 87.81
# -----------
# Food item : Coop Bordelaise Baked fish
# QI (incl. all): 3.457758372991716
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.559973032365969
# NB (incl. all): 78.68
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 75.77
# -----------
# Food item : Coop Fait maison - Bowl salade de saumon
# QI (incl. all): 3.156167102602205
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.1259680215495536
# NB (incl. all): 67.63
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 63.22
# -----------
# Food item : Quiche, with spinach, baked, with cake dough
# QI (incl. all): 1.3125984084757187
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.2876420703428866
# NB (incl. all): 88.78
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 87.31
# -----------
# Food item : Farmer's Best Spicy Ratatouille Mixes
# QI (incl. all): 1.9830763358892582
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.9614685162384455
# NB (incl. all): 80.52
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 77.86
# -----------
# Food item : Quiche, with spinach, baked, with puff pastry
# QI (incl. all): 1.286776970622866
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.2725401114354724
# NB (incl. all): 87.64
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 86.25
# -----------
# Food item : Betty Bossi - Mâche salad & House dressing
# QI (incl. all): 0.7854140063126414
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.7567984668520452
# NB (incl. all): 53.63
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 50.93
# -----------
# Food item : Egg, scrambled, with ham, prepared
# QI (incl. all): 3.2825526542388657
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.290098808982579
# NB (incl. all): 76.87
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 73.72
# -----------
# Food item : Egg, scrambled, with cheese, prepared
# QI (incl. all): 3.2002208105855323
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.2491803793118166
# NB (incl. all): 69.25
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 65.06
# -----------
# Food item : Beef ragout, with sauce, prepared
# QI (incl. all): 1.4752263565467252
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.488586056520042
# NB (incl. all): 65.32
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 63.47
# -----------
# Food item : Migros Bio - Linsensalat
# QI (incl. all): 2.3567065460419236
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.2792909035356805
# NB (incl. all): 70.96
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 68.53
# -----------
# Food item : Alnatura - Bratlinge mediterran
# QI (incl. all): 2.8182479216854053
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.403094611851361
# NB (incl. all): 78.45
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 75.51
# -----------
# Food item : Vegetable au gratin, baked
# QI (incl. all): 2.396600823184966
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.460939907417104
# NB (incl. all): 89.70
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 88.29
# -----------
# Food item : Lamb ragout, with sauce, prepared
# QI (incl. all): 1.6082081901111285
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.702172707106803
# NB (incl. all): 62.99
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 61.33
# -----------
# Food item : coop naturaplan Plätzli mit Spinat bio
# QI (incl. all): 1.474440732852114
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.463714733051133
# NB (incl. all): 77.57
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 74.51
# -----------
# Food item : Patty
# QI (incl. all): 2.0858523806991633
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.2325457494170937
# NB (incl. all): 55.26
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 55.28
# -----------
# Food item : Pasta, tortelloni, vegetable stuffing
# QI (incl. all): 1.5879723196631064
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.5946541845815394
# NB (incl. all): 84.87
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 82.81
# -----------
# Food item : MIGROS Salmon tartar
# QI (incl. all): 2.429347723799085
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.4319139553289637
# NB (incl. all): 69.36
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 65.18
# -----------
# Food item : M Classic Chili with meat
# QI (incl. all): 1.9658369097602573
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.916727213966352
# NB (incl. all): 88.51
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 86.94
# -----------
# Food item : Pork ragout, with sauce, prepared
# QI (incl. all): 1.2090773120575582
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.0570251885292894
# NB (incl. all): 65.40
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 60.68
# -----------
