# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
from matplotlib.patches import Circle
import os
import pickle
from scipy.stats import mannwhitneyu, ttest_ind, kruskal, f_oneway
from statannotations.Annotator import Annotator
from itertools import combinations
from ipywidgets import interact
import ipywidgets as widgets
from IPython.display import clear_output, display

# %%
df_food_scaled = pd.read_csv('df_food_scaled.csv')
# Out:
# C:\Users\Sophie\AppData\Local\Temp\ipykernel_4200\4074791732.py:1: DtypeWarning: Columns (1,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food_scaled = pd.read_csv('df_food_scaled.csv')

# %%
nutrient_info = {
    'folate_eaten':                                         {'unit': 'mcg', 'target': 400,  'type': 'qualifying'},
    'niacin_eaten':                                         {'unit': 'mg',  'target': 14,   'type': 'qualifying'},
    'pantothenic_acid_eaten':                               {'unit': 'mg',  'target': 5,    'type': 'qualifying'},
    'vitamin_b2_eaten':                                     {'unit': 'mg',  'target': 1.1,  'type': 'qualifying'},
    'vitamin_b1_eaten':                                     {'unit': 'mg',  'target': 1.2,  'type': 'qualifying'},
    'all_trans_retinol_equivalents_activity_eaten':         {'unit': 'IU',  'target': 700,  'type': 'qualifying'},
    'beta_carotene_eaten':                                  {'unit' : 'mcg','target' : 700, 'type' :'qualifying'},
    'vitamin_b12_eaten':                                    {'unit': 'mcg', 'target': 2.4,  'type': 'qualifying'},
    'vitamin_b6_eaten':                                     {'unit': 'mg',  'target': 1.3,  'type': 'qualifying'},
    'vitamin_c_eaten':                                      {'unit': 'mg',  'target': 75,   'type': 'qualifying'},
    'vitamin_d_eaten':                                      {'unit': 'mcg', 'target': 7.5,  'type': 'qualifying'},
    'vitamin_e_activity_eaten':                             {'unit': 'TAE', 'target': 15,    'type': 'qualifying'},
    'calcium_eaten':                                        {'unit': 'mg',  'target': 1000, 'type': 'qualifying'},
    'iron_eaten':                                           {'unit': 'mg',  'target': 18,   'type': 'qualifying'},
    'magnesium_eaten':                                      {'unit': 'mg',  'target': 320,  'type': 'qualifying'},
    'phosphorus_eaten':                                     {'unit': 'mg',  'target': 700,  'type': 'qualifying'},
    'potassium_eaten':                                      {'unit': 'mg',  'target': 4700, 'type': 'qualifying'},
    'zinc_eaten':                                           {'unit': 'mg',  'target': 8,    'type': 'qualifying'},
    'fiber_eaten':                                          {'unit': 'g',   'target': 25,   'type': 'qualifying'},
    'protein_eaten':                                        {'unit': 'g',   'target': 46,   'type': 'qualifying'},
    'fat_eaten':                                            {'unit': 'g',   'target': 78,   'type': 'disqualifying'},
    'fatty_acids_saturated_eaten':                          {'unit': 'g',   'target': 22,   'type': 'disqualifying'},
    'cholesterol_eaten':                                    {'unit': 'mg',  'target': 300,  'type': 'disqualifying'},
    'sugar_eaten':                                          {'unit': 'g',   'target': 125,  'type': 'disqualifying'},
    'sodium_eaten':                                         {'unit': 'mg',  'target': 2400, 'type': 'disqualifying'},
    'salt_eaten' :                                          {'unit' : 'g',  'target': 6,   'type': 'disqualifying'}
}


conversion_factors = {
    "mg": 1000,
    "g": 1,
    "mcg": 1000000,
    "IU": 1,
    "TAE": 1,
}

# %%
qualifying_nutrients = {nutr: info for nutr, info in nutrient_info.items() if info['type'] == 'qualifying'}
disqualifying_nutrients = {nutr: info for nutr, info in nutrient_info.items() if info['type'] == 'disqualifying'}

# %%
df_processed_foods = df_food_scaled[df_food_scaled['food_group'] == 'processed_foods']
df_processed_foods.drop_duplicates('combined_name')[['combined_name', 'QI', 'DI', 'NB']].sort_values('QI', ascending=False)
# Out:
#                                             combined_name          QI  \
# 290599                       MClassic - Saladbowl Chicken  254.631479
# 291464  Betty Bossi - Chicken Caesar Salad (& caesar d...  147.293505
# 261242  Chicken caesar salad (green salad, cheese, cro...  143.393908
# 256693                                        Bami goreng   86.332573
# 297433                                      Tandoori Wrap   64.399538
# ...                                                   ...         ...
# 299379  Migros Daily - Salatschale gemischt mit Balsam...    0.007489
# 316141              Migros V-Love - Plant-based Schnitzel    0.000000
# 316159                      Pierre Baguette - Wrap Caesar    0.000000
# 310824                            Nissin Demae Ramen Beef    0.000000
# 316551                        M Classic - Älpler-Magronen    0.000000
#
#               DI         NB
# 290599  1.645896  85.009150
# 291464  1.478695  78.709698
# 261242  1.126360  80.829971
# 256693  1.083334  72.360804
# 297433  1.224223  71.323872
# ...          ...        ...
# 299379  0.985452   0.748878
# 316141  0.000000   0.000000
# 316159  0.000000   0.000000
# 310824  0.330351   0.000000
# 316551  0.000000   0.000000
#
# [838 rows x 4 columns]

# %%
high_qi_processed_foods = df_processed_foods[df_processed_foods['QI'] > 2].drop_duplicates('combined_name').sort_values('QI', ascending=False)

# %%
high_qi_processed_foods[['combined_name', 'eaten_quantity', 'QI', 'DI', 'NB']]
# Out:
#                                             combined_name  eaten_quantity  \
# 290599                       MClassic - Saladbowl Chicken         250.000
# 291464  Betty Bossi - Chicken Caesar Salad (& caesar d...         260.000
# 261242  Chicken caesar salad (green salad, cheese, cro...         200.000
# 256693                                        Bami goreng         400.000
# 297433                                      Tandoori Wrap         190.000
# 294058                         COOP Spicy Chicken Avocado         235.000
# 301176      migrolino - Avocado & Kalbsspeck Chicken Wrap         200.000
# 281830                           Chicken Ketchup Sandwich         215.000
# 281347                            Chicken Crispy Sandwich         230.000
# 290384        Coop, Betty Bossi - Sandwich Poulet tartare         235.000
# 269244  Sandwich, chicken (raw vegetable, tomato, sala...         250.000
# 307982                    Baguettine maïs poulet exotique         130.000
# 258309                                             Paella         250.000
# 282671                 Coop Betty Bossi - Poulet Cocktail         220.000
# 288097                                coop Chicken Caesar         200.000
# 266234                                     Vegetable flan         125.000
# 284981          Coop Naturaplan Bio - Rüeblisalat (Vegan)         160.000
# 266428  Chicken curry (cream/coconut milk. curry spice...         140.000
# 297043                       Migros - Sushi Salmon Masago         165.000
# 292436                               Naturaplan Bio sushi         250.000
# 298861                   Sushis vegan no fish - 15 pieces         313.000
# 303443                           Sushi wrap smoked salmon         350.000
# 277188  Coop Betty Bossi - Chicken Tikka Masala mit Ba...         400.000
# 296390               Onigiri Zenbu - Spinach and shiitake         110.000
# 297044                            Migros - Sushi Maki Mix         200.000
# 257611                                              Sushi         180.000
# 310292                                       Sushi Nigiri         240.000
# 299691             Anna's best - Salade bowl farmer style         180.000
# 305742                                    Sandwich salmon         240.000
# 288554                         Zenbu - Onigiri Spicy tuna         110.000
# 316612                                 Carpaccio de boeuf           0.102
# 304174                  Fait Maison - Carpaccio de poulpe         112.000
# 299410                      Betty Bossi Vegi sticks & dip         150.000
# 306091                                 Power salad Linsen         300.000
# 17537                                         Ratatouille         120.000
# 304044                                   Russischer Salat         100.000
# 301556                         Coop Bordelaise Baked fish         120.000
# 306137           Coop Fait maison - Bowl salade de saumon         180.000
# 8351         Quiche, with spinach, baked, with cake dough          70.000
# 281945              Farmer's Best Spicy Ratatouille Mixes         150.000
# 8476        Quiche, with spinach, baked, with puff pastry         120.000
# 296578         Betty Bossi - Mâche salad & House dressing         190.000
# 5640                   Egg, scrambled, with ham, prepared         250.000
# 5597                Egg, scrambled, with cheese, prepared         136.000
# 8672                    Beef ragout, with sauce, prepared         250.000
# 289682                           Migros Bio - Linsensalat         200.000
# 298059                    Alnatura - Bratlinge mediterran          87.500
# 274571                         Vegetable au gratin, baked         200.000
# 8647                    Lamb ragout, with sauce, prepared         120.000
# 308739             coop naturaplan Plätzli mit Spinat bio         180.000
# 144154                                              Patty          60.000
# 119896              Pasta, tortelloni, vegetable stuffing         160.000
# 295577                               MIGROS Salmon tartar         180.000
# 278715                          M Classic Chili with meat         430.000
# 8738                    Pork ragout, with sauce, prepared         200.000
#
#                 QI         DI         NB
# 290599  254.631479   1.645896  85.009150
# 291464  147.293505   1.478695  78.709698
# 261242  143.393908   1.126360  80.829971
# 256693   86.332573   1.083334  72.360804
# 297433   64.399538   1.224223  71.323872
# 294058   63.639363   1.244381  70.529591
# 301176   57.342590   1.231895  67.389236
# 281830   51.153458   1.023575  62.918973
# 281347   47.803951   1.105742  61.095693
# 290384   44.197996   1.070280  59.971490
# 269244   42.917946   0.672460  59.239724
# 307982   42.917946   0.672460  59.239724
# 258309   42.599565   0.787205  77.265047
# 282671   40.548636   0.956261  57.625859
# 288097   32.093522   0.971304  51.121824
# 266234   30.849914   2.481927  68.959993
# 284981   28.327363   0.731399  80.790109
# 266428   23.133060   1.452577  71.087165
# 297043   22.774807   1.215756  67.952450
# 292436   22.161030   1.356121  67.888551
# 298861   20.980305   1.133819  66.553980
# 303443   20.099597   1.019840  65.537227
# 277188   18.825940   1.412344  65.393477
# 296390   18.128352   0.660648  65.517540
# 297044   17.293963   0.484705  62.241389
# 257611   17.293963   0.484705  62.241389
# 310292   17.293963   0.484705  62.241389
# 299691   17.187527   0.417521  85.000000
# 305742   16.333035   0.702573  61.426264
# 288554   15.295266   0.626517  61.457278
# 316612   15.217391  21.168091   5.000000
# 304174   12.093442   1.193991  81.319930
# 299410    4.684958   0.843915  55.415293
# 306091    4.496858   0.544199  85.052632
# 17537     4.355484   1.620089  84.583333
# 304044    4.278647   1.559904  98.362573
# 301556    3.919717   1.341602  79.081365
# 306137    3.319293   2.086387  64.640719
# 8351      3.294457   1.419167  95.260637
# 281945    3.210203   1.554814  82.230769
# 8476      3.129374   1.538136  93.879706
# 296578    3.123942   0.952614  56.413501
# 5640      3.007359   3.682127  76.258987
# 5597      2.893992   3.720559  66.894750
# 8672      2.783396   1.107407  68.517156
# 289682    2.759388   0.685142  77.398268
# 298059    2.686034   2.789252  76.008170
# 274571    2.634672   1.295495  92.630187
# 8647      2.558935   1.291487  62.700435
# 308739    2.417053   1.353547  82.688777
# 144154    2.364214   0.835238  56.108389
# 119896    2.322210   1.715616  84.707561
# 295577    2.319845   2.389467  61.500386
# 278715    2.303934   1.446780  91.207283
# 8738      2.183452   1.156192  65.620422

# %%
ratio_cols = [i for i in high_qi_processed_foods.columns if '_ratio_scaled' in i]

df_corr = high_qi_processed_foods[ratio_cols + ['QI']]
corr = df_corr.corr()['QI']
corr.sort_values(ascending=True)
# Out:
# vitamin_d_eaten_ratio_scaled                                -0.246694
# all_trans_retinol_equivalents_activity_eaten_ratio_scaled   -0.238711
# vitamin_c_eaten_ratio_scaled                                -0.186693
# iron_eaten_ratio_scaled                                     -0.174035
# zinc_eaten_ratio_scaled                                     -0.171968
# pantothenic_acid_eaten_ratio_scaled                         -0.124503
# magnesium_eaten_ratio_scaled                                -0.113676
# vitamin_b12_eaten_ratio_scaled                              -0.097083
# potassium_eaten_ratio_scaled                                -0.096146
# vitamin_e_activity_eaten_ratio_scaled                       -0.082748
# cholesterol_eaten_ratio_scaled                              -0.072221
# salt_eaten_ratio_scaled                                     -0.068826
# fiber_eaten_ratio_scaled                                    -0.064617
# phosphorus_eaten_ratio_scaled                               -0.057383
# protein_eaten_ratio_scaled                                  -0.045098
# sugar_eaten_ratio_scaled                                    -0.038661
# fat_eaten_ratio_scaled                                      -0.036742
# folate_eaten_ratio_scaled                                   -0.028073
# fatty_acids_saturated_eaten_ratio_scaled                    -0.023123
# beta_carotene_eaten_ratio_scaled                            -0.020840
# niacin_eaten_ratio_scaled                                    0.035596
# sodium_eaten_ratio_scaled                                    0.048450
# calcium_eaten_ratio_scaled                                   0.179435
# vitamin_b2_eaten_ratio_scaled                                0.852263
# vitamin_b6_eaten_ratio_scaled                                0.887987
# vitamin_b1_eaten_ratio_scaled                                0.948325
# QI                                                           1.000000
# Name: QI, dtype: float64

# %%
def compute_index(row, nutrient_cols, scaling_factor=2000) :

    index = 0
    ratio_sum = 0

    for nutr in nutrient_cols :
        ratio_sum += row[nutr + '_ratio']

    index = (scaling_factor / row['energy_kcal_eaten']) * (ratio_sum / len(nutrient_cols))
    return index

# %%
def compute_qi_excluding(row, nutrient_list, exclude=None, scaling_factor=2000):
    if exclude is not None:
        new_list = [nutr for nutr in nutrient_list if nutr != exclude]
    else:
        new_list = nutrient_list
    

    return compute_index(row, new_list, scaling_factor=scaling_factor)

# %%
def compute_qi_excluding_multiple(row, nutrient_list, exclude_list, scaling_factor=2000):

    new_list = nutrient_list.copy()  

    for nutr in exclude_list:
        if nutr in new_list:
            new_list.remove(nutr)

    return compute_index(row, new_list, scaling_factor=scaling_factor)

# %%
def compare_qi_excluding_nutrient(df, nutrient_to_exclude, qualifying_nutrients, new_col_name=None,scaling_factor=2000):


    if new_col_name is None:
        new_col_name = f"QI_excl_{nutrient_to_exclude}"


    df[new_col_name] = df.apply(lambda row: compute_qi_excluding(row, qualifying_nutrients, exclude=nutrient_to_exclude, scaling_factor=scaling_factor), axis=1)

 
    df_plot = df.drop_duplicates('combined_name').copy()
    df_plot = df_plot[['combined_name', 'QI', new_col_name]]

    labels = df_plot['combined_name'].tolist()
    x = np.arange(len(labels))
    width = 0.35


    plt.figure(figsize=(20, 8))
    plt.bar(x - width/2, df_plot['QI'], width, label='QI (incl. ' + nutrient_to_exclude + ')', color='skyblue')
    plt.bar(x + width/2, df_plot[new_col_name], width, label=f"QI (excl. {nutrient_to_exclude})", color='deeppink')

    plt.xlabel('Food Item')
    plt.ylabel('QI Value')
    plt.title(f"Comparison of QI with and without {nutrient_to_exclude}")
    plt.xticks(x, labels, rotation=45, ha='right')
    plt.legend()
    plt.tight_layout()
    plt.show()

    df_plot['QI_diff'] = df_plot['QI'] - df_plot[new_col_name]
    df_plot['QI_pct_change'] = (df_plot['QI_diff'] / df_plot['QI']) * 100

    return df_plot

# %%
def compute_nb(row, nutrient_cols, scaling_factor=2000) :
    truncated_ratios = []
    for nutr in nutrient_cols:
        ratio =   row[nutr + '_ratio_scaled']
        if ratio > 1.0 :
            ratio = 1
        truncated_ratios.append(ratio)

    nb_value =  (sum(truncated_ratios) / len(nutrient_cols)) * 100
    return nb_value

# %%
def compute_nb_excluding(row, nutrient_list, exclude=None, scaling_factor=2000):

    if exclude is not None:
        new_list = [nutr for nutr in nutrient_list if nutr != exclude]
    else:
        new_list = nutrient_list
    return compute_nb(row, new_list, scaling_factor=scaling_factor)

# %%
def compare_nb_excluding_nutrient(df, nutrient_to_exclude, qualifying_nutrients, new_col_name=None, scaling_factor=2000):
  
    if new_col_name is None:
        new_col_name = f"NB_excl_{nutrient_to_exclude}"

    df['NB'] = df.apply(lambda row: compute_nb(row, qualifying_nutrients, scaling_factor=scaling_factor), axis=1)

    df[new_col_name] = df.apply(lambda row: compute_nb_excluding(row, qualifying_nutrients, exclude=nutrient_to_exclude, scaling_factor=scaling_factor), axis=1)
    
    df_plot = df.drop_duplicates('combined_name').copy()
    df_plot = df_plot[['combined_name', 'NB', new_col_name]]
    
    labels = df_plot['combined_name'].tolist()
    x = np.arange(len(labels))
    width = 0.35
    
    plt.figure(figsize=(20, 8))
    plt.bar(x - width/2, df_plot['NB'], width, label='NB (incl. all)', color='skyblue')
    plt.bar(x + width/2, df_plot[new_col_name], width, label=f"NB (excl. {nutrient_to_exclude})", color='deeppink')
    plt.xlabel('Food Item')
    plt.ylabel('NB Value (%)')
    plt.title(f"Comparison of NB with and without {nutrient_to_exclude}")
    plt.xticks(x, labels, rotation=45, ha='right')
    plt.legend()
    plt.tight_layout()
    plt.show()
    
    df_plot['NB_diff'] = df_plot['NB'] - df_plot[new_col_name]
    df_plot['NB_pct_change'] = (df_plot['NB_diff'] / df_plot['NB']) * 100
    return df_plot

# %%
def compute_nb_excluding_multiple(row, nutrient_list, exclude_list, scaling_factor=2000):
    new_list = nutrient_list.copy()  
    for nutr in exclude_list:
        if nutr in new_list:
            new_list.remove(nutr)
    return compute_nb(row, new_list, scaling_factor=scaling_factor)

# %%
def interactive_exclude_nutrient(nutrient):
    clear_output(wait=True)
    df_plot = compare_qi_excluding_nutrient(
        df=high_qi_processed_foods, 
        nutrient_to_exclude=nutrient,
        qualifying_nutrients=qualifying_nutrients, 
        scaling_factor=2000
    )

    display(df_plot[['combined_name', 'QI', f"QI_excl_{nutrient}", 'QI_diff', 'QI_pct_change']])

    print(f"\nExcluding {nutrient} for NB:")
    df_nb = compare_nb_excluding_nutrient(
        df=high_qi_processed_foods, 
        nutrient_to_exclude=nutrient,
        qualifying_nutrients=qualifying_nutrients, 
        scaling_factor=2000
    )
    display(df_nb[['combined_name', 'NB', f"NB_excl_{nutrient}", 'NB_diff', 'NB_pct_change']])

nutrient_choice = ['folate_eaten', 
                   'niacin_eaten', 
                   'pantothenic_acid_eaten', 
                   'vitamin_b2_eaten', 
                   'vitamin_b1_eaten', 
                   'all_trans_retinol_equivalents_activity_eaten', 
                   'beta_carotene_eaten', 
                   'vitamin_b12_eaten', 
                   'vitamin_b6_eaten', 
                   'vitamin_c_eaten', 
                   'vitamin_d_eaten', 
                   'vitamin_e_activity_eaten', 
                   'calcium_eaten', 
                   'iron_eaten', 
                   'magnesium_eaten', 
                   'phosphorus_eaten', 
                   'potassium_eaten', 
                   'zinc_eaten', 
                   'fiber_eaten', 
                   'protein_eaten']

# %%
interact(interactive_exclude_nutrient, nutrient=widgets.Dropdown(options=nutrient_choice, description='Exclude:'))
# Out:
# interactive(children=(Dropdown(description='Exclude:', options=('folate_eaten', 'niacin_eaten', 'pantothenic_a…
# <function __main__.interactive_exclude_nutrient(nutrient)>

# %% [markdown]
# - vitamin b2
# - vitamin b1
# - vitamin b6

# %%
exclude_list = ['vitamin_b1_eaten', 'vitamin_b6_eaten', 'vitamin_b2_eaten']
qualifying_nutrients = list(nutrient_info.keys())

for idx, row in high_qi_processed_foods.iterrows():

    qi_incl = compute_qi_excluding_multiple(row, qualifying_nutrients, exclude_list=[])
    qi_excl = compute_qi_excluding_multiple(row, qualifying_nutrients, exclude_list=exclude_list)

    nb_incl = compute_nb_excluding_multiple(row, qualifying_nutrients, exclude_list=[]) 
    nb_excl = compute_nb_excluding_multiple(row, qualifying_nutrients, exclude_list=exclude_list)

    print(f"Food item : {row['combined_name']}")
    print(f"QI (incl. all): {qi_incl}")
    print(f"QI (excl. {', '.join(exclude_list)}): {qi_excl}")
    print(f"NB (incl. all): {nb_incl:.2f}")
    print(f"NB (excl. {', '.join(exclude_list)}): {nb_excl:.2f}")
    print("-----------")
# Out:
# Food item : MClassic - Saladbowl Chicken
# QI (incl. all): 196.2501904840887
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.793438730479668
# NB (incl. all): 84.32
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 82.28
# -----------
# Food item : Betty Bossi - Chicken Caesar Salad (& caesar dressing)
# QI (incl. all): 113.64393357901248
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.8028293070799806
# NB (incl. all): 80.40
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 77.85
# -----------
# Food item : Chicken caesar salad (green salad, cheese, croutons, sauce)
# QI (incl. all): 110.56293518697744
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.6753052958033712
# NB (incl. all): 78.26
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 75.42
# -----------
# Food item : Bami goreng
# QI (incl. all): 66.65967150577147
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.4314297884815972
# NB (incl. all): 71.47
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 67.75
# -----------
# Food item : Tandoori Wrap
# QI (incl. all): 49.82061899090764
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.0727575261273137
# NB (incl. all): 71.73
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 68.05
# -----------
# Food item : COOP Spicy Chicken Avocado
# QI (incl. all): 49.240521247900354
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.0174970674265518
# NB (incl. all): 73.44
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 69.97
# -----------
# Food item : migrolino - Avocado & Kalbsspeck Chicken Wrap
# QI (incl. all): 44.393968108812366
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.970991688140501
# NB (incl. all): 72.30
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 68.77
# -----------
# Food item : Chicken Ketchup Sandwich
# QI (incl. all): 39.58502370346755
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.8408249610479795
# NB (incl. all): 64.78
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 60.74
# -----------
# Food item : Chicken Crispy Sandwich
# QI (incl. all): 37.0274414161107
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.8170711197904296
# NB (incl. all): 65.17
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 61.42
# -----------
# Food item : Coop, Betty Bossi - Sandwich Poulet tartare
# QI (incl. all): 34.2454461693809
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.7695681782491092
# NB (incl. all): 63.79
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 60.14
# -----------
# Food item : Sandwich, chicken (raw vegetable, tomato, salad, mayonnaise)
# QI (incl. all): 33.168987939198395
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.6645756222048249
# NB (incl. all): 58.64
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 54.41
# -----------
# Food item : Baguettine maïs poulet exotique
# QI (incl. all): 33.16898793919837
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.6645756222048209
# NB (incl. all): 58.64
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 54.41
# -----------
# Food item : Paella
# QI (incl. all): 32.95055890619072
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.211600117966506
# NB (incl. all): 73.92
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 70.51
# -----------
# Food item : Coop Betty Bossi - Poulet Cocktail
# QI (incl. all): 31.41193418869835
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.7174164936472632
# NB (incl. all): 61.05
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 57.30
# -----------
# Food item : coop Chicken Caesar
# QI (incl. all): 24.911471451815117
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 0.6886381889839104
# NB (incl. all): 56.57
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 52.87
# -----------
# Food item : Vegetable flan
# QI (incl. all): 24.30345558973502
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.3226060509085458
# NB (incl. all): 68.87
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 65.44
# -----------
# Food item : Coop Naturaplan Bio - Rüeblisalat (Vegan)
# QI (incl. all): 21.959063467475342
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 24.246939476128183
# NB (incl. all): 72.51
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 68.92
# -----------
# Food item : Chicken curry (cream/coconut milk. curry spices/paste))
# QI (incl. all): 18.129871711811475
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.702606803649504
# NB (incl. all): 70.81
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 71.35
# -----------
# Food item : Migros - Sushi Salmon Masago
# QI (incl. all): 17.79964117837774
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 4.724766055451764
# NB (incl. all): 68.52
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 65.77
# -----------
# Food item : Naturaplan Bio sushi
# QI (incl. all): 17.35989738957149
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 4.630932433916736
# NB (incl. all): 67.06
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 64.19
# -----------
# Food item : Sushis vegan no fish - 15 pieces
# QI (incl. all): 16.400346468431657
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 4.319762347434409
# NB (incl. all): 71.20
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 69.03
# -----------
# Food item : Sushi wrap smoked salmon
# QI (incl. all): 15.696576178502186
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 4.13113689755591
# NB (incl. all): 68.13
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 65.67
# -----------
# Food item : Coop Betty Bossi - Chicken Tikka Masala mit Basmatireis
# QI (incl. all): 14.807418113278846
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.4084795734571498
# NB (incl. all): 70.18
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 70.64
# -----------
# Food item : Onigiri Zenbu - Spinach and shiitake
# QI (incl. all): 14.097343278057812
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.6696311381311753
# NB (incl. all): 63.15
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 60.30
# -----------
# Food item : Migros - Sushi Maki Mix
# QI (incl. all): 13.414903613582
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.4761800358515274
# NB (incl. all): 58.99
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 55.71
# -----------
# Food item : Sushi
# QI (incl. all): 13.414903613581993
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.476180035851523
# NB (incl. all): 58.99
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 55.71
# -----------
# Food item : Sushi Nigiri
# QI (incl. all): 13.414903613581975
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.4761800358515282
# NB (incl. all): 58.99
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 55.71
# -----------
# Food item : Anna's best - Salade bowl farmer style
# QI (incl. all): 13.317525954392142
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 14.127261021109957
# NB (incl. all): 74.08
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 70.70
# -----------
# Food item : Sandwich salmon
# QI (incl. all): 12.726005274985743
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.333927519731558
# NB (incl. all): 60.96
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 58.07
# -----------
# Food item : Zenbu - Onigiri Spicy tuna
# QI (incl. all): 11.910169909756862
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.128011627544695
# NB (incl. all): 60.83
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 58.06
# -----------
# Food item : Carpaccio de boeuf
# QI (incl. all): 16.59062973444244
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 18.7546249171958
# NB (incl. all): 11.54
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 13.04
# -----------
# Food item : Fait Maison - Carpaccio de poulpe
# QI (incl. all): 9.578183901299964
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 10.483816077338583
# NB (incl. all): 72.57
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 71.19
# -----------
# Food item : Betty Bossi Vegi sticks & dip
# QI (incl. all): 3.7985630791530056
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 4.089697329747092
# NB (incl. all): 55.83
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 54.52
# -----------
# Food item : Power salad Linsen
# QI (incl. all): 3.5847055921107587
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.419878154793835
# NB (incl. all): 75.93
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 72.79
# -----------
# Food item : Ratatouille
# QI (incl. all): 3.7242386445278797
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.8317488775106208
# NB (incl. all): 82.63
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 80.37
# -----------
# Food item : Russischer Salat
# QI (incl. all): 3.651244857672029
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.680318682549856
# NB (incl. all): 89.69
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 88.34
# -----------
# Food item : Coop Bordelaise Baked fish
# QI (incl. all): 3.3247676663381887
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.4051915961761448
# NB (incl. all): 75.65
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 72.48
# -----------
# Food item : Coop Fait maison - Bowl salade de saumon
# QI (incl. all): 3.0347760601944276
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.9900563684387036
# NB (incl. all): 65.03
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 60.47
# -----------
# Food item : Quiche, with spinach, baked, with cake dough
# QI (incl. all): 2.8616977024081334
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.039882852098348
# NB (incl. all): 89.21
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 87.86
# -----------
# Food item : Farmer's Best Spicy Ratatouille Mixes
# QI (incl. all): 2.828190475125978
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.917754404925642
# NB (incl. all): 81.27
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 78.83
# -----------
# Food item : Quiche, with spinach, baked, with puff pastry
# QI (incl. all): 2.762165163443088
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.9409892363273493
# NB (incl. all): 88.12
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 86.85
# -----------
# Food item : Betty Bossi - Mâche salad & House dressing
# QI (incl. all): 2.6228660120595655
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.8351622794120726
# NB (incl. all): 55.41
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 53.06
# -----------
# Food item : Egg, scrambled, with ham, prepared
# QI (incl. all): 3.1630746769457705
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.1547086540102236
# NB (incl. all): 74.59
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 71.28
# -----------
# Food item : Egg, scrambled, with cheese, prepared
# QI (incl. all): 3.0847378552264297
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 3.1165057528742968
# NB (incl. all): 67.35
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 63.09
# -----------
# Food item : Beef ragout, with sauce, prepared
# QI (incl. all): 2.3966296176794226
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.5295914951929466
# NB (incl. all): 66.65
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 65.06
# -----------
# Food item : Migros Bio - Linsensalat
# QI (incl. all): 2.2807160012307874
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.1967544460320587
# NB (incl. all): 69.70
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 67.20
# -----------
# Food item : Alnatura - Bratlinge mediterran
# QI (incl. all): 2.7098537708513515
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.2986122374230407
# NB (incl. all): 75.43
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 72.23
# -----------
# Food item : Vegetable au gratin, baked
# QI (incl. all): 2.325630731759209
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.377915496056155
# NB (incl. all): 88.37
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 86.85
# -----------
# Food item : Lamb ragout, with sauce, prepared
# QI (incl. all): 2.266446944167875
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.442183276171139
# NB (incl. all): 64.42
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 63.01
# -----------
# Food item : coop naturaplan Plätzli mit Spinat bio
# QI (incl. all): 2.1716287394214353
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.252306653512149
# NB (incl. all): 78.43
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 75.62
# -----------
# Food item : Patty
# QI (incl. all): 2.0113731772326404
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.141973894684592
# NB (incl. all): 53.71
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 53.53
# -----------
# Food item : Pasta, tortelloni, vegetable stuffing
# QI (incl. all): 2.1822265326029897
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.2661293007345207
# NB (incl. all): 85.46
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 83.56
# -----------
# Food item : MIGROS Salmon tartar
# QI (incl. all): 2.3359112728837355
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.3261785659668353
# NB (incl. all): 66.69
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 62.35
# -----------
# Food item : M Classic Chili with meat
# QI (incl. all): 2.1061295431599114
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 2.0774540906700434
# NB (incl. all): 88.95
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 87.51
# -----------
# Food item : Pork ragout, with sauce, prepared
# QI (incl. all): 1.9463922904764273
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 1.8971226477648928
# NB (incl. all): 66.73
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, vitamin_b2_eaten): 62.39
# -----------
