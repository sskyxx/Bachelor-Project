# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
from matplotlib.patches import Circle
import os
import pickle
from scipy.stats import mannwhitneyu, ttest_ind, kruskal, f_oneway
from statannotations.Annotator import Annotator
from itertools import combinations
from ipywidgets import interact
import ipywidgets as widgets
from IPython.display import clear_output, display
import sys
sys.path.append('../scripts') 

from functions import *

# %%
print(os.getcwd())
# Out:
# c:\Users\Sophie\Desktop\EPFL\Bachelor project\Bachelor-Project\food groups

# %%
df_food_scaled = pd.read_csv('../data/df_food_scaled.csv')
# Out:
# C:\Users\Sophie\AppData\Local\Temp\ipykernel_736\2711278687.py:1: DtypeWarning: Columns (1,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food_scaled = pd.read_csv('../data/df_food_scaled.csv')

# %%
nutrient_info = {
    'folate_eaten':                                         {'unit': 'mcg', 'target': 400,  'type': 'qualifying'},
    'niacin_eaten':                                         {'unit': 'mg',  'target': 14,   'type': 'qualifying'},
    'pantothenic_acid_eaten':                               {'unit': 'mg',  'target': 5,    'type': 'qualifying'},
    'vitamin_b2_eaten':                                     {'unit': 'mg',  'target': 1.1,  'type': 'qualifying'},
    'vitamin_b1_eaten':                                     {'unit': 'mg',  'target': 1.2,  'type': 'qualifying'},
    'all_trans_retinol_equivalents_activity_eaten':         {'unit': 'IU',  'target': 700,  'type': 'qualifying'},
    'beta_carotene_eaten':                                  {'unit' : 'mcg','target' : 700, 'type' :'qualifying'},
    'vitamin_b12_eaten':                                    {'unit': 'mcg', 'target': 2.4,  'type': 'qualifying'},
    'vitamin_b6_eaten':                                     {'unit': 'mg',  'target': 1.3,  'type': 'qualifying'},
    'vitamin_c_eaten':                                      {'unit': 'mg',  'target': 75,   'type': 'qualifying'},
    'vitamin_d_eaten':                                      {'unit': 'mcg', 'target': 7.5,  'type': 'qualifying'},
    'vitamin_e_activity_eaten':                             {'unit': 'TAE', 'target': 15,    'type': 'qualifying'},
    'calcium_eaten':                                        {'unit': 'mg',  'target': 1000, 'type': 'qualifying'},
    'iron_eaten':                                           {'unit': 'mg',  'target': 18,   'type': 'qualifying'},
    'magnesium_eaten':                                      {'unit': 'mg',  'target': 320,  'type': 'qualifying'},
    'phosphorus_eaten':                                     {'unit': 'mg',  'target': 700,  'type': 'qualifying'},
    'potassium_eaten':                                      {'unit': 'mg',  'target': 4700, 'type': 'qualifying'},
    'zinc_eaten':                                           {'unit': 'mg',  'target': 8,    'type': 'qualifying'},
    'fiber_eaten':                                          {'unit': 'g',   'target': 25,   'type': 'qualifying'},
    'protein_eaten':                                        {'unit': 'g',   'target': 46,   'type': 'qualifying'},
    'fat_eaten':                                            {'unit': 'g',   'target': 78,   'type': 'disqualifying'},
    'fatty_acids_saturated_eaten':                          {'unit': 'g',   'target': 22,   'type': 'disqualifying'},
    'cholesterol_eaten':                                    {'unit': 'mg',  'target': 300,  'type': 'disqualifying'},
    'sugar_eaten':                                          {'unit': 'g',   'target': 125,  'type': 'disqualifying'},
    'sodium_eaten':                                         {'unit': 'mg',  'target': 2400, 'type': 'disqualifying'},
    'salt_eaten' :                                          {'unit' : 'g',  'target': 6,   'type': 'disqualifying'}
}


conversion_factors = {
    "mg": 1000,
    "g": 1,
    "mcg": 1000000,
    "IU": 1,
    "TAE": 1,
}

# %%
qualifying_nutrients = {nutr: info for nutr, info in nutrient_info.items() if info['type'] == 'qualifying'}
disqualifying_nutrients = {nutr: info for nutr, info in nutrient_info.items() if info['type'] == 'disqualifying'}

# %%
df_yogurt_fresh_dairy = df_food_scaled[df_food_scaled['food_group'] == 'yogurt_fresh_dairy']
df_yogurt_fresh_dairy.drop_duplicates('combined_name')[['combined_name', 'QI', 'DI', 'NB']].sort_values('QI', ascending=False)
# Out:
#                                             combined_name         QI  \
# 284621           Migros - Oh! Yogurt greek style (Nature)  91.427047
# 294398                            Isey skyr pommes cuites  89.839474
# 294326   Icelandic Skyr - The Original (Lemon Cheesecake)  86.855694
# 303882                                         YoQua Moka  84.018835
# 271962         Greek Yaourt, yahourt, yogourt ou yoghourt  75.223594
# ...                                                   ...        ...
# 308758  Abbot Kinney's - Coco start, coconut based yog...   0.000000
# 311905                               Nestlé - Hirz, choco   0.000000
# 313704  Milco - Yogurt à la crème de la Gruyère sur li...   0.000000
# 315265          Coop Naturaplan -  Bio Jogurt (Zwetschge)   0.000000
# 315912         Coop Naturaplan - Bio Kefir Drink (Nature)   0.000000
#
#               DI         NB
# 284621  0.607057  63.380585
# 294398  0.598977  63.236092
# 294326  0.583826  62.961556
# 303882  0.556391  62.704731
# 271962  1.070352  61.913073
# ...          ...        ...
# 308758  0.000000   0.000000
# 311905  0.000000   0.000000
# 313704  0.182708   0.000000
# 315265  0.000000   0.000000
# 315912  0.000000   0.000000
#
# [643 rows x 4 columns]

# %%
high_qi_yogurt_fresh_dairy = df_yogurt_fresh_dairy[df_yogurt_fresh_dairy['QI'] > 5].drop_duplicates('combined_name').sort_values('QI', ascending=False)

# %%
high_qi_yogurt_fresh_dairy[['combined_name', 'eaten_quantity', 'QI', 'DI', 'NB']]
# Out:
#                                             combined_name  eaten_quantity  \
# 284621           Migros - Oh! Yogurt greek style (Nature)           170.0
# 294398                            Isey skyr pommes cuites           170.0
# 294326   Icelandic Skyr - The Original (Lemon Cheesecake)           170.0
# 303882                                         YoQua Moka            60.0
# 271962         Greek Yaourt, yahourt, yogourt ou yoghourt            40.0
# 284217      Nestlé YOGURT Greek-style, plain, unsweetened           170.0
# 294821                    Nestlé - Le Yaourt A La Grecque           150.0
# 267589         coop naturaplan Griechischer Jogurt Nature           150.0
# 267627        coop naturaplan  Griechischer Jogurt Nature           170.0
# 293602          Nestlé THE YOGURT WITH GREEK NATURE sweet           150.0
# 306099  Lac - Joghurt nach griechischer (Natur), lacto...           150.0
# 282818           Joghurt nach griechischer Art (Himbeere)           150.0
# 295005                     Nestlé YOGURT WITH GREEK HONEY           150.0
# 291128                                      Yogos Classic           180.0
# 283860        Nestlé Joghurt Nach Griechischer Art Feigen           150.0
# 292484                 MIGROS Yogourt à la grecque mangue           150.0
# 285442                                       Yogos Nature             0.3
# 297841                   Olympus - Authentic Greek yogurt           150.0
# 299793  Coop Naturaplan Bio - Bio jogurt à la grecque ...           100.0
# 290008                           Emmi Knusper Mix Classic           150.0
# 299764               Coop Naturaplan Jogurt bei The Greek           150.0
# 273884                           Coop Jogurt à la Grecque           150.0
# 301126  Migros - Joghurt nach griechischer Art (Mandel...            75.0
# 301894                             Joghurt pfirsch ananas           180.0
#
#                QI        DI         NB
# 284621  91.427047  0.607057  63.380585
# 294398  89.839474  0.598977  63.236092
# 294326  86.855694  0.583826  62.961556
# 303882  84.018835  0.556391  62.704731
# 271962  75.223594  1.070352  61.913073
# 284217  49.524165  1.168528  59.013746
# 294821  48.563941  1.453769  58.845265
# 267589  46.393967  1.461046  58.249494
# 267627  46.393967  1.461046  58.249494
# 293602  44.062586  1.208376  57.491045
# 306099  42.285563  1.320473  56.780027
# 282818  41.929123  1.190923  58.257608
# 295005  41.145492  1.138597  56.335127
# 291128  40.922923  1.360663  56.251522
# 283860  40.304772  1.050872  56.619716
# 292484  40.303963  1.168748  57.549948
# 285442  40.296885  1.339568  55.999561
# 297841  38.841940  1.296855  55.402562
# 299793  37.374369  1.193697  53.758429
# 290008  36.867363  0.603351  54.637896
# 299764  36.844236  1.211543  53.492352
# 273884  36.805692  1.211543  49.637896
# 301126  35.864125  1.082652  55.613402
# 301894  35.859628  1.161692  55.613402

# %%
ratio_cols = [i for i in high_qi_yogurt_fresh_dairy.columns if '_ratio_scaled' in i]

df_corr = high_qi_yogurt_fresh_dairy[ratio_cols + ['QI']]
corr = df_corr.corr()['QI']
corr.sort_values(ascending=True)
# Out:
# fat_eaten_ratio_scaled                                      -0.792821
# fatty_acids_saturated_eaten_ratio_scaled                    -0.728951
# fiber_eaten_ratio_scaled                                    -0.303561
# sugar_eaten_ratio_scaled                                    -0.098691
# salt_eaten_ratio_scaled                                      0.565620
# protein_eaten_ratio_scaled                                   0.940160
# vitamin_b2_eaten_ratio_scaled                                0.999998
# phosphorus_eaten_ratio_scaled                                0.999998
# vitamin_b1_eaten_ratio_scaled                                0.999998
# pantothenic_acid_eaten_ratio_scaled                          0.999998
# cholesterol_eaten_ratio_scaled                               0.999998
# folate_eaten_ratio_scaled                                    0.999998
# iron_eaten_ratio_scaled                                      0.999998
# potassium_eaten_ratio_scaled                                 0.999998
# vitamin_b6_eaten_ratio_scaled                                0.999998
# calcium_eaten_ratio_scaled                                   0.999998
# sodium_eaten_ratio_scaled                                    0.999998
# magnesium_eaten_ratio_scaled                                 0.999998
# vitamin_b12_eaten_ratio_scaled                               0.999998
# niacin_eaten_ratio_scaled                                    0.999998
# zinc_eaten_ratio_scaled                                      0.999998
# QI                                                           1.000000
# all_trans_retinol_equivalents_activity_eaten_ratio_scaled         NaN
# beta_carotene_eaten_ratio_scaled                                  NaN
# vitamin_c_eaten_ratio_scaled                                      NaN
# vitamin_d_eaten_ratio_scaled                                      NaN
# vitamin_e_activity_eaten_ratio_scaled                             NaN
# Name: QI, dtype: float64

# %%
def interactive_exclude_nutrient(nutrient):
    clear_output(wait=True)
    df_plot = compare_qi_excluding_nutrient(
        df=high_qi_yogurt_fresh_dairy, 
        nutrient_to_exclude=nutrient,
        qualifying_nutrients=qualifying_nutrients, 
        scaling_factor=2000
    )

    display(df_plot[['combined_name', 'QI', f"QI_excl_{nutrient}", 'QI_diff', 'QI_pct_change']])

    print(f"\nExcluding {nutrient} for NB:")
    df_nb = compare_nb_excluding_nutrient(
        df=high_qi_yogurt_fresh_dairy, 
        nutrient_to_exclude=nutrient,
        qualifying_nutrients=qualifying_nutrients, 
        scaling_factor=2000
    )
    display(df_nb[['combined_name', 'NB', f"NB_excl_{nutrient}", 'NB_diff', 'NB_pct_change']])

nutrient_choice = ['folate_eaten', 
                   'niacin_eaten', 
                   'pantothenic_acid_eaten', 
                   'vitamin_b2_eaten', 
                   'vitamin_b1_eaten', 
                   'all_trans_retinol_equivalents_activity_eaten', 
                   'beta_carotene_eaten', 
                   'vitamin_b12_eaten', 
                   'vitamin_b6_eaten', 
                   'vitamin_c_eaten', 
                   'vitamin_d_eaten', 
                   'vitamin_e_activity_eaten', 
                   'calcium_eaten', 
                   'iron_eaten', 
                   'magnesium_eaten', 
                   'phosphorus_eaten', 
                   'potassium_eaten', 
                   'zinc_eaten', 
                   'fiber_eaten', 
                   'protein_eaten']

# %%
interact(interactive_exclude_nutrient, nutrient=widgets.Dropdown(options=nutrient_choice, description='Exclude:'))
# Out:
# interactive(children=(Dropdown(description='Exclude:', options=('folate_eaten', 'niacin_eaten', 'pantothenic_a…
# <function __main__.interactive_exclude_nutrient(nutrient)>

# %% [markdown]
# - vitamin b1
# - vitamin b6
# - folate

# %%
exclude_list = ['vitamin_b1_eaten', 'vitamin_b6_eaten', 'folate_eaten']
qualifying_nutrients = list(nutrient_info.keys())

for idx, row in high_qi_yogurt_fresh_dairy.iterrows():

    qi_incl = compute_qi_excluding_multiple(row, qualifying_nutrients, exclude_list=[])
    qi_excl = compute_qi_excluding_multiple(row, qualifying_nutrients, exclude_list=exclude_list)

    nb_incl = compute_nb_excluding_multiple(row, qualifying_nutrients, exclude_list=[]) 
    nb_excl = compute_nb_excluding_multiple(row, qualifying_nutrients, exclude_list=exclude_list)

    print(f"Food item : {row['combined_name']}")
    print(f"QI (incl. all): {qi_incl}")
    print(f"QI (excl. {', '.join(exclude_list)}): {qi_excl}")
    print(f"NB (incl. all): {nb_incl:.2f}")
    print(f"NB (excl. {', '.join(exclude_list)}): {nb_excl:.2f}")
    print("-----------")
# Out:
# Food item : Migros - Oh! Yogurt greek style (Nature)
# QI (incl. all): 70.46858740068443
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.9895346004177652
# NB (incl. all): 59.66
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 54.40
# -----------
# Food item : Isey skyr pommes cuites
# QI (incl. all): 69.24551314242987
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.9460773254254804
# NB (incl. all): 59.44
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 54.15
# -----------
# Food item : Icelandic Skyr - The Original (Lemon Cheesecake)
# QI (incl. all): 66.94680168614003
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.8919159157331835
# NB (incl. all): 59.34
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 54.04
# -----------
# Food item : YoQua Moka
# QI (incl. all): 64.75827070068769
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.7981526667895216
# NB (incl. all): 58.97
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 53.61
# -----------
# Food item : Greek Yaourt, yahourt, yogourt ou yoghourt
# QI (incl. all): 58.11130759179148
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.6212222693927407
# NB (incl. all): 61.63
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 56.62
# -----------
# Food item : Nestlé YOGURT Greek-style, plain, unsweetened
# QI (incl. all): 38.3651717992132
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.20528047419685
# NB (incl. all): 59.83
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 54.59
# -----------
# Food item : Nestlé - Le Yaourt A La Grecque
# QI (incl. all): 37.6923626245581
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.232826556218604
# NB (incl. all): 59.95
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 54.73
# -----------
# Food item : coop naturaplan Griechischer Jogurt Nature
# QI (incl. all): 36.02483121289051
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.194930832791353
# NB (incl. all): 58.68
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 53.29
# -----------
# Food item : coop naturaplan  Griechischer Jogurt Nature
# QI (incl. all): 36.02483121289052
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.1949308327913526
# NB (incl. all): 58.68
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 53.29
# -----------
# Food item : Nestlé THE YOGURT WITH GREEK NATURE sweet
# QI (incl. all): 34.173152903959824
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.1116678123368093
# NB (incl. all): 60.61
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 55.47
# -----------
# Food item : Lac - Joghurt nach griechischer (Natur), lactosefrei
# QI (incl. all): 32.832080906511386
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.1208300008330763
# NB (incl. all): 58.42
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 53.00
# -----------
# Food item : Joghurt nach griechischer Art (Himbeere)
# QI (incl. all): 32.52799981346022
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.0673579003958922
# NB (incl. all): 60.45
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 55.29
# -----------
# Food item : Nestlé YOGURT WITH GREEK HONEY
# QI (incl. all): 31.913131936418367
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.0363424778174235
# NB (incl. all): 59.19
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 53.87
# -----------
# Food item : Yogos Classic
# QI (incl. all): 31.79317079145194
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.0800695949016221
# NB (incl. all): 57.14
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 51.55
# -----------
# Food item : Nestlé Joghurt Nach Griechischer Art Feigen
# QI (incl. all): 31.246179515219204
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.0021973129014365
# NB (incl. all): 58.53
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 53.12
# -----------
# Food item : MIGROS Yogourt à la grecque mangue
# QI (incl. all): 31.272759541192567
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.032244298784357
# NB (incl. all): 59.74
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 54.49
# -----------
# Food item : Yogos Nature
# QI (incl. all): 31.306734968339025
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.0706513033847043
# NB (incl. all): 56.85
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 51.22
# -----------
# Food item : Olympus - Authentic Greek yogurt
# QI (incl. all): 30.17768944324452
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 1.0749199719653704
# NB (incl. all): 56.70
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 51.05
# -----------
# Food item : Coop Naturaplan Bio - Bio jogurt à la grecque (Mangue)
# QI (incl. all): 29.024983298622754
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 0.9603137236646797
# NB (incl. all): 56.27
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 50.56
# -----------
# Food item : Emmi Knusper Mix Classic
# QI (incl. all): 28.498744792094485
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 0.817216078060976
# NB (incl. all): 53.55
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 47.49
# -----------
# Food item : Coop Naturaplan Jogurt bei The Greek
# QI (incl. all): 28.62130702472575
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 0.9557646888615277
# NB (incl. all): 56.10
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 50.38
# -----------
# Food item : Coop Jogurt à la Grecque
# QI (incl. all): 28.59165736510384
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 0.9222476823324147
# NB (incl. all): 53.14
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 47.03
# -----------
# Food item : Migros - Joghurt nach griechischer Art (Mandel-Honig)
# QI (incl. all): 27.837631477159324
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 0.9360431790776628
# NB (incl. all): 57.82
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 52.32
# -----------
# Food item : Joghurt pfirsch ananas
# QI (incl. all): 27.852411607266404
# QI (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 0.9527511522421904
# NB (incl. all): 57.82
# NB (excl. vitamin_b1_eaten, vitamin_b6_eaten, folate_eaten): 52.32
# -----------
