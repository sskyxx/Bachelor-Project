# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
from matplotlib.patches import Circle
import os
import pickle
from scipy.stats import mannwhitneyu, ttest_ind, kruskal, f_oneway
from statannotations.Annotator import Annotator
from itertools import combinations

# %%
df_food_scaled = pd.read_csv('../data/df_food_scaled.csv')
# Out:
# C:\Users\Sophie\AppData\Local\Temp\ipykernel_11668\2711278687.py:1: DtypeWarning: Columns (1,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food_scaled = pd.read_csv('../data/df_food_scaled.csv')

# %%
df_potatoes = df_food_scaled[df_food_scaled['food_group'] == 'potatoes']
df_potatoes.drop_duplicates('combined_name')[['combined_name', 'QI', 'DI', 'NB']].sort_values('QI', ascending=False)
# Out:
#                                             combined_name        QI        DI  \
# 285354          MIFLOC : Kartoffelstock Instant mit Milch  5.246306  3.445493
# 282689                                     Kartoffelstock  4.060594  3.115798
# 303818                             Kartoffeln festkochend  1.496327  0.342718
# 280996                        Knorr Stocki Kartoffelstock  1.475469  0.953215
# 11812                                    Potatoes steamed  1.365492  0.034843
# 10630                                        Sweet potato  1.365492  0.034843
# 11273                                            Potatoes  1.365492  0.034843
# 256314  Mashed potatoes, prepared, with full fat milk,...  1.210374  0.625121
# 4076           Potato flakes, with milk powder, with salt  1.107937  0.790109
# 277860                        Denny's, sweet potato fries  1.033772  0.548001
# 7808           French fries, baked, in the oven, unsalted  0.892086  0.228836
# ...

# %%
df_potatoes[df_potatoes['combined_name'] == 'MIFLOC : Kartoffelstock Instant mit Milch'][[i for i in df_potatoes.columns if '_ratio_scaled' in i]].T
# Out:
#                                                        285354
# folate_eaten_ratio_scaled                            1.830986
# niacin_eaten_ratio_scaled                            9.054326
# pantothenic_acid_eaten_ratio_scaled                  6.760563
# vitamin_b2_eaten_ratio_scaled                       10.499360
# vitamin_b1_eaten_ratio_scaled                        3.051643
# all_trans_retinol_equivalents_activity_eaten_ra...   1.730382
# beta_carotene_eaten_ratio_scaled                     0.000000
# vitamin_b12_eaten_ratio_scaled                       3.403756
# vitamin_b6_eaten_ratio_scaled                       14.951246
# vitamin_c_eaten_ratio_scaled                         6.647887
# vitamin_d_eaten_ratio_scaled                         0.751174
# vitamin_e_activity_eaten_ratio_scaled                0.582160
# calcium_eaten_ratio_scaled                           6.478873
# iron_eaten_ratio_scaled                              3.129890
# ...
