# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
from matplotlib.patches import Circle
import os
import pickle
from scipy.stats import mannwhitneyu, ttest_ind, kruskal, f_oneway
from statannotations.Annotator import Annotator
from itertools import combinations

# %%
df_food_scaled = pd.read_csv('df_food_scaled.csv')
# Out:
# C:\Users\Sophie\AppData\Local\Temp\ipykernel_11076\4074791732.py:1: DtypeWarning: Columns (1,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food_scaled = pd.read_csv('df_food_scaled.csv')

# %%
df_tofu = df_food_scaled[df_food_scaled['food_group'] == 'tofu_tempeh_seitan']
df_tofu.drop_duplicates('combined_name')[['combined_name', 'QI', 'DI', 'NB']].sort_values('QI', ascending=False)
# Out:
#                                             combined_name        QI        DI  \
# 155193                                               Tofu  1.839542  0.283953
# 300631                 Coop Karma - Organic Tofu (Nature)  1.647394  0.691872
# 281197                             COOP - Smokey bio Tofu  1.474101  0.959455
# 305237                    Coop Karma - Curry Organic Tofu  1.416131  0.869006
# 285825                                        Tofu nature  1.309179  0.444673
# 307320                     Swiss Soja - Tofu Sambal Oelek  1.202146  0.652546
# 305235                   Coop Karma - Smokey Organic Tofu  1.120672  0.870135
# 303248                                    Bio smokey tofu  1.112945  0.803413
# 305051                         Coop Karma Smokey Bio Tofu  1.095103  0.560239
# 287856                                      Tofu-spiessli  1.064062  0.401764
# 285042                             ALTANATURA Smoked Tofu  1.055301  0.588686
# ...
