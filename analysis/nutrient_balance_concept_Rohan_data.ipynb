# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import datetime

#from func_data_prep import process_string, nutri_macro_vars, personal_vars, amount_vars, nutri_micro_vars, nutri_cfg_vars, nutri_fg_vars

plt.rcParams['font.family'] = 'Arial'

#from pingouin import partial_corr

#from tqdm import tqdm

import warnings

warnings.filterwarnings("ignore", category=FutureWarning)

# %%
"""
meta = pd.read_csv(
    "/Users/rohansingh/WORK/qiime2_2024/metadata_files/fay_meta_may24.csv", index_col=0
)
meta.rename(columns={"subject_app_key": "subject_key"}, inplace=True)

if "age_group_2" not in meta.columns:
    meta["age_group_2"] = pd.cut(
        meta["age"], bins=[0, 35, 50, np.inf], labels=["<35", "35-50", ">50"]
    )
"""
# Out:
# '\nmeta = pd.read_csv(\n    "/Users/rohansingh/WORK/qiime2_2024/metadata_files/fay_meta_may24.csv", index_col=0\n)\nmeta.rename(columns={"subject_app_key": "subject_key"}, inplace=True)\n\nif "age_group_2" not in meta.columns:\n    meta["age_group_2"] = pd.cut(\n        meta["age"], bins=[0, 35, 50, np.inf], labels=["<35", "35-50", ">50"]\n    )\n'

# %%
df_food = pd.read_csv("../data/df_food_filtered_with_food_group.csv",index_col=0)
df_food_bkp = df_food.copy()

df_food = df_food[df_food["eaten_quantity_in_gram"] > 0]
df_food = df_food[df_food["energy_kcal_eaten"] > 0]

df_food.columns
# Out:
# C:\Users\Sophie\AppData\Local\Temp\ipykernel_3168\2341903789.py:1: DtypeWarning: Columns (2,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food = pd.read_csv("../data/df_food_filtered_with_food_group.csv",index_col=0)
# Index(['food_id', 'barcode', 'dish_id', 'eaten_quantity', 'eaten_unit',
#        'subject_key', 'eaten_at', 'eaten_at_utc_offset', 'media_count',
#        'food_group_cname', 'type', 'display_name_en', 'display_name_fr',
#        'display_name_de', 'fallback_food_id', 'standard_portion_quantity',
#        'standard_portion_unit', 'specific_gravity', 'alcohol',
#        'all_trans_retinol_equivalents_activity', 'beta_carotene',
#        'beta_carotene_activity', 'calcium', 'carbohydrates', 'chloride',
#        'cholesterol', 'energy_kcal', 'energy_kj', 'fat',
#        'fatty_acids_monounsaturated', 'fatty_acids_polyunsaturated',
#        'fatty_acids_saturated', 'fiber', 'folate', 'iodide', 'iron',
#        'magnesium', 'niacin', 'pantothenic_acid', 'phosphorus', 'potassium',
#        'protein', 'salt', 'sodium', 'starch', 'sugar', 'vitamin_a_activity',
#        'vitamin_b1', 'vitamin_b12', 'vitamin_b2', 'vitamin_b6', 'vitamin_c',
#        'vitamin_d', 'vitamin_e_activity', 'water', 'zinc',
#        'eaten_quantity_in_gram', 'energy_kcal_eaten', 'energy_kj_eaten',
#        'carb_eaten', 'fat_eaten', 'protein_eaten', 'fiber_eaten',
#        'alcohol_eaten', 'local_eaten_at', 'eaten_date', 'combined_name',
#        'all_trans_retinol_equivalents_activity_eaten', 'beta_carotene_eaten',
#        'calcium_eaten', 'cholesterol_eaten',
#        'fatty_acids_monounsaturated_eaten',
#        'fatty_acids_polyunsaturated_eaten', 'fatty_acids_saturated_eaten',
#        'folate_eaten', 'iron_eaten', 'magnesium_eaten', 'niacin_eaten',
#        'pantothenic_acid_eaten', 'phosphorus_eaten', 'potassium_eaten',
#        'salt_eaten', 'sodium_eaten', 'sugar_eaten', 'vitamin_b1_eaten',
#        'vitamin_b12_eaten', 'vitamin_b2_eaten', 'vitamin_b6_eaten',
#        'vitamin_c_eaten', 'vitamin_d_eaten', 'vitamin_e_activity_eaten',
#        'zinc_eaten', 'start_date', 'cohort', 'food_group'],
#       dtype='object')

# %%
df_food
# Out:
#         food_id        barcode  dish_id  eaten_quantity eaten_unit  \
# 0            13            NaN   335994          110.00          g
# 3            13            NaN   411384          100.00          g
# 4            25            NaN   202497           35.00          g
# 5            25            NaN   283397           35.00          g
# 6            25            NaN   266679           40.00          g
# ...         ...            ...      ...             ...        ...
# 514955    46573  4104420237155   426463           16.00          g
# 514956    46573  4104420237155   426838           16.00          g
# 514957    46575  5411188102809   423445          100.00          g
# 514958    46588  7618500940806   425332          100.00         ml
# 514959    46590  7613404894064   427468            0.25          l
#
#        subject_key             eaten_at  eaten_at_utc_offset  media_count  \
# 0           bjsqab  2022-02-15 18:06:27                   60            1
# 3           erv9jd  2023-01-18 13:08:53                   60            1
# 4           6ata8r  2021-03-30 13:52:23                  120            1
# 5           uzbc9s  2021-10-21 10:09:09                  120            1
# 6           fvh6kf  2021-09-19 10:14:35                  120            1
# ...            ...                  ...                  ...          ...
# 514955      pgeyqb  2023-03-13 15:16:39                   60            0
# 514956      pgeyqb  2023-03-13 15:30:54                   60            0
# 514957      kmxhmz  2023-02-25 08:18:11                   60            1
# 514958      pgeyqb  2023-03-06 18:31:08                   60            1
# 514959      vd3fgz  2023-03-21 21:37:40                   60            0
#
#                           food_group_cname  ... vitamin_b12_eaten  \
# 0       dairy_products_meat_fish_eggs_tofu  ...      2.310000e-06
# 3       dairy_products_meat_fish_eggs_tofu  ...      2.100000e-06
# 4                        vegetables_fruits  ...      0.000000e+00
# 5                        vegetables_fruits  ...      0.000000e+00
# 6                        vegetables_fruits  ...      0.000000e+00
# ...                                    ...  ...               ...
# 514955                        unclassified  ...      0.000000e+00
# 514956                        unclassified  ...      0.000000e+00
# 514957                        unclassified  ...      3.800000e-07
# 514958                        unclassified  ...      0.000000e+00
# 514959                        unclassified  ...      0.000000e+00
#
#        vitamin_b2_eaten vitamin_b6_eaten vitamin_c_eaten  vitamin_d_eaten  \
# 0              0.000275         0.000154         0.00000     0.000000e+00
# 3              0.000250         0.000140         0.00000     0.000000e+00
# 4              0.000010         0.000028         0.00315     0.000000e+00
# 5              0.000010         0.000028         0.00315     0.000000e+00
# 6              0.000012         0.000032         0.00360     0.000000e+00
# ...                 ...              ...             ...              ...
# 514955         0.000000         0.000000         0.00000     0.000000e+00
# 514956         0.000000         0.000000         0.00000     0.000000e+00
# 514957         0.000210         0.000000         0.00000     7.500000e-07
# 514958         0.000000         0.000000         0.01200     0.000000e+00
# 514959         0.000000         0.000000         0.00000     0.000000e+00
#
#         vitamin_e_activity_eaten zinc_eaten  start_date    cohort  \
# 0                          0.220   0.004730  2022-02-04  cohort_b
# 3                          0.200   0.004300  2023-01-10  cohort_b
# 4                          0.035   0.000035  2021-03-22  cohort_b
# 5                          0.035   0.000035  2021-10-19  cohort_b
# 6                          0.040   0.000040  2021-09-10  cohort_b
# ...                          ...        ...         ...       ...
# 514955                     0.000   0.000000  2023-03-01  cohort_b
# 514956                     0.000   0.000000  2023-03-01  cohort_b
# 514957                     0.000   0.000000  2023-02-12  cohort_b
# 514958                     0.000   0.000000  2023-03-01  cohort_b
# 514959                     0.000   0.000000  2023-03-13  cohort_b
#
#                     food_group
# 0            meat_fish_seafood
# 3            meat_fish_seafood
# 4                       fruits
# 5                       fruits
# 6                       fruits
# ...                        ...
# 514955         sweets_desserts
# 514956         sweets_desserts
# 514957      yogurt_fresh_dairy
# 514958  vegetable_fruit_juices
# 514959                    milk
#
# [317780 rows x 95 columns]

# %%
nutrient_units = {
    "sugar": "g",
    "fatty_acids_saturated": "g",
    "salt": "g",
    "fatty_acids_monounsaturated": "g",
    "fatty_acids_polyunsaturated": "g",
    "cholesterol": "mg",
    # "vitamin_a": "IU",
    "all_trans_retinol_equivalents_activity": "mcg",
    "vitamin_c": "mg",
    "beta_carotene": "mcg",
    # "vitamin_e": "TAE",
    #"vitamin_e_activity": "TAE",
    'vitamin_e_activity':'mg',
    "vitamin_d": "mcg",
    # "vitamin_k": "mcg",
    # "thiamin": "mg",
    # "riboflavin": "mg",
    "niacin": "mg",
    "vitamin_b6": "mg",
    "folate": "mcg",
    "vitamin_b12": "mcg",
    "calcium": "mg",
    "phosphorus": "mg",
    "magnesium": "mg",
    "iron": "mg",
    "zinc": "mg",
    # "copper": "mg",
    # "selenium": "mcg",
    "potassium": "mg",
    "sodium": "mg",
    # "caffeine": "mg",
    # "theobromine": "mg",
    "pantothenic_acid": "mg",
    "vitamin_b1": "mg",
    "vitamin_b2": "mg",
    "protein":"g",
    "fiber":"g",
}

conversion_factors = {
    "mg": 1000,
    "g": 1,
    "mcg": 1000000,
    "IU": 1,
    "TAE": 1,
}

# %%
df_food['beta_carotene_eaten'].describe()
# Out:
# count    317780.000000
# mean          0.000147
# std           0.000782
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000022
# max           0.034995
# Name: beta_carotene_eaten, dtype: float64

# %%
def scale_for_nbc(df, nutrient_cols, scaling_factor=2000):
    df = df.copy()

    for nutr in nutrient_cols:
        conversion_factor = conversion_factors[nutrient_units[nutr]]
        # df_food[nutr + "_eaten"].fillna(0, inplace=True)

        df[nutr + "_scaled"] = (
            df[nutr + "_eaten"]
            * (scaling_factor / df["energy_kcal_eaten"])
            * conversion_factor
        )
        if nutr == 'beta_carotene':
            print(f'df[nutr + "_scaled"] = ({df[nutr+"_eaten"]} * ({scaling_factor} / {df["energy_kcal_eaten"]})* {conversion_factor})')

    return df


t = scale_for_nbc(df_food.fillna(0), list(nutrient_units.keys()), scaling_factor=2000)
# Out:
# df[nutr + "_scaled"] = (0         0.000005
# 3         0.000005
# 4         0.000000
# 5         0.000000
# 6         0.000000
#             ...
# 514955    0.000000
# 514956    0.000000
# 514957    0.000000
# 514958    0.000000
# 514959    0.000000
# Name: beta_carotene_eaten, Length: 317780, dtype: float64 * (2000 / 0         163.90
# 3         149.00
# 4          17.85
# 5          17.85
# 6          20.40
#            ...
# 514955     60.64
# 514956     60.64
# 514957     73.00
# 514958     22.00
# 514959    170.00
# Name: energy_kcal_eaten, Length: 317780, dtype: float64)* 1000000)

# %%
t['beta_carotene_scaled'].describe()
# Out:
# count    317780.000000
# mean      13481.176036
# std       55955.059693
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%         585.365854
# max      468571.428571
# Name: beta_carotene_scaled, dtype: float64

# %%
t.to_csv('t.csv',index = False)

# %%
t
# Out:
#         food_id        barcode  dish_id  eaten_quantity eaten_unit  \
# 0            13              0   335994          110.00          g
# 3            13              0   411384          100.00          g
# 4            25              0   202497           35.00          g
# 5            25              0   283397           35.00          g
# 6            25              0   266679           40.00          g
# ...         ...            ...      ...             ...        ...
# 514955    46573  4104420237155   426463           16.00          g
# 514956    46573  4104420237155   426838           16.00          g
# 514957    46575  5411188102809   423445          100.00          g
# 514958    46588  7618500940806   425332          100.00         ml
# 514959    46590  7613404894064   427468            0.25          l
#
#        subject_key             eaten_at  eaten_at_utc_offset  media_count  \
# 0           bjsqab  2022-02-15 18:06:27                   60            1
# 3           erv9jd  2023-01-18 13:08:53                   60            1
# 4           6ata8r  2021-03-30 13:52:23                  120            1
# 5           uzbc9s  2021-10-21 10:09:09                  120            1
# 6           fvh6kf  2021-09-19 10:14:35                  120            1
# ...            ...                  ...                  ...          ...
# 514955      pgeyqb  2023-03-13 15:16:39                   60            0
# 514956      pgeyqb  2023-03-13 15:30:54                   60            0
# 514957      kmxhmz  2023-02-25 08:18:11                   60            1
# 514958      pgeyqb  2023-03-06 18:31:08                   60            1
# 514959      vd3fgz  2023-03-21 21:37:40                   60            0
#
#                           food_group_cname  ... magnesium_scaled iron_scaled  \
# 0       dairy_products_meat_fish_eggs_tofu  ...       416.107383   32.214765
# 3       dairy_products_meat_fish_eggs_tofu  ...       416.107383   32.214765
# 4                        vegetables_fruits  ...       588.235294   11.764706
# 5                        vegetables_fruits  ...       588.235294   11.764706
# 6                        vegetables_fruits  ...       588.235294   11.764706
# ...                                    ...  ...              ...         ...
# 514955                        unclassified  ...         0.000000    0.000000
# 514956                        unclassified  ...         0.000000    0.000000
# 514957                        unclassified  ...         0.000000    0.000000
# 514958                        unclassified  ...         0.000000    0.000000
# 514959                        unclassified  ...         0.000000    0.000000
#
#        zinc_scaled potassium_scaled  sodium_scaled  pantothenic_acid_scaled  \
# 0        57.718121      4026.845638    1033.557047                 9.395973
# 3        57.718121      4026.845638    1033.557047                 9.395973
# 4         3.921569      5098.039216      78.431373                 6.666667
# 5         3.921569      5098.039216      78.431373                 6.666667
# 6         3.921569      5098.039216      78.431373                 6.666667
# ...            ...              ...            ...                      ...
# 514955    0.000000         0.000000       0.000000                 0.000000
# 514956    0.000000         0.000000       0.000000                 0.000000
# 514957    0.000000         0.000000       0.000000                 0.000000
# 514958    0.000000         0.000000       0.000000                 0.000000
# 514959    0.000000         0.000000       0.000000                 0.000000
#
#        vitamin_b1_scaled  vitamin_b2_scaled  protein_scaled  fiber_scaled
# 0               1.342282           3.355705      365.100671      0.000000
# 3               1.342282           3.355705      365.100671      0.000000
# 4               2.352941           1.176471       15.686275     54.901961
# 5               2.352941           1.176471       15.686275     54.901961
# 6               2.352941           1.176471       15.686275     54.901961
# ...                  ...                ...             ...           ...
# 514955          0.000000           0.000000       42.216359     22.163588
# 514956          0.000000           0.000000       42.216359     22.163588
# 514957          0.000000           5.753425       98.630137     32.876712
# 514958          0.000000           0.000000       54.545455      0.000000
# 514959          0.000000           0.000000       94.117647      0.000000
#
# [317780 rows x 122 columns]

# %%
t.columns[95:]
# Out:
# Index(['sugar_scaled', 'fatty_acids_saturated_scaled', 'salt_scaled',
#        'fatty_acids_monounsaturated_scaled',
#        'fatty_acids_polyunsaturated_scaled', 'cholesterol_scaled',
#        'all_trans_retinol_equivalents_activity_scaled', 'vitamin_c_scaled',
#        'beta_carotene_scaled', 'vitamin_e_activity_scaled', 'vitamin_d_scaled',
#        'niacin_scaled', 'vitamin_b6_scaled', 'folate_scaled',
#        'vitamin_b12_scaled', 'calcium_scaled', 'phosphorus_scaled',
#        'magnesium_scaled', 'iron_scaled', 'zinc_scaled', 'potassium_scaled',
#        'sodium_scaled', 'pantothenic_acid_scaled', 'vitamin_b1_scaled',
#        'vitamin_b2_scaled', 'protein_scaled', 'fiber_scaled'],
#       dtype='object')

# %%
t['beta_carotene_scaled']
# Out:
# 0         67.114094
# 3         67.114094
# 4          0.000000
# 5          0.000000
# 6          0.000000
#             ...
# 514955     0.000000
# 514956     0.000000
# 514957     0.000000
# 514958     0.000000
# 514959     0.000000
# Name: beta_carotene_scaled, Length: 317780, dtype: float64

# %%
t[[i for i in t.columns if "scaled" in i]].columns
# Out:
# Index(['sugar_scaled', 'fatty_acids_saturated_scaled', 'salt_scaled',
#        'fatty_acids_monounsaturated_scaled',
#        'fatty_acids_polyunsaturated_scaled', 'cholesterol_scaled',
#        'all_trans_retinol_equivalents_activity_scaled', 'vitamin_c_scaled',
#        'beta_carotene_scaled', 'vitamin_e_activity_scaled', 'vitamin_d_scaled',
#        'niacin_scaled', 'vitamin_b6_scaled', 'folate_scaled',
#        'vitamin_b12_scaled', 'calcium_scaled', 'phosphorus_scaled',
#        'magnesium_scaled', 'iron_scaled', 'zinc_scaled', 'potassium_scaled',
#        'sodium_scaled', 'pantothenic_acid_scaled', 'vitamin_b1_scaled',
#        'vitamin_b2_scaled', 'protein_scaled', 'fiber_scaled'],
#       dtype='object')

# %%
t[t["iron_scaled"] > 18].drop_duplicates("combined_name")["combined_name"]
# Out:
# 0         Lamb, filet, pan fried, medium, without additi...
# 66                                 Anchovy, in oil, drained
# 114       Berries, (average), cooked, without addition o...
# 126             Beetroot, steamed, without addition of salt
# 1014      Beef, entrecote, pan fried, medium, without ad...
#                                 ...
# 514279           Planted. - Chicken Curry, 100% plant-based
# 514401                                       CHOCOLATE CHIP
# 514717                                          PROTEIN BAR
# 514877                          Beavita - Shake (Chocolate)
# 514934                                             ovosport
# Name: combined_name, Length: 1037, dtype: object

# %%
t[t["folate_scaled"] > 400].drop_duplicates("combined_name")["combined_name"]
# Out:
# 114       Berries, (average), cooked, without addition o...
# 126             Beetroot, steamed, without addition of salt
# 1010                                       Beaten egg white
# 1066            Broccoli, steamed, without addition of salt
# 1529              Carrot, steamed, without addition of salt
#                                 ...
# 513989                                     Ovomaltine Drink
# 514195                                Vitamin Well - Reload
# 514324                      Ovomaltine Drink - High Protein
# 514877                          Beavita - Shake (Chocolate)
# 514934                                             ovosport
# Name: combined_name, Length: 687, dtype: object

# %%
dri_dict = {
    "sugar_scaled": 125,
    "fatty_acids_saturated_scaled": 22,
    "salt_scaled": 6,
    "pantothenic_acid_scaled":5,
    "fatty_acids_monounsaturated_scaled": None,
    "fatty_acids_polyunsaturated_scaled": 12,
    "cholesterol_scaled": 300,
    "all_trans_retinol_equivalents_activity_scaled": 700,
    "vitamin_c_scaled": 75,
    "beta_carotene_scaled": 700,
    "vitamin_e_activity_scaled": 15,
    "vitamin_d_scaled": 7.5,
    "niacin_scaled": 14,
    "vitamin_b6_scaled": 1.3,
    "folate_scaled": 400,
    "vitamin_b12_scaled": 2.4,
    "calcium_scaled": 1000,
    "phosphorus_scaled": 700,
    "magnesium_scaled": 320,
    "iron_scaled": 18,
    "zinc_scaled": 8,
    "potassium_scaled": 4700,
    "sodium_scaled": 2400,
    "vitamin_b1_scaled":1.2,
    "vitamin_b2_scaled":1.1,
    "protein_scaled":46,
    "fiber_scaled":25,
}


# def calculate_qi_metric(row, nutrient_cols):

#     qi_ratios = []
#     for nutr in nutrient_cols:
#         qi_ratios.append(row[nutr] / dri_dict[nutr])

#     return np.mean(qi_ratios)

# %%
def calculate_qi_ratios(row, nutrient_cols):

    qi_ratios = {}
    for nutr in nutrient_cols:
        qi_ratios[nutr + "_ratio"] = row[nutr] / dri_dict[nutr]

    qi_ratios["qi_metric"] = np.sum([i for i in qi_ratios.values()]) / len(
        nutrient_cols
    )

    qi_ratios["combined_name"] = row["combined_name"]
    qi_ratios["food_group"] = row["food_group"]
    qi_ratios["energy_kcal_eaten"] = row["energy_kcal_eaten"]
    qi_ratios["eaten_quantity_in_gram"] = row["eaten_quantity_in_gram"]

    return qi_ratios

# %%
qi_nutrients = [
    "all_trans_retinol_equivalents_activity_scaled",
    "vitamin_c_scaled",
    "vitamin_e_activity_scaled",
    "vitamin_d_scaled",
    "niacin_scaled",
    "vitamin_b6_scaled",
    "folate_scaled",
    "vitamin_b12_scaled",
    "calcium_scaled",
    "phosphorus_scaled",
    "magnesium_scaled",
    "iron_scaled",
    "zinc_scaled",
    "potassium_scaled",
    "pantothenic_acid_scaled",
    "vitamin_b1_scaled",
    "vitamin_b2_scaled",
    "protein_scaled",
    "fiber_scaled",
    "beta_carotene_scaled",
    # "fatty_acids_polyunsaturated_scaled",
]

# %%
qi_ratios = t.apply(calculate_qi_ratios, axis=1, nutrient_cols=qi_nutrients)

qi_ratios = qi_ratios.apply(pd.Series)

qi_ratios
# Out:
#         all_trans_retinol_equivalents_activity_scaled_ratio  \
# 0                                           230105.465005
# 3                                           230105.465005
# 4                                                0.000000
# 5                                                0.000000
# 6                                                0.000000
# ...                                                   ...
# 514955                                           0.000000
# 514956                                           0.000000
# 514957                                           0.000000
# 514958                                           0.000000
# 514959                                           0.000000
#
#         vitamin_c_scaled_ratio  vitamin_e_activity_scaled_ratio  \
# 0                     0.000000                       178.970917
# 3                     0.000000                       178.970917
# 4                     4.705882                       261.437908
# 5                     4.705882                       261.437908
# 6                     4.705882                       261.437908
# ...                        ...                              ...
# 514955                0.000000                         0.000000
# 514956                0.000000                         0.000000
# 514957                0.000000                         0.000000
# 514958               14.545455                         0.000000
# 514959                0.000000                         0.000000
#
#         vitamin_d_scaled_ratio  niacin_scaled_ratio  vitamin_b6_scaled_ratio  \
# 0                     0.000000             5.848514                 1.445534
# 3                     0.000000             5.848514                 1.445534
# 4                     0.000000             0.756303                 2.413273
# 5                     0.000000             0.756303                 2.413273
# 6                     0.000000             0.756303                 2.413273
# ...                        ...                  ...                      ...
# 514955                0.000000             0.000000                 0.000000
# 514956                0.000000             0.000000                 0.000000
# 514957                2.739726             0.000000                 0.000000
# 514958                0.000000             0.000000                 0.000000
# 514959                0.000000             0.000000                 0.000000
#
#         folate_scaled_ratio  vitamin_b12_scaled_ratio  calcium_scaled_ratio  \
# 0                  0.872483                 11.744966              0.187919
# 3                  0.872483                 11.744966              0.187919
# 4                  0.686275                  0.000000              0.549020
# 5                  0.686275                  0.000000              0.549020
# 6                  0.686275                  0.000000              0.549020
# ...                     ...                       ...                   ...
# 514955             0.000000                  0.000000              0.000000
# 514956             0.000000                  0.000000              0.000000
# 514957             0.000000                  4.337900              3.287671
# 514958             0.000000                  0.000000              0.000000
# 514959             0.000000                  0.000000              3.529412
#
#         phosphorus_scaled_ratio  ...  vitamin_b1_scaled_ratio  \
# 0                      4.218600  ...                 1.118568
# 3                      4.218600  ...                 1.118568
# 4                      0.616246  ...                 1.960784
# 5                      0.616246  ...                 1.960784
# 6                      0.616246  ...                 1.960784
# ...                         ...  ...                      ...
# 514955                 0.000000  ...                 0.000000
# 514956                 0.000000  ...                 0.000000
# 514957                 0.000000  ...                 0.000000
# 514958                 0.000000  ...                 0.000000
# 514959                 0.000000  ...                 0.000000
#
#         vitamin_b2_scaled_ratio  protein_scaled_ratio  fiber_scaled_ratio  \
# 0                      3.050641              7.936971            0.000000
# 3                      3.050641              7.936971            0.000000
# 4                      1.069519              0.341006            2.196078
# 5                      1.069519              0.341006            2.196078
# 6                      1.069519              0.341006            2.196078
# ...                         ...                   ...                 ...
# 514955                 0.000000              0.917747            0.886544
# 514956                 0.000000              0.917747            0.886544
# 514957                 5.230386              2.144133            1.315068
# 514958                 0.000000              1.185771            0.000000
# 514959                 0.000000              2.046036            0.000000
#
#         beta_carotene_scaled_ratio     qi_metric  \
# 0                         0.095877  11516.699839
# 3                         0.095877  11516.699839
# 4                         0.000000     14.106617
# 5                         0.000000     14.106617
# 6                         0.000000     14.106617
# ...                            ...           ...
# 514955                    0.000000      0.090215
# 514956                    0.000000      0.090215
# 514957                    0.000000      0.952744
# 514958                    0.000000      0.786561
# 514959                    0.000000      0.278772
#
#                                             combined_name  \
# 0       Lamb, filet, pan fried, medium, without additi...
# 3       Lamb, filet, pan fried, medium, without additi...
# 4                          Pineapple, unsweetened, canned
# 5                          Pineapple, unsweetened, canned
# 6                          Pineapple, unsweetened, canned
# ...                                                   ...
# 514955                      Alnatura - Kakao Knusper Reis
# 514956                      Alnatura - Kakao Knusper Reis
# 514957                      alpro - Joghurt (Heidelbeere)
# 514958                                  Biotta Sauerkraut
# 514959                        Migros Bio - Past Vollmilch
#
#                     food_group  energy_kcal_eaten  eaten_quantity_in_gram
# 0            meat_fish_seafood             163.90                   110.0
# 3            meat_fish_seafood             149.00                   100.0
# 4                       fruits              17.85                    35.0
# 5                       fruits              17.85                    35.0
# 6                       fruits              20.40                    40.0
# ...                        ...                ...                     ...
# 514955         sweets_desserts              60.64                    16.0
# 514956         sweets_desserts              60.64                    16.0
# 514957      yogurt_fresh_dairy              73.00                   100.0
# 514958  vegetable_fruit_juices              22.00                   100.0
# 514959                    milk             170.00                   250.0
#
# [317780 rows x 25 columns]

# %%
qi_ratios.head().T
# Out:
#                                                                                                     0  \
# all_trans_retinol_equivalents_activity_scaled_r...                                      230105.465005
# vitamin_c_scaled_ratio                                                                            0.0
# vitamin_e_activity_scaled_ratio                                                            178.970917
# vitamin_d_scaled_ratio                                                                            0.0
# niacin_scaled_ratio                                                                          5.848514
# vitamin_b6_scaled_ratio                                                                      1.445534
# folate_scaled_ratio                                                                          0.872483
# vitamin_b12_scaled_ratio                                                                    11.744966
# calcium_scaled_ratio                                                                         0.187919
# phosphorus_scaled_ratio                                                                        4.2186
# magnesium_scaled_ratio                                                                       1.300336
# iron_scaled_ratio                                                                            1.789709
# zinc_scaled_ratio                                                                            7.214765
# potassium_scaled_ratio                                                                       0.856776
# pantothenic_acid_scaled_ratio                                                                1.879195
# vitamin_b1_scaled_ratio                                                                      1.118568
# vitamin_b2_scaled_ratio                                                                      3.050641
# protein_scaled_ratio                                                                         7.936971
# fiber_scaled_ratio                                                                                0.0
# beta_carotene_scaled_ratio                                                                   0.095877
# qi_metric                                                                                11516.699839
# combined_name                                       Lamb, filet, pan fried, medium, without additi...
# food_group                                                                          meat_fish_seafood
# energy_kcal_eaten                                                                               163.9
# eaten_quantity_in_gram                                                                          110.0
#
#                                                                                                     3  \
# all_trans_retinol_equivalents_activity_scaled_r...                                      230105.465005
# vitamin_c_scaled_ratio                                                                            0.0
# vitamin_e_activity_scaled_ratio                                                            178.970917
# vitamin_d_scaled_ratio                                                                            0.0
# niacin_scaled_ratio                                                                          5.848514
# vitamin_b6_scaled_ratio                                                                      1.445534
# folate_scaled_ratio                                                                          0.872483
# vitamin_b12_scaled_ratio                                                                    11.744966
# calcium_scaled_ratio                                                                         0.187919
# phosphorus_scaled_ratio                                                                        4.2186
# magnesium_scaled_ratio                                                                       1.300336
# iron_scaled_ratio                                                                            1.789709
# zinc_scaled_ratio                                                                            7.214765
# potassium_scaled_ratio                                                                       0.856776
# pantothenic_acid_scaled_ratio                                                                1.879195
# vitamin_b1_scaled_ratio                                                                      1.118568
# vitamin_b2_scaled_ratio                                                                      3.050641
# protein_scaled_ratio                                                                         7.936971
# fiber_scaled_ratio                                                                                0.0
# beta_carotene_scaled_ratio                                                                   0.095877
# qi_metric                                                                                11516.699839
# combined_name                                       Lamb, filet, pan fried, medium, without additi...
# food_group                                                                          meat_fish_seafood
# energy_kcal_eaten                                                                               149.0
# eaten_quantity_in_gram                                                                          100.0
#
#                                                                                  4  \
# all_trans_retinol_equivalents_activity_scaled_r...                             0.0
# vitamin_c_scaled_ratio                                                    4.705882
# vitamin_e_activity_scaled_ratio                                         261.437908
# vitamin_d_scaled_ratio                                                         0.0
# niacin_scaled_ratio                                                       0.756303
# vitamin_b6_scaled_ratio                                                   2.413273
# folate_scaled_ratio                                                       0.686275
# vitamin_b12_scaled_ratio                                                       0.0
# calcium_scaled_ratio                                                       0.54902
# phosphorus_scaled_ratio                                                   0.616246
# magnesium_scaled_ratio                                                    1.838235
# iron_scaled_ratio                                                         0.653595
# zinc_scaled_ratio                                                         0.490196
# potassium_scaled_ratio                                                    1.084689
# pantothenic_acid_scaled_ratio                                             1.333333
# vitamin_b1_scaled_ratio                                                   1.960784
# vitamin_b2_scaled_ratio                                                   1.069519
# protein_scaled_ratio                                                      0.341006
# fiber_scaled_ratio                                                        2.196078
# beta_carotene_scaled_ratio                                                     0.0
# qi_metric                                                                14.106617
# combined_name                                       Pineapple, unsweetened, canned
# food_group                                                                  fruits
# energy_kcal_eaten                                                            17.85
# eaten_quantity_in_gram                                                        35.0
#
#                                                                                  5  \
# all_trans_retinol_equivalents_activity_scaled_r...                             0.0
# vitamin_c_scaled_ratio                                                    4.705882
# vitamin_e_activity_scaled_ratio                                         261.437908
# vitamin_d_scaled_ratio                                                         0.0
# niacin_scaled_ratio                                                       0.756303
# vitamin_b6_scaled_ratio                                                   2.413273
# folate_scaled_ratio                                                       0.686275
# vitamin_b12_scaled_ratio                                                       0.0
# calcium_scaled_ratio                                                       0.54902
# phosphorus_scaled_ratio                                                   0.616246
# magnesium_scaled_ratio                                                    1.838235
# iron_scaled_ratio                                                         0.653595
# zinc_scaled_ratio                                                         0.490196
# potassium_scaled_ratio                                                    1.084689
# pantothenic_acid_scaled_ratio                                             1.333333
# vitamin_b1_scaled_ratio                                                   1.960784
# vitamin_b2_scaled_ratio                                                   1.069519
# protein_scaled_ratio                                                      0.341006
# fiber_scaled_ratio                                                        2.196078
# beta_carotene_scaled_ratio                                                     0.0
# qi_metric                                                                14.106617
# combined_name                                       Pineapple, unsweetened, canned
# food_group                                                                  fruits
# energy_kcal_eaten                                                            17.85
# eaten_quantity_in_gram                                                        35.0
#
#                                                                                  6
# all_trans_retinol_equivalents_activity_scaled_r...                             0.0
# vitamin_c_scaled_ratio                                                    4.705882
# vitamin_e_activity_scaled_ratio                                         261.437908
# vitamin_d_scaled_ratio                                                         0.0
# niacin_scaled_ratio                                                       0.756303
# vitamin_b6_scaled_ratio                                                   2.413273
# folate_scaled_ratio                                                       0.686275
# vitamin_b12_scaled_ratio                                                       0.0
# calcium_scaled_ratio                                                       0.54902
# phosphorus_scaled_ratio                                                   0.616246
# magnesium_scaled_ratio                                                    1.838235
# iron_scaled_ratio                                                         0.653595
# zinc_scaled_ratio                                                         0.490196
# potassium_scaled_ratio                                                    1.084689
# pantothenic_acid_scaled_ratio                                             1.333333
# vitamin_b1_scaled_ratio                                                   1.960784
# vitamin_b2_scaled_ratio                                                   1.069519
# protein_scaled_ratio                                                      0.341006
# fiber_scaled_ratio                                                        2.196078
# beta_carotene_scaled_ratio                                                     0.0
# qi_metric                                                                14.106617
# combined_name                                       Pineapple, unsweetened, canned
# food_group                                                                  fruits
# energy_kcal_eaten                                                             20.4
# eaten_quantity_in_gram                                                        40.0

# %%
qi_ratios[qi_ratios['food_group']=='vegetables'].drop_duplicates('combined_name').describe().T
# Out:
#                                                     count          mean  \
# all_trans_retinol_equivalents_activity_scaled_r...  389.0  16819.813660
# vitamin_c_scaled_ratio                              389.0      9.919384
# vitamin_e_activity_scaled_ratio                     389.0   1768.071455
# vitamin_d_scaled_ratio                              389.0      1.107098
# niacin_scaled_ratio                                 389.0      2.738122
# vitamin_b6_scaled_ratio                             389.0      3.185147
# folate_scaled_ratio                                 389.0      4.007080
# vitamin_b12_scaled_ratio                            389.0      0.115606
# calcium_scaled_ratio                                389.0      1.326748
# phosphorus_scaled_ratio                             389.0      2.757761
# magnesium_scaled_ratio                              389.0      2.144517
# iron_scaled_ratio                                   389.0      2.401499
# zinc_scaled_ratio                                   389.0      2.229860
# potassium_scaled_ratio                              389.0      2.176185
# pantothenic_acid_scaled_ratio                       389.0      3.558950
# vitamin_b1_scaled_ratio                             389.0      2.506731
# vitamin_b2_scaled_ratio                             389.0      3.334916
# protein_scaled_ratio                                389.0      2.434769
# fiber_scaled_ratio                                  389.0      5.853346
# beta_carotene_scaled_ratio                          389.0     45.812140
# qi_metric                                           389.0    934.274749
# energy_kcal_eaten                                   389.0     46.440244
# eaten_quantity_in_gram                              389.0     91.348329
#
#                                                               std   min  \
# all_trans_retinol_equivalents_activity_scaled_r...  147109.665975  0.00
# vitamin_c_scaled_ratio                                  21.329486  0.00
# vitamin_e_activity_scaled_ratio                       4464.107572  0.00
# vitamin_d_scaled_ratio                                   5.601688  0.00
# niacin_scaled_ratio                                      7.415955  0.00
# vitamin_b6_scaled_ratio                                  6.101241  0.00
# folate_scaled_ratio                                      7.310495  0.00
# vitamin_b12_scaled_ratio                                 1.382946  0.00
# calcium_scaled_ratio                                     2.265830  0.00
# phosphorus_scaled_ratio                                  6.412796  0.00
# magnesium_scaled_ratio                                   4.672643  0.00
# iron_scaled_ratio                                        7.166606  0.00
# zinc_scaled_ratio                                        8.797529  0.00
# potassium_scaled_ratio                                   3.465383  0.00
# pantothenic_acid_scaled_ratio                            8.281755  0.00
# vitamin_b1_scaled_ratio                                  8.129496  0.00
# vitamin_b2_scaled_ratio                                  8.496069  0.00
# protein_scaled_ratio                                     1.555911  0.00
# fiber_scaled_ratio                                       4.449622  0.00
# beta_carotene_scaled_ratio                             120.691990  0.00
# qi_metric                                             7357.827284  0.00
# energy_kcal_eaten                                       64.736327  0.46
# eaten_quantity_in_gram                                  84.255197  1.00
#
#                                                           25%         50%  \
# all_trans_retinol_equivalents_activity_scaled_r...   0.000000    0.000000
# vitamin_c_scaled_ratio                               0.000000    1.253188
# vitamin_e_activity_scaled_ratio                      0.000000  190.476190
# vitamin_d_scaled_ratio                               0.000000    0.000000
# niacin_scaled_ratio                                  0.000000    0.714286
# vitamin_b6_scaled_ratio                              0.000000    1.136794
# folate_scaled_ratio                                  0.000000    0.875000
# vitamin_b12_scaled_ratio                             0.000000    0.000000
# calcium_scaled_ratio                                 0.000000    0.516667
# phosphorus_scaled_ratio                              0.000000    1.584158
# magnesium_scaled_ratio                               0.000000    1.123047
# iron_scaled_ratio                                    0.000000    0.675676
# zinc_scaled_ratio                                    0.000000    0.757576
# potassium_scaled_ratio                               0.000000    0.879433
# pantothenic_acid_scaled_ratio                        0.000000    0.028986
# vitamin_b1_scaled_ratio                              0.000000    0.680272
# vitamin_b2_scaled_ratio                              0.000000    0.886918
# protein_scaled_ratio                                 1.242236    2.103787
# fiber_scaled_ratio                                   2.962963    5.307692
# beta_carotene_scaled_ratio                           0.000000    0.000000
# qi_metric                                            0.413043   15.702082
# energy_kcal_eaten                                   10.200000   23.600000
# eaten_quantity_in_gram                              30.000000   60.000000
#
#                                                             75%           max
# all_trans_retinol_equivalents_activity_scaled_r...     0.000000  1.696429e+06
# vitamin_c_scaled_ratio                                 9.696970  1.456410e+02
# vitamin_e_activity_scaled_ratio                     1600.000000  5.230769e+04
# vitamin_d_scaled_ratio                                 0.000000  5.777778e+01
# niacin_scaled_ratio                                    2.747253  8.928571e+01
# vitamin_b6_scaled_ratio                                5.494505  9.467456e+01
# folate_scaled_ratio                                    5.000000  6.176471e+01
# vitamin_b12_scaled_ratio                               0.000000  1.927083e+01
# calcium_scaled_ratio                                   1.631579  1.882353e+01
# phosphorus_scaled_ratio                                3.896104  1.065934e+02
# magnesium_scaled_ratio                                 2.777778  6.009615e+01
# iron_scaled_ratio                                      2.525253  1.111111e+02
# zinc_scaled_ratio                                      2.678571  1.634615e+02
# potassium_scaled_ratio                                 3.624901  4.148936e+01
# pantothenic_acid_scaled_ratio                          3.478261  8.333333e+01
# vitamin_b1_scaled_ratio                                3.658537  1.474359e+02
# vitamin_b2_scaled_ratio                                3.519062  1.287879e+02
# protein_scaled_ratio                                   3.432494  8.009153e+00
# fiber_scaled_ratio                                     8.000000  3.800000e+01
# beta_carotene_scaled_ratio                            14.126984  6.693878e+02
# qi_metric                                             96.809682  8.494717e+04
# energy_kcal_eaten                                     52.500000  5.460000e+02
# eaten_quantity_in_gram                               120.000000  5.000000e+02

# %%
qi_ratios[qi_ratios['food_group']=='yogurt_fresh_dairy'].drop_duplicates('combined_name').describe().T
# Out:
#                                                     count           mean  \
# all_trans_retinol_equivalents_activity_scaled_r...  643.0  423776.815787
# vitamin_c_scaled_ratio                              643.0       0.323484
# vitamin_e_activity_scaled_ratio                     643.0     154.627433
# vitamin_d_scaled_ratio                              643.0       0.215533
# niacin_scaled_ratio                                 643.0       0.126024
# vitamin_b6_scaled_ratio                             643.0       7.908662
# folate_scaled_ratio                                 643.0       0.453293
# vitamin_b12_scaled_ratio                            643.0       2.165755
# calcium_scaled_ratio                                643.0       1.627868
# phosphorus_scaled_ratio                             643.0       1.853910
# magnesium_scaled_ratio                              643.0       0.458320
# iron_scaled_ratio                                   643.0       0.051471
# zinc_scaled_ratio                                   643.0       0.672492
# potassium_scaled_ratio                              643.0       0.388090
# pantothenic_acid_scaled_ratio                       643.0       0.785808
# vitamin_b1_scaled_ratio                             643.0      29.687785
# vitamin_b2_scaled_ratio                             643.0       1.680679
# protein_scaled_ratio                                643.0       2.601059
# fiber_scaled_ratio                                  643.0       0.377515
# beta_carotene_scaled_ratio                          643.0       0.226646
# qi_metric                                           643.0   21199.152381
# energy_kcal_eaten                                   643.0     142.529887
# eaten_quantity_in_gram                              643.0     153.437792
#
#                                                               std   min  \
# all_trans_retinol_equivalents_activity_scaled_r...  589565.897048   0.0
# vitamin_c_scaled_ratio                                   0.972726   0.0
# vitamin_e_activity_scaled_ratio                        520.701663   0.0
# vitamin_d_scaled_ratio                                   1.249029   0.0
# niacin_scaled_ratio                                      0.241898   0.0
# vitamin_b6_scaled_ratio                                 39.126441   0.0
# folate_scaled_ratio                                      1.272885   0.0
# vitamin_b12_scaled_ratio                                 2.760370   0.0
# calcium_scaled_ratio                                     1.753037   0.0
# phosphorus_scaled_ratio                                  2.155400   0.0
# magnesium_scaled_ratio                                   0.536054   0.0
# iron_scaled_ratio                                        0.132058   0.0
# zinc_scaled_ratio                                        0.902102   0.0
# potassium_scaled_ratio                                   0.469862   0.0
# pantothenic_acid_scaled_ratio                            0.976262   0.0
# vitamin_b1_scaled_ratio                                160.065962   0.0
# vitamin_b2_scaled_ratio                                  1.998096   0.0
# protein_scaled_ratio                                     1.763931   0.0
# fiber_scaled_ratio                                       0.923392   0.0
# beta_carotene_scaled_ratio                               0.821087   0.0
# qi_metric                                            29481.496254   0.0
# energy_kcal_eaten                                       67.558517  16.8
# eaten_quantity_in_gram                                  62.184994  10.0
#
#                                                            25%         50%  \
# all_trans_retinol_equivalents_activity_scaled_r...    0.000000    0.000000
# vitamin_c_scaled_ratio                                0.000000    0.000000
# vitamin_e_activity_scaled_ratio                       0.000000    0.000000
# vitamin_d_scaled_ratio                                0.000000    0.000000
# niacin_scaled_ratio                                   0.000000    0.000000
# vitamin_b6_scaled_ratio                               0.000000    0.229885
# folate_scaled_ratio                                   0.000000    0.000000
# vitamin_b12_scaled_ratio                              0.000000    0.846354
# calcium_scaled_ratio                                  0.000000    1.604651
# phosphorus_scaled_ratio                               0.000000    0.000000
# magnesium_scaled_ratio                                0.000000    0.000000
# iron_scaled_ratio                                     0.000000    0.000000
# zinc_scaled_ratio                                     0.000000    0.000000
# potassium_scaled_ratio                                0.000000    0.108955
# pantothenic_acid_scaled_ratio                         0.000000    0.000000
# vitamin_b1_scaled_ratio                               0.000000    0.000000
# vitamin_b2_scaled_ratio                               0.000000    0.000000
# protein_scaled_ratio                                  1.478287    1.811594
# fiber_scaled_ratio                                    0.000000    0.000000
# beta_carotene_scaled_ratio                            0.000000    0.000000
# qi_metric                                             0.128219    2.705360
# energy_kcal_eaten                                    94.000000  142.500000
# eaten_quantity_in_gram                              125.000000  150.000000
#
#                                                               75%  \
# all_trans_retinol_equivalents_activity_scaled_r...  757160.006860
# vitamin_c_scaled_ratio                                   0.459770
# vitamin_e_activity_scaled_ratio                        184.151205
# vitamin_d_scaled_ratio                                   0.000000
# niacin_scaled_ratio                                      0.168971
# vitamin_b6_scaled_ratio                                  1.161103
# folate_scaled_ratio                                      0.550000
# vitamin_b12_scaled_ratio                                 3.297316
# calcium_scaled_ratio                                     2.594821
# phosphorus_scaled_ratio                                  3.042520
# magnesium_scaled_ratio                                   0.841346
# iron_scaled_ratio                                        0.103842
# zinc_scaled_ratio                                        1.190476
# potassium_scaled_ratio                                   0.692269
# pantothenic_acid_scaled_ratio                            1.265306
# vitamin_b1_scaled_ratio                                  0.192685
# vitamin_b2_scaled_ratio                                  2.721840
# protein_scaled_ratio                                     3.077734
# fiber_scaled_ratio                                       0.416667
# beta_carotene_scaled_ratio                               0.349854
# qi_metric                                            37871.234625
# energy_kcal_eaten                                      181.800000
# eaten_quantity_in_gram                                 180.000000
#
#                                                              max
# all_trans_retinol_equivalents_activity_scaled_r...  5.306122e+06
# vitamin_c_scaled_ratio                              1.101449e+01
# vitamin_e_activity_scaled_ratio                     9.009009e+03
# vitamin_d_scaled_ratio                              1.877934e+01
# niacin_scaled_ratio                                 4.638219e+00
# vitamin_b6_scaled_ratio                             3.508772e+02
# folate_scaled_ratio                                 1.974359e+01
# vitamin_b12_scaled_ratio                            1.488095e+01
# calcium_scaled_ratio                                8.571429e+00
# phosphorus_scaled_ratio                             1.122449e+01
# magnesium_scaled_ratio                              3.030303e+00
# iron_scaled_ratio                                   2.597403e+00
# zinc_scaled_ratio                                   1.363636e+01
# potassium_scaled_ratio                              2.735562e+00
# pantothenic_acid_scaled_ratio                       5.142857e+00
# vitamin_b1_scaled_ratio                             1.432749e+03
# vitamin_b2_scaled_ratio                             1.045455e+01
# protein_scaled_ratio                                8.695652e+00
# fiber_scaled_ratio                                  1.505882e+01
# beta_carotene_scaled_ratio                          1.974026e+01
# qi_metric                                           2.653390e+05
# energy_kcal_eaten                                   7.560000e+02
# eaten_quantity_in_gram                              5.000000e+02

# %%
a = qi_ratios[['qi_metric', 'combined_name', 'food_group']].groupby('food_group').mean(numeric_only=True).sort_values('qi_metric')
a
# Out:
#                                    qi_metric
# food_group
# tofu_tempeh_seitan                  2.177403
# pulses                              3.196878
# vegetable_fruit_juices             65.400128
# fruits                             89.686130
# cooked_grains_pasta               128.324099
# nuts_seeds                        148.589181
# vegetable_oils                    212.079930
# soy_granules_textured_protein     333.301684
# sweetened_beverages               546.853400
# alcoholic_beverages               589.220317
# vegetables                        861.470560
# cereal_grains_starches           1821.106290
# potatoes                         3067.828530
# salty_snacks                     3846.584765
# breakfast_cereals                4760.065326
# bread_pastries                   5312.714786
# soups_sauces_condiments          5745.376327
# sweets_desserts                  7673.224680
# others                          11689.519773
# beverages                       14450.391508
# processed_foods                 16054.341775
# processed_meats                 27883.855590
# yogurt_fresh_dairy              34887.778192
# milk                            46380.120818
# soft_cheese                     73647.889933
# cream_based_foods               75952.542012
# meat_fish_seafood               90549.968115
# hard_semi_hard_cheese          101937.558008
# butter_margarine_spreads       114077.559206
# eggs                           153011.893452

# %%
qi_ratios.describe()
# Out:
#        all_trans_retinol_equivalents_activity_scaled_ratio  \
# count                                       3.177800e+05
# mean                                        4.002870e+05
# std                                         3.515382e+06
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         0.000000e+00
# max                                         2.421603e+08
#
#        vitamin_c_scaled_ratio  vitamin_e_activity_scaled_ratio  \
# count           317780.000000                    317780.000000
# mean                 4.261686                       972.178533
# std                 14.318611                      4407.515727
# min                  0.000000                         0.000000
# 25%                  0.000000                         0.000000
# 50%                  0.000000                       132.231405
# 75%                  0.993842                       629.629630
# max                220.994475                    350877.192982
#
#        vitamin_d_scaled_ratio  niacin_scaled_ratio  vitamin_b6_scaled_ratio  \
# count           317780.000000        317780.000000            317780.000000
# mean                 0.386326             1.716105                 3.546673
# std                  2.763487            12.708898                34.987105
# min                  0.000000             0.000000                 0.000000
# 25%                  0.000000             0.000000                 0.000000
# 50%                  0.000000             0.250289                 0.433369
# 75%                  0.000000             1.666667                 1.639344
# max                108.096871           962.406015              1709.401709
#
#        folate_scaled_ratio  vitamin_b12_scaled_ratio  calcium_scaled_ratio  \
# count        317780.000000             317780.000000         317780.000000
# mean              1.336722                  1.550485              1.261794
# std               4.324491                 16.543500              2.493453
# min               0.000000                  0.000000              0.000000
# 25%               0.000000                  0.000000              0.000000
# 50%               0.150177                  0.000000              0.181818
# 75%               0.716667                  0.000000              1.192547
# max             247.368421               2380.952381            126.315789
#
#        phosphorus_scaled_ratio  ...  potassium_scaled_ratio  \
# count            317780.000000  ...           317780.000000
# mean                  1.665848  ...                1.170699
# std                   2.574719  ...                3.372541
# min                   0.000000  ...                0.000000
# 25%                   0.000000  ...                0.000000
# 50%                   0.873016  ...                0.272777
# 75%                   3.000000  ...                1.319149
# max                 177.443609  ...              304.591265
#
#        pantothenic_acid_scaled_ratio  vitamin_b1_scaled_ratio  \
# count                  317780.000000            317780.000000
# mean                        3.915609                 4.629047
# std                        43.266940                55.288578
# min                         0.000000                 0.000000
# 25%                         0.000000                 0.000000
# 50%                         0.297521                 0.207039
# 75%                         1.428571                 1.239316
# max                      1142.857143              2087.719298
#
#        vitamin_b2_scaled_ratio  protein_scaled_ratio  fiber_scaled_ratio  \
# count            317780.000000         317780.000000       317780.000000
# mean                  2.827041              1.782079            1.897762
# std                  43.213469              2.276008            3.030249
# min                   0.000000              0.000000            0.000000
# 25%                   0.000000              0.543478            0.000000
# 50%                   0.375657              1.358696            0.776699
# 75%                   1.560671              2.173913            3.043478
# max                3511.961722            304.347826          151.578947
#
#        beta_carotene_scaled_ratio     qi_metric  energy_kcal_eaten  \
# count               317780.000000  3.177800e+05      317780.000000
# mean                    19.258823  2.006570e+04         105.359098
# std                     79.935800  1.757660e+05         117.319215
# min                      0.000000  0.000000e+00           0.006700
# 25%                      0.000000  1.881869e-01          23.520000
# 50%                      0.000000  1.430111e+01          74.600000
# 75%                      0.836237  3.315402e+02         144.000000
# max                    669.387755  1.210805e+07        2797.500000
#
#        eaten_quantity_in_gram
# count           317780.000000
# mean                79.673623
# std                 83.585647
# min                  0.020000
# 25%                 22.000000
# 50%                 50.000000
# 75%                100.000000
# max               3000.000000
#
# [8 rows x 23 columns]

# %%
qi_ratios[
    qi_ratios["combined_name"] == "Connie's Kitchen - Jalapeño Ketchup"
].drop_duplicates()
# Out:
#         all_trans_retinol_equivalents_activity_scaled_ratio  \
# 503267                                                0.0
#
#         vitamin_c_scaled_ratio  vitamin_e_activity_scaled_ratio  \
# 503267                     0.0                              0.0
#
#         vitamin_d_scaled_ratio  niacin_scaled_ratio  vitamin_b6_scaled_ratio  \
# 503267                     0.0                  0.0                      0.0
#
#         folate_scaled_ratio  vitamin_b12_scaled_ratio  calcium_scaled_ratio  \
# 503267                  0.0                       0.0                   0.0
#
#         phosphorus_scaled_ratio  ...  vitamin_b1_scaled_ratio  \
# 503267                      0.0  ...                      0.0
#
#         vitamin_b2_scaled_ratio  protein_scaled_ratio  fiber_scaled_ratio  \
# 503267                      0.0              0.917874            2.044444
#
#         beta_carotene_scaled_ratio  qi_metric  \
# 503267                         0.0   0.148116
#
#                               combined_name               food_group  \
# 503267  Connie's Kitchen - Jalapeño Ketchup  soups_sauces_condiments
#
#         energy_kcal_eaten  eaten_quantity_in_gram
# 503267               39.6                    44.0
#
# [1 rows x 25 columns]

# %%
qi_ratios.groupby("combined_name")["qi_metric"].median().sort_values(
    ascending=False
).sample(10)
# Out:
# combined_name
# Moist chocolate cake                                       0.054102
# MClassic - Mokka Joghurt (stichfest)                   38208.328022
# Roggenbrot mit Leinsamen                                   0.217088
# Planted. - Wie Poulet, aus Pflanzen (BBQ Marinade)         0.306017
# Alnatura - Tomaten Mark                                  319.806954
# Quince                                                    66.915678
# kolid - Rol baklava                                      123.448327
# Migros V-Love - Plant based  Coffee caramel swirl          0.034247
# Tenseup - Bio Whey protein                              1119.591149
# Coop Karma - Organic Spinach Falafel (with Spinach)        0.261003
# Name: qi_metric, dtype: float64

# %%
df_food["food_group"].value_counts()
# Out:
# food_group
# vegetables                       47567
# sweets_desserts                  30641
# bread_pastries                   25817
# soups_sauces_condiments          22818
# beverages                        22752
# fruits                           21730
# processed_foods                  11330
# butter_margarine_spreads         10517
# alcoholic_beverages              10505
# cereal_grains_starches            9849
# nuts_seeds                        9736
# hard_semi_hard_cheese             8957
# meat_fish_seafood                 8945
# others                            8562
# milk                              7394
# sweetened_beverages               7310
# processed_meats                   6720
# cream_based_foods                 5822
# yogurt_fresh_dairy                5784
# soft_cheese                       5558
# potatoes                          4987
# eggs                              4159
# breakfast_cereals                 3905
# pulses                            3763
# vegetable_fruit_juices            3541
# vegetable_oils                    3421
# salty_snacks                      3086
# tofu_tempeh_seitan                1132
# cooked_grains_pasta                770
# soy_granules_textured_protein      702
# Name: count, dtype: int64

# %%
qi_ratios[qi_ratios["food_group"] == "milk"].describe()
# Out:
#        all_trans_retinol_equivalents_activity_scaled_ratio  \
# count                                       7.394000e+03
# mean                                        9.270155e+05
# std                                         9.535654e+05
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         8.658009e+04
# 75%                                         1.932773e+06
# max                                         3.675676e+06
#
#        vitamin_c_scaled_ratio  vitamin_e_activity_scaled_ratio  \
# count             7394.000000                      7394.000000
# mean                 0.207940                       471.753566
# std                  0.203087                      1041.446448
# min                  0.000000                         0.000000
# 25%                  0.000000                         0.000000
# 50%                  0.327485                       215.686275
# 75%                  0.392157                       215.686275
# max                  1.178947                     18461.538462
#
#        vitamin_d_scaled_ratio  niacin_scaled_ratio  vitamin_b6_scaled_ratio  \
# count             7394.000000          7394.000000              7394.000000
# mean                 0.378494             0.147126                 0.399098
# std                  2.780186             0.156931                 0.480906
# min                  0.000000             0.000000                 0.000000
# 25%                  0.000000             0.000000                 0.000000
# 50%                  0.392157             0.210084                 0.539811
# 75%                  0.392157             0.210084                 0.678733
# max                102.564103             1.098901                 4.895105
#
#        folate_scaled_ratio  vitamin_b12_scaled_ratio  calcium_scaled_ratio  \
# count          7394.000000               7394.000000           7394.000000
# mean              0.311858                  0.974813              2.388794
# std               0.247401                  1.508140              2.204304
# min               0.000000                  0.000000              0.000000
# 25%               0.000000                  0.000000              0.046948
# 50%               0.367647                  1.470588              3.529412
# 75%               0.367647                  1.470588              3.529412
# max               0.968182                 24.358974             18.461538
#
#        phosphorus_scaled_ratio  ...  potassium_scaled_ratio  \
# count              7394.000000  ...             7394.000000
# mean                  2.392003  ...                0.631633
# std                   2.129300  ...                0.528670
# min                   0.000000  ...                0.000000
# 25%                   0.000000  ...                0.000000
# 50%                   3.823529  ...                1.001252
# 75%                   3.865546  ...                1.001252
# max                  12.355212  ...                2.063185
#
#        pantothenic_acid_scaled_ratio  vitamin_b1_scaled_ratio  \
# count                    7394.000000              7394.000000
# mean                      100.049698                 0.482063
# std                       252.396975                 0.446395
# min                         0.000000                 0.000000
# 25%                         0.000000                 0.000000
# 50%                         2.588235                 0.490196
# 75%                         2.588235                 0.497512
# max                       957.575758                 4.292929
#
#        vitamin_b2_scaled_ratio  protein_scaled_ratio  fiber_scaled_ratio  \
# count              7394.000000           7394.000000         7394.000000
# mean                  2.547317              1.963864            0.433261
# std                   2.641784              1.317430            0.932299
# min                   0.000000              0.000000            0.000000
# 25%                   0.000000              1.026036            0.000000
# 50%                   4.010695              2.109974            0.000000
# 75%                   4.010695              2.109974            0.000000
# max                  29.370629              7.803790            6.690909
#
#        beta_carotene_scaled_ratio      qi_metric  energy_kcal_eaten  \
# count                 7394.000000    7394.000000        7394.000000
# mean                     0.355007   46380.120818          66.747878
# std                      0.361751   47661.766849          66.266142
# min                      0.000000       0.000000           0.067500
# 25%                      0.000000       0.408514          21.300000
# 50%                      0.086580    4331.364156          42.600000
# 75%                      0.714286   96650.650309          92.800000
# max                      1.760618  183805.779785         680.000000
#
#        eaten_quantity_in_gram
# count             7394.000000
# mean               103.417732
# std                 85.159220
# min                  0.300000
# 25%                 40.000000
# 50%                100.000000
# 75%                150.000000
# max               1000.000000
#
# [8 rows x 23 columns]

# %%
qi_ratios[qi_ratios["combined_name"] == "Milk"].describe().round(3)
# Out:
#        all_trans_retinol_equivalents_activity_scaled_ratio  \
# count                                           3020.000
# mean                                         1932773.109
# std                                                0.000
# min                                          1932773.109
# 25%                                          1932773.109
# 50%                                          1932773.109
# 75%                                          1932773.109
# max                                          1932773.109
#
#        vitamin_c_scaled_ratio  vitamin_e_activity_scaled_ratio  \
# count                3020.000                         3020.000
# mean                    0.392                          215.686
# std                     0.000                            0.000
# min                     0.392                          215.686
# 25%                     0.392                          215.686
# 50%                     0.392                          215.686
# 75%                     0.392                          215.686
# max                     0.392                          215.686
#
#        vitamin_d_scaled_ratio  niacin_scaled_ratio  vitamin_b6_scaled_ratio  \
# count                3020.000              3020.00                 3020.000
# mean                    0.392                 0.21                    0.679
# std                     0.000                 0.00                    0.000
# min                     0.392                 0.21                    0.679
# 25%                     0.392                 0.21                    0.679
# 50%                     0.392                 0.21                    0.679
# 75%                     0.392                 0.21                    0.679
# max                     0.392                 0.21                    0.679
#
#        folate_scaled_ratio  vitamin_b12_scaled_ratio  calcium_scaled_ratio  \
# count             3020.000                  3020.000              3020.000
# mean                 0.368                     1.471                 3.529
# std                  0.000                     0.000                 0.000
# min                  0.368                     1.471                 3.529
# 25%                  0.368                     1.471                 3.529
# 50%                  0.368                     1.471                 3.529
# 75%                  0.368                     1.471                 3.529
# max                  0.368                     1.471                 3.529
#
#        phosphorus_scaled_ratio  ...  potassium_scaled_ratio  \
# count                 3020.000  ...                3020.000
# mean                     3.866  ...                   1.001
# std                      0.000  ...                   0.000
# min                      3.866  ...                   1.001
# 25%                      3.866  ...                   1.001
# 50%                      3.866  ...                   1.001
# 75%                      3.866  ...                   1.001
# max                      3.866  ...                   1.001
#
#        pantothenic_acid_scaled_ratio  vitamin_b1_scaled_ratio  \
# count                       3020.000                  3020.00
# mean                           2.588                     0.49
# std                            0.000                     0.00
# min                            2.588                     0.49
# 25%                            2.588                     0.49
# 50%                            2.588                     0.49
# 75%                            2.588                     0.49
# max                            2.588                     0.49
#
#        vitamin_b2_scaled_ratio  protein_scaled_ratio  fiber_scaled_ratio  \
# count                 3020.000               3020.00              3020.0
# mean                     4.011                  2.11                 0.0
# std                      0.000                  0.00                 0.0
# min                      4.011                  2.11                 0.0
# 25%                      4.011                  2.11                 0.0
# 50%                      4.011                  2.11                 0.0
# 75%                      4.011                  2.11                 0.0
# max                      4.011                  2.11                 0.0
#
#        beta_carotene_scaled_ratio  qi_metric  energy_kcal_eaten  \
# count                    3020.000    3020.00           3020.000
# mean                        0.714   96650.65             58.475
# std                         0.000       0.00             53.019
# min                         0.714   96650.65              0.340
# 25%                         0.714   96650.65             20.400
# 50%                         0.714   96650.65             34.000
# 75%                         0.714   96650.65             81.600
# max                         0.714   96650.65            680.000
#
#        eaten_quantity_in_gram
# count                3020.000
# mean                   85.992
# std                    77.969
# min                     0.500
# 25%                    30.000
# 50%                    50.000
# 75%                   120.000
# max                  1000.000
#
# [8 rows x 23 columns]

# %%
qi_ratios[qi_ratios["food_group"] == "milk"]["combined_name"].value_counts()
# Out:
# combined_name
# Milk                              3020
# Oat milk                           901
# Soya drink (soy milk)              633
# Coconut milk                       421
# Almond drink (almond milk)         263
#                                   ...
# Coop Karma - Haferdrink Mandel       1
# Barebells - Milkshake (Banana)       1
# Migros Bio - Past Drink Milch        1
# Yörem - Ayran                        1
# Migros Bio - Past Vollmilch          1
# Name: count, Length: 246, dtype: int64

# %%
qi_ratios[qi_ratios["combined_name"] == "Oat milk"].describe().round(3)
# Out:
#        all_trans_retinol_equivalents_activity_scaled_ratio  \
# count                                              901.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        vitamin_c_scaled_ratio  vitamin_e_activity_scaled_ratio  \
# count                   901.0                          901.000
# mean                      0.0                         1158.059
# std                       0.0                            0.000
# min                       0.0                         1158.059
# 25%                       0.0                         1158.059
# 50%                       0.0                         1158.059
# 75%                       0.0                         1158.059
# max                       0.0                         1158.059
#
#        vitamin_d_scaled_ratio  niacin_scaled_ratio  vitamin_b6_scaled_ratio  \
# count                   901.0                901.0                    901.0
# mean                      0.0                  0.0                      0.0
# std                       0.0                  0.0                      0.0
# min                       0.0                  0.0                      0.0
# 25%                       0.0                  0.0                      0.0
# 50%                       0.0                  0.0                      0.0
# 75%                       0.0                  0.0                      0.0
# max                       0.0                  0.0                      0.0
#
#        folate_scaled_ratio  vitamin_b12_scaled_ratio  calcium_scaled_ratio  \
# count               901.00                     901.0               901.000
# mean                  0.75                       0.0                 0.047
# std                   0.00                       0.0                 0.000
# min                   0.75                       0.0                 0.047
# 25%                   0.75                       0.0                 0.047
# 50%                   0.75                       0.0                 0.047
# 75%                   0.75                       0.0                 0.047
# max                   0.75                       0.0                 0.047
#
#        phosphorus_scaled_ratio  ...  potassium_scaled_ratio  \
# count                  901.000  ...                  901.00
# mean                     0.738  ...                    0.32
# std                      0.000  ...                    0.00
# min                      0.738  ...                    0.32
# 25%                      0.738  ...                    0.32
# 50%                      0.738  ...                    0.32
# 75%                      0.738  ...                    0.32
# max                      0.738  ...                    0.32
#
#        pantothenic_acid_scaled_ratio  vitamin_b1_scaled_ratio  \
# count                        901.000                  901.000
# mean                         741.784                    1.135
# std                            0.000                    0.000
# min                          741.784                    1.135
# 25%                          741.784                    1.135
# 50%                          741.784                    1.135
# 75%                          741.784                    1.135
# max                          741.784                    1.135
#
#        vitamin_b2_scaled_ratio  protein_scaled_ratio  fiber_scaled_ratio  \
# count                    901.0                 901.0               901.0
# mean                       0.0                   0.0                 0.0
# std                        0.0                   0.0                 0.0
# min                        0.0                   0.0                 0.0
# 25%                        0.0                   0.0                 0.0
# 50%                        0.0                   0.0                 0.0
# 75%                        0.0                   0.0                 0.0
# max                        0.0                   0.0                 0.0
#
#        beta_carotene_scaled_ratio  qi_metric  energy_kcal_eaten  \
# count                       901.0    901.000            901.000
# mean                          0.0     95.161             39.334
# std                           0.0      0.000             30.734
# min                           0.0     95.161              0.213
# 25%                           0.0     95.161             21.300
# 50%                           0.0     95.161             21.300
# 75%                           0.0     95.161             42.600
# max                           0.0     95.161            213.000
#
#        eaten_quantity_in_gram
# count                 901.000
# mean                   92.332
# std                    72.147
# min                     0.500
# 25%                    50.000
# 50%                    50.000
# 75%                   100.000
# max                   500.000
#
# [8 rows x 23 columns]

# %%
t[t["combined_name"] == "Red Bull Zero Calories"][
    ["niacin_eaten", "vitamin_b6", "vitamin_b12", "energy_kcal_eaten"]
]
# Out:
#         niacin_eaten  vitamin_b6  vitamin_b12  energy_kcal_eaten
# 513972          0.02         2.0          2.0                4.5
# 513973          0.02         2.0          2.0                4.5
# 513974          0.02         2.0          2.0                4.5
# 513975          0.02         2.0          2.0                4.5
# 513976          0.02         2.0          2.0                4.5
# 513977          0.02         2.0          2.0                4.5
# 513978          0.02         2.0          2.0                4.5
# 513979          0.02         2.0          2.0                4.5
# 513980          0.02         2.0          2.0                4.5
# 513981          0.02         2.0          2.0                4.5
# 513982          0.02         2.0          2.0                4.5
# 513983          0.02         2.0          2.0                4.5
# 513984          0.02         2.0          2.0                4.5
# 513985          0.02         2.0          2.0                4.5
# 513986          0.02         2.0          2.0                4.5
# 513987          0.02         2.0          2.0                4.5
# 513988          0.02         2.0          2.0                4.5

# %%
t[t["combined_name"] == "Red Bull Zero Calories"][
    [i for i in t.columns if "scale" in i]
].drop_duplicates().T
# Out:
#                                                     513972
# sugar_scaled                                      0.000000
# fatty_acids_saturated_scaled                      0.000000
# salt_scaled                                      66.666667
# fatty_acids_monounsaturated_scaled                0.000000
# fatty_acids_polyunsaturated_scaled                0.000000
# cholesterol_scaled                                0.000000
# all_trans_retinol_equivalents_activity_scaled     0.000000
# vitamin_c_scaled                                  0.000000
# beta_carotene_scaled                              0.000000
# vitamin_e_activity_scaled                         0.000000
# vitamin_d_scaled                                  0.000000
# niacin_scaled                                  8888.888889
# vitamin_b6_scaled                              2222.222222
# folate_scaled                                     0.000000
# vitamin_b12_scaled                             2222.222222
# calcium_scaled                                    0.000000
# phosphorus_scaled                                 0.000000
# magnesium_scaled                                  0.000000
# iron_scaled                                       0.000000
# zinc_scaled                                       0.000000
# potassium_scaled                                  0.000000
# sodium_scaled                                     0.000000
# pantothenic_acid_scaled                        2222.222222
# vitamin_b1_scaled                                 0.000000
# vitamin_b2_scaled                                 0.000000
# protein_scaled                                    0.000000
# fiber_scaled                                      0.000000

# %%
qi_ratios[qi_ratios["combined_name"].str.contains("Chicken")].drop_duplicates(
    "combined_name"
)
# Out:
#         all_trans_retinol_equivalents_activity_scaled_ratio  \
# 192627                                      227434.257285
# 192695                                      227434.257285
# 193993                                      130861.504907
# 194586                                      111111.111111
# 194599                                           0.000000
# ...                                                   ...
# 514279                                           0.000000
# 514288                                           0.000000
# 514532                                           0.000000
# 514842                                           0.000000
# 514857                                           0.000000
#
#         vitamin_c_scaled_ratio  vitamin_e_activity_scaled_ratio  \
# 192627                0.092869                       451.077944
# 192695                0.092869                       451.077944
# 193993                0.000000                       396.946565
# 194586                0.000000                       488.888889
# 194599                0.000000                         0.000000
# ...                        ...                              ...
# 514279                0.000000                         0.000000
# 514288                0.000000                         0.000000
# 514532                0.000000                         0.000000
# 514842                0.000000                         0.000000
# 514857                0.000000                         0.000000
#
#         vitamin_d_scaled_ratio  niacin_scaled_ratio  vitamin_b6_scaled_ratio  \
# 192627                2.122720             1.137171                 5.587447
# 192695                2.122720             1.137171                 5.587447
# 193993                0.000000            11.995638                 4.227833
# 194586                2.222222             0.000000                 2.564103
# 194599                0.000000             0.000000                 0.000000
# ...                        ...                  ...                      ...
# 514279                0.000000             0.000000                 0.000000
# 514288                0.000000             0.000000                 0.000000
# 514532                0.000000             0.000000                 0.000000
# 514842                0.000000             0.000000                 0.000000
# 514857                0.000000             0.000000                 0.000000
#
#         folate_scaled_ratio  vitamin_b12_scaled_ratio  calcium_scaled_ratio  \
# 192627             0.323383                  2.197347              0.082587
# 192695             0.323383                  2.197347              0.082587
# 193993             0.213740                  2.099237              0.274809
# 194586             0.222222                  1.620370              0.078889
# 194599             0.000000                  0.000000              0.000000
# ...                     ...                       ...                   ...
# 514279             0.000000                  5.144033              0.000000
# 514288             0.000000                  0.000000              0.000000
# 514532             0.000000                  0.000000              0.000000
# 514842             0.000000                  0.000000              0.000000
# 514857             0.000000                  0.000000              0.000000
#
#         phosphorus_scaled_ratio  ...  vitamin_b1_scaled_ratio  \
# 192627                 3.553660  ...                 0.995025
# 192695                 3.553660  ...                 0.995025
# 193993                 4.798255  ...                 1.399491
# 194586                 3.174603  ...                 1.018519
# 194599                 0.000000  ...                 0.000000
# ...                         ...  ...                      ...
# 514279                 0.000000  ...                 0.000000
# 514288                 0.000000  ...                 0.000000
# 514532                 0.000000  ...                 0.000000
# 514842                 0.000000  ...                 0.000000
# 514857                 0.000000  ...                 0.000000
#
#         vitamin_b2_scaled_ratio  protein_scaled_ratio  fiber_scaled_ratio  \
# 192627                 1.718679              5.970149            0.000000
# 192695                 1.718679              5.970149            0.000000
# 193993                 2.637058              9.591769            0.000000
# 194586                 3.232323              6.352657            0.000000
# 194599                 0.000000              4.246714            0.217054
# ...                         ...                   ...                 ...
# 514279                 0.000000              5.636071            2.222222
# 514288                 0.000000              1.786778            0.273973
# 514532                 0.000000              1.309586            1.445783
# 514842                 0.000000              1.123188            0.000000
# 514857                 0.000000              1.581028            0.727273
#
#         beta_carotene_scaled_ratio     qi_metric  \
# 192627                         0.0  11395.753164
# 192695                         0.0  11395.753164
# 193993                         0.0   6565.134752
# 194586                         0.0   5581.287641
# 194599                         0.0      0.223188
# ...                            ...           ...
# 514279                         0.0      0.790720
# 514288                         0.0      0.103038
# 514532                         0.0      0.137768
# 514842                         0.0      0.056159
# 514857                         0.0      0.115415
#
#                                      combined_name  \
# 192627                              Chicken, whole
# 192695                                     Chicken
# 193993                             Chicken, breast
# 194586                         Chicken, for fondue
# 194599                               Chicken, wing
# ...                                            ...
# 514279  Planted. - Chicken Curry, 100% plant-based
# 514288            Butter Chicken with Masala Pualo
# 514532               Anna's thai red Chicken-Curry
# 514842     Migrolino - Sandwich (Chicken Cocktail)
# 514857        migrolino - Roasted Chicken & Grains
#
#                            food_group  energy_kcal_eaten  \
# 192627              meat_fish_seafood              221.1
# 192695              meat_fish_seafood              201.0
# 193993              meat_fish_seafood              235.8
# 194586              meat_fish_seafood               90.0
# 194599              meat_fish_seafood              283.8
# ...                               ...                ...
# 514279  soy_granules_textured_protein              137.7
# 514288                processed_foods              292.0
# 514532                processed_foods              664.0
# 514842                         others              630.0
# 514857                         others              660.0
#
#         eaten_quantity_in_gram
# 192627                   110.0
# 192695                   100.0
# 193993                   180.0
# 194586                    50.0
# 194599                   110.0
# ...                        ...
# 514279                    85.0
# 514288                   200.0
# 514532                   400.0
# 514842                   175.0
# 514857                   400.0
#
# [65 rows x 25 columns]

# %%
t.groupby("combined_name")["qi_metric"].std().round(2).fillna(0)[
    t.groupby("combined_name")["qi_metric"].std().round(2).fillna(0) > 0
].sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 t.groupby("combined_name")["qi_metric"].std().round(2).fillna(0)[
#       2     t.groupby("combined_name")["qi_metric"].std().round(2).fillna(0) > 0
#       3 ].sort_values(ascending=False)
#
# File c:\Users\Sophie\Anaconda\envs\Nutrient_Bachelor_Project\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File c:\Users\Sophie\Anaconda\envs\Nutrient_Bachelor_Project\Lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: qi_metric'

# %%
t[t["combined_name"] == "Andros - Apfel"]
# Out:
#         food_id        barcode  dish_id  eaten_quantity eaten_unit  \
# 466020     5244  3608580881865    26635           100.0          g
# 466021     5244  3608580881865    39823           100.0          g
# 479107     7019  3608580867968   140222            90.0          g
# 479108     7019  3608580867968   140859            90.0          g
# 479109     7019  3608580867968   139916            90.0          g
# 479110     7019  3608580867968   401361            90.0          g
# 479111     7019  3608580867968   400024            90.0          g
# 479112     7019  3608580867968    54616            90.0          g
# 479113     7019  3608580867968   402051            90.0          g
#
#        subject_key            eaten_at  eaten_at_utc_offset  media_count  \
# 466020      vfygbe 2019-04-29 11:31:24                  120            0
# 466021      b6qjbv 2019-06-15 18:14:52                  120            0
# 479107      8bztuh 2020-08-13 10:28:01                  120            0
# 479108      8bztuh 2020-08-17 08:11:13                  120            0
# 479109      8bztuh 2020-08-11 14:51:49                  120            0
# 479110      pyvpkd 2022-11-18 11:25:57                   60            0
# 479111      pyvpkd 2022-11-15 08:43:49                   60            0
# 479112      6zkdx5 2019-08-12 10:58:28                  120            0
# 479113      pyvpkd 2022-11-20 10:15:59                   60            0
#
#                    food_group_cname  ... folate_scaled vitamin_b12_scaled  \
# 466020  sweets_salty_snacks_alcohol  ...    254.901961                0.0
# 466021  sweets_salty_snacks_alcohol  ...    254.901961                0.0
# 479107  sweets_salty_snacks_alcohol  ...     99.148936                0.0
# 479108  sweets_salty_snacks_alcohol  ...     99.148936                0.0
# 479109  sweets_salty_snacks_alcohol  ...     99.148936                0.0
# 479110  sweets_salty_snacks_alcohol  ...     99.148936                0.0
# 479111  sweets_salty_snacks_alcohol  ...     99.148936                0.0
# 479112  sweets_salty_snacks_alcohol  ...     99.148936                0.0
# 479113  sweets_salty_snacks_alcohol  ...     99.148936                0.0
#
#        calcium_scaled phosphorus_scaled  magnesium_scaled  iron_scaled  \
# 466020     188.235294        352.941176        156.862745     7.843137
# 466021     188.235294        352.941176        156.862745     7.843137
# 479107     188.936170        226.808511        216.595745     4.680851
# 479108     188.936170        226.808511        216.595745     4.680851
# 479109     188.936170        226.808511        216.595745     4.680851
# 479110     188.936170        226.808511        216.595745     4.680851
# 479111     188.936170        226.808511        216.595745     4.680851
# 479112     188.936170        226.808511        216.595745     4.680851
# 479113     188.936170        226.808511        216.595745     4.680851
#
#         zinc_scaled  potassium_scaled  sodium_scaled  qi_metric
# 466020     3.921569       4313.725490     156.862745   0.525369
# 466021     3.921569       4313.725490     156.862745   0.525369
# 479107  1063.829787       4425.531915       0.000000  68.557833
# 479108  1063.829787       4425.531915       0.000000  68.557833
# 479109  1063.829787       4425.531915       0.000000  68.557833
# 479110  1063.829787       4425.531915       0.000000  68.557833
# 479111  1063.829787       4425.531915       0.000000  68.557833
# 479112  1063.829787       4425.531915       0.000000  68.557833
# 479113  1063.829787       4425.531915       0.000000  68.557833
#
# [9 rows x 118 columns]

# %%
df_food.groupby(["subject_key", "eaten_at"])["combined_name"].value_counts()
# Out:
# subject_key   eaten_at             combined_name
# 02ae3856ca04  2018-11-26 07:20:04  Coffee, with caffeine                              1
#               2018-11-26 07:47:34  Corn Flakes                                        1
#                                    Honey n.s.                                         1
#                                    Yaourt, yahourt, yogourt ou yoghourt, natural      1
#               2018-11-26 08:56:24  Banana                                             1
#                                                                                      ..
# zznk4w        2022-09-25 06:11:19  Tomato, raw                                        1
#               2022-09-25 09:19:35  Coffee, with caffeine                              1
#                                    Oat milk                                           1
#               2022-09-25 10:24:40  Porridge, prepared, with partially skimmed milk    1
#               2022-09-25 10:36:35  Cake, chocolate                                    1
# Name: count, Length: 317109, dtype: int64
